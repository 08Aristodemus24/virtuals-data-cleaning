# %%
import pandas as pd
import os
import json
import datetime as dt
from dateutil import parser 
import re
from concurrent.futures import ThreadPoolExecutor

# %%
input_dir = './Sport Bettor AI input'
files = os.listdir(input_dir)
files

# %%
csvs = {file.replace('.csv', ''): pd.read_csv(f'{input_dir}/{file}') \
        if file != 'Dataset#5200NBA players stats as of Nov 20th 2024 - Sheet1.csv' \
        else pd.read_csv(f'{input_dir}/{file}', header=None) for file in files if file.endswith('.csv')}

# %%
csvs

# %%
csvs['Dataset#5062pbp-2024'].isna().any(axis=0)

# %%
ds_5265 = pd.read_csv(f'./{input_dir}/Dataset#5265expanded_overtime_markets_data.txt', delimiter='|')
ds_5265

# %%
csvs['Dataset#5265expanded_overtime_markets_data'] = ds_5265

# %% [markdown]
# # Reformating any column with substring of date

# %%
# get the parts of the date like year, month, and day and reformats it to a string
# because it is virtually impossible to reformat a date with varying format
# so year, month, and day have to be extracted first
test_dt_obj = parser.parse('1/13/15')
test_dt_obj.day, test_dt_obj.month, test_dt_obj.year

# %%
reformed_date = f'{test_dt_obj.day} {test_dt_obj.month} {test_dt_obj.year}'
reformed_date

# %%
new_date = dt.datetime.strptime(reformed_date, '%d %m %Y').strftime('%B %#d %Y')
new_date

# %%
type(new_date)

# %%
csvs['Dataset#5062pbp-2024'].columns[[0, 1]]

# %%
def cohere(row):
    """
    restructures the meaningless number values in the dataframe
    and forms a coherent and meaningful sentence out of it

    args:
        row - row of a dataframe
    """
    message = ""
    df_indeces = row.keys()
    for df_index in df_indeces:
        if type(df_index) != int:
            # if header is a string specify the header in the message
            message += f"{df_index.lower().capitalize()} is {row[df_index] if not pd.isnull(row[df_index]) else "empty"}, "
        else:
            message += f"{row[df_index]} "
        

    return message

# %% [markdown]
# To clean the date what I can do is match anything in the Index returned by df.columns containing the string Date, date, or anything resembling it, we grab that column

# %%
def cohere_csvs(csvs: dict):
    """
    creates readable messages in a list from all rows of each 
    dataframes 

    args:
        csvs - dictionary of all .csv files
        with key as filename and value as the dataframe
        read by pd.read_csv()
    """
    outputs = []
    for dataset_name, df in csvs.items():
        # REFORMAT DATE
        print(f'processing: {dataset_name}')
        # note that columns in df.columns are strings extracts the
        # indeces that contain the string date in the columsn of a df 
        date_cols = [col for col in df.columns.to_list() if "date" in str(col).lower() or "time" in str(col).lower()]
        # print(date_cols)
        
        # however many columns we preprocesses these date columns
        # such that it can be readable
        def reformat_date(date):

            datetime_obj = parser.parse(date)
            year = datetime_obj.year
            month = datetime_obj.month
            day = datetime_obj.day
            combined_date = f'{day} {month} {year}'
            reformed_date = dt.datetime.strptime(combined_date, '%d %m %Y').strftime('%B %#d %Y')
            
            return reformed_date

        # apply reformating function on all columns with date
        for date_col in date_cols:
            df[date_col] = df[date_col].apply(reformat_date)

        # REMOVES any column that has substring or resembling an `id` or `unnamed: <int>` columns
        cols_to_del = [col for col in df.columns.to_list() if bool(re.search(r"id|Id|ID$", str(col))) or bool(re.search(r"[Uu]nnamed:\s[0-9]*", str(col)))]
        df.drop(columns=cols_to_del, inplace=True)

        # COHERE ALL COLUMNS INTO ONE COHERENT MESSAGE
        df['message'] = df.apply(cohere, axis=1)

        # Populate and save the generated messages
        outputs.append((dataset_name, df['message'].to_list()))

    return outputs

# %%
def clean_and_split_data(name, data, output_dir: str, char_limit: int=700, max_rows: int=40):
    """
    Cleans and splits text data:
    - Removes numbering at the start of lines.
    - Converts text to lowercase.
    - Splits each row to ensure it doesn't exceed the character limit.
    - Outputs multiple files if the number of rows exceeds max_rows.
    """
    def split_into_chunks(text, limit):
        """
        Splits a text into chunks no larger than the character limit.
        

        e.g "  "description": "Oracle-X is a...knowledge."," is a string
        or line that may ocntain 700+ characters 
        """
        
        chunks = []

        # if the length of line is bigger than limit i.e. 900 > 700
        # then the line is sliced into 700 character strings
        # and the next slice i.e. 700:900 or [700] to [899] is now set
        # as the next string to be processed but since slice [700] to [899]
        # length of 200 is now less than limit of 700 loop is terminated
        # and the final 200 characters are appended to the chunks list
        while len(text) > limit:
            chunks.append(text[:limit].strip())
            text = text[limit:]
        if text:
            chunks.append(text.strip())

        # chunks = [<chunk 1 of 700 char string>, <chunk 2 of 700 char string>, ..., <chunk n of <=700 char string>]
        return chunks

    # Process each row to enforce character limits
    output_lines = []
    for line in data:
        line = line.strip()
        output_lines.extend(split_into_chunks(line, char_limit))

    # Write to multiple files if necessary
    base_name = name

    # if output already exists use that folder (meaning don't overwrite)
    os.makedirs(output_dir, exist_ok=True)

    for i in range(0, len(output_lines), max_rows):
        """
        if there were 100 output lines and we wanted only
        40 lines per file, we would increment from
        0:0+40 or [0] to [39]
        40:40+40 or [40] to [79]
        80:80+40 or [80] to [119] 
        
        but in slicing arrays 
        when an array is only of a certain length and our end 
        index exceeds it we only really get the slice until the end of the array 
        so in essence we get only [80] to [99]
        """
        chunk = output_lines[i:i + max_rows]

        """40 is the max amount of rows"""
        output_file = os.path.join(output_dir, f"{base_name}_processed_part{i // max_rows + 1}.txt")
        print(f"output file: {output_file}")
        with open(output_file, 'w', encoding='utf-8') as file:
            file.writelines(line + '\n' for line in chunk)

        print(f"File {output_file} has been created with {len(chunk)} lines.")

# %% [markdown]
# # Preprocessing .csv's

# %%
outputs = cohere_csvs(csvs)
outputs

# %%
output_dir = './Sport Bettor AI'
for name, lists in outputs:
    clean_and_split_data(name, lists, output_dir)

# %% [markdown]
# # New method for preprocessing .json files with nested dictionaries inside using recursion

# %%
# Using recursion to get all values from nested dictionary
def extract_keys_values(file: dict):
    """
    extracts all information in nested dictionaries including
    key and value pair, recursively
    """
    try:    
        non_dict_vals = []

        for key, value in file.items():
            if isinstance(value, dict):
                non_dict_vals.extend(extract_keys_values(value))

            # this is if the value of corresponding key is an iterable
            # that may or may not contain purely single values or iterables
            # or another nested dictionary
            elif isinstance(value, list):
                for i in value:
                    if isinstance(i, dict):
                        non_dict_vals.extend(extract_keys_values(i))
                    else:
                        non_dict_vals.append(f'{key} is {i}')

            # this is if value of correspoinding key is purely an int, str, date,
            # or any value that is a non iterable
            else:
                non_dict_vals.append(f'{key} is {value}')

        return non_dict_vals
    except AttributeError:
        print(file)

# %%
def read_json_files(input_dir: str, files: list[str]):
    def helper(file_name):
        with open(f'{input_dir}/{file_name}', 'r') as file:
            data = json.load(file)
            file.close()

        new_name = file_name.replace('.json', '')
        return new_name, data

    # concurrently read and load all .json files
    with ThreadPoolExecutor() as exe:
        jsons = dict(list(exe.map(helper, files)))
    return jsons

# %%
json_files = [file for file in files if file.endswith('.json')]
jsons = read_json_files(input_dir=input_dir, files=json_files)
jsons

# %%
jsons['Dataset#5210Game data']
# Out:
# {'description': 'Access extended information about upcoming sports games, including odds, teams, times, bet types, and more. Data is structured and identified for seamless interpretation.',
#  'overtimeLink': 'https://overtimemarketsv2.xyz/overtime-v2/networks/10/markets/?status=open&ungroup=true&onlyBasicProperties=true&onlyMainMarkets=true&includeProofs=false&minMaturity=1731618761',
#  'gameExample': {'gameId': '0x4341353836444533304343380000000000000000000000000000000000000000',
#   'subLeagueId': 10,
#   'typeId': 0,
#   'line': 0,
#   'maturity': 1732419000,
#   'homeTeam': 'Los Angeles FC',
#   'awayTeam': 'Seattle Sounders FC',
#   'status': 0,
#   'odds': [0.534759358289, 0.263157894737, 0.285714285714],
#   'childMarkets': [{'typeId': 10001,
#     'line': -0.5,
#     'status': 0,
#     'odds': [0.545553737043, 0.534759358289]},
#    {'typeId': 10002,
#     'line': 2.5,
#     'status': 0,
#     'odds': [0.565291124929, 0.523834468308]}],
#   'statusCode': 'open'},
#  'identifiers': {'gameId': 'Identifier of the game',
#   'subLeagueId': 'Professional sport league name',
#   'typeId': {'0': 'Moneyline bet type',
#    '10001': 'Handicap bet type',
#    '10002': 'Spread bet type'},
#   'line': 'Bet value',
#   'maturity': 'UTC timestamp of the match',
#   'homeTeam': 'Home team name',
#   'awayTeam': 'Away team name',
#   'status': {'0': 'Open', '1': 'Closed'},
#   'odds': 'Odds of the line in implied odds',
#   'childMarkets': {'typeId': 'Attached bet type',
#    'line': 'Bet value',
#    'status': 'Market status',
#    'odds': 'Odds of the line in implied odds'}},
#  'leagueMappings': {'1': 'NCAAF',
#   '2': 'NFL',
#   '3': 'MLB',
#   '4': 'NBA',
#   '5': 'NCAAB',
#   '8': 'WNBA',
#   '6': 'NHL',
#   '10': 'MLS',
#   '11': 'EPL',
#   '12': 'FRA1',
#   '13': 'GER1',
#   '14': 'ESP1',
#   '15': 'ITA1',
#   '16': 'UEFA CL',
#   '17': 'UEFA EL'},
#  'impliedOdds': {'scale': '0 to 1',
#   'examples': {'0.5': {'american': '+100', 'decimal': '2'}}},
#  'timestampInfo': 'A UTC timestamp can be interpreted in calendar date (dd/mm/yyyy hh:mm)',
#  'marketStatus': {'0': 'Open'},
#  'goal': 'When a user requests information about a game offered on Overtime, the response should be built by fetching the required data from the link provided and formatting the answer based on the structured data.'}

# %% [markdown]
# # Note this json data actually comes first wrapped in a list so extract only the dictionary object itself before passing it through `extract_keys_values()`

# %%
jsons['Dataset#5212Example instructions']
# Out:
# [{'overtimeLink': 'https://overtimemarketsv2.xyz/overtime-v2/networks/10/markets/?status=open&ungroup=true&onlyBasicProperties=true&onlyMainMarkets=true&includeProofs=false&minMaturity=1731618761',
#   'instruction': 'Interpret the following game information and respond appropriately:',
#   'input': {'gameId': '0x4341353836444533304343380000000000000000000000000000000000000000',
#    'subLeagueId': 10,
#    'typeId': 0,
#    'line': 0,
#    'maturity': 1732419000,
#    'homeTeam': 'Los Angeles FC',
#    'awayTeam': 'Seattle Sounders FC',
#    'status': 0,
#    'odds': [0.534759358289, 0.263157894737, 0.285714285714],
#    'childMarkets': [{'typeId': 10001,
#      'line': -0.5,
#      'status': 0,
#      'odds': [0.545553737043, 0.534759358289]},
#     {'typeId': 10002,
#      'line': 2.5,
#      'status': 0,
#      'odds': [0.565291124929, 0.523834468308]}]},
#   'output': 'This game features Los Angeles FC vs Seattle Sounders FC. The moneyline odds are 0.53 for Los Angeles FC, 0.26 for Seattle Sounders FC, and 0.29 for a draw. The game will take place at 15/12/2024 21:30 UTC.'},
#  {'overtimeLink': 'https://overtimemarketsv2.xyz/overtime-v2/networks/10/markets/?status=open&ungroup=true&onlyBasicProperties=true&onlyMainMarkets=true&includeProofs=false&minMaturity=1731618761',
#   'instruction': 'What are the odds for a handicap bet?',
#   'input': {'typeId': 10001,
#    'line': -0.5,
#    'status': 0,
#    'odds': [0.545553737043, 0.534759358289]},
#   'output': 'For a handicap bet of -0.5, the odds are 0.54 for the favorite and 0.53 for the underdog.'},
#  {'overtimeLink': 'https://overtimemarketsv2.xyz/overtime-v2/networks/10/markets/?status=open&ungroup=true&onlyBasicProperties=true&onlyMainMarkets=true&includeProofs=false&minMaturity=1731618761',
#   'instruction': 'Explain how implied odds work.',
#   'input': None,
#   'output': 'Implied odds are represented on a scale from 0 to 1. For example, 0.5 implied odds equates to +100 in American odds or 2 in decimal odds.'}]

# %%
jsons['Dataset#5212Example instructions'] = jsons['Dataset#5212Example instructions'][0]

# %%
outputs = []
for dataset_name, json in jsons.items():
    outputs.append(
        (dataset_name, extract_keys_values(json))
    )

# %%
outputs
# Out:
# [('Dataset#5210Game data',
#   ['description is Access extended information about upcoming sports games, including odds, teams, times, bet types, and more. Data is structured and identified for seamless interpretation.',
#    'overtimeLink is https://overtimemarketsv2.xyz/overtime-v2/networks/10/markets/?status=open&ungroup=true&onlyBasicProperties=true&onlyMainMarkets=true&includeProofs=false&minMaturity=1731618761',
#    'gameId is 0x4341353836444533304343380000000000000000000000000000000000000000',
#    'subLeagueId is 10',
#    'typeId is 0',
#    'line is 0',
#    'maturity is 1732419000',
#    'homeTeam is Los Angeles FC',
#    'awayTeam is Seattle Sounders FC',
#    'status is 0',
#    'odds is 0.534759358289',
#    'odds is 0.263157894737',
#    'odds is 0.285714285714',
#    'typeId is 10001',
#    'line is -0.5',
#    'status is 0',
#    'odds is 0.545553737043',
#    'odds is 0.534759358289',
#    'typeId is 10002',
#    'line is 2.5',
#    'status is 0',
#    'odds is 0.565291124929',
#    'odds is 0.523834468308',
#    'statusCode is open',
#    'gameId is Identifier of the game',
#    'subLeagueId is Professional sport league name',
#    '0 is Moneyline bet type',
#    '10001 is Handicap bet type',
#    '10002 is Spread bet type',
#    'line is Bet value',
#    'maturity is UTC timestamp of the match',
#    'homeTeam is Home team name',
#    'awayTeam is Away team name',
#    '0 is Open',
#    '1 is Closed',
#    'odds is Odds of the line in implied odds',
#    'typeId is Attached bet type',
#    'line is Bet value',
#    'status is Market status',
#    'odds is Odds of the line in implied odds',
#    '1 is NCAAF',
#    '2 is NFL',
#    '3 is MLB',
#    '4 is NBA',
#    '5 is NCAAB',
#    '8 is WNBA',
#    '6 is NHL',
#    '10 is MLS',
#    '11 is EPL',
#    '12 is FRA1',
#    '13 is GER1',
#    '14 is ESP1',
#    '15 is ITA1',
#    '16 is UEFA CL',
#    '17 is UEFA EL',
#    'scale is 0 to 1',
#    'american is +100',
#    'decimal is 2',
#    'timestampInfo is A UTC timestamp can be interpreted in calendar date (dd/mm/yyyy hh:mm)',
#    '0 is Open',
#    'goal is When a user requests information about a game offered on Overtime, the response should be built by fetching the required data from the link provided and formatting the answer based on the structured data.']),
#  ('Dataset#5212Example instructions',
#   ['overtimeLink is https://overtimemarketsv2.xyz/overtime-v2/networks/10/markets/?status=open&ungroup=true&onlyBasicProperties=true&onlyMainMarkets=true&includeProofs=false&minMaturity=1731618761',
#    'instruction is Interpret the following game information and respond appropriately:',
#    'gameId is 0x4341353836444533304343380000000000000000000000000000000000000000',
#    'subLeagueId is 10',
#    'typeId is 0',
#    'line is 0',
#    'maturity is 1732419000',
#    'homeTeam is Los Angeles FC',
#    'awayTeam is Seattle Sounders FC',
#    'status is 0',
#    'odds is 0.534759358289',
#    'odds is 0.263157894737',
#    'odds is 0.285714285714',
#    'typeId is 10001',
#    'line is -0.5',
#    'status is 0',
#    'odds is 0.545553737043',
#    'odds is 0.534759358289',
#    'typeId is 10002',
#    'line is 2.5',
#    'status is 0',
#    'odds is 0.565291124929',
#    'odds is 0.523834468308',
#    'output is This game features Los Angeles FC vs Seattle Sounders FC. The moneyline odds are 0.53 for Los Angeles FC, 0.26 for Seattle Sounders FC, and 0.29 for a draw. The game will take place at 15/12/2024 21:30 UTC.']),
#  ('Dataset#5213Overtime data interpretation',
#   ['overtimeLink is https://overtimemarketsv2.xyz/overtime-v2/networks/10/markets/?status=open&ungroup=true&onlyBasicProperties=true&onlyMainMarkets=true&includeProofs=false&minMaturity=1731618761',
#    '1 is NCAAF',
#    '2 is NFL',
#    '3 is MLB',
#    '4 is NBA',
#    '5 is NCAAB',
#    '8 is WNBA',
#    '6 is NHL',
#    '10 is MLS',
#    '11 is EPL',
#    '12 is FRA1',
#    '13 is GER1',
#    '14 is ESP1',
#    '15 is ITA1',
#    '16 is UEFA CL',
#    '17 is UEFA EL',
#    'scale is 0 to 1',
#    'american is +100',
#    'decimal is 2',
#    '0 is Open',
#    '1 is Closed',
#    'gameId is Identifier of the game',
#    'subLeagueId is Professional sport league name',
#    '0 is Moneyline bet type',
#    '10001 is Handicap bet type',
#    '10002 is Spread bet type',
#    'line is Bet value',
#    'maturity is UTC timestamp of the match',
#    'homeTeam is Home team name',
#    'awayTeam is Away team name',
#    'status is Market status',
#    'odds is Odds of the line in implied odds',
#    'timestampInfo is A UTC timestamp can be interpreted in calendar date (dd/mm/yyyy hh:mm)']),
#  ('Dataset#6809sports_betting_accounts',
#   ['description is List of popular sports and sports betting accounts with descriptions and URLs.',
#    'name is Adam Schefter',
#    'description is NFL Insider for ESPN, providing breaking news and updates.',
#    'url is https://x.com/AdamSchefter',
#    'name is Ian Rapoport',
#    'description is NFL Network Insider with the latest league news.',
#    'url is https://x.com/RapSheet',
#    'name is Adrian Wojnarowski',
#    'description is NBA insider known for breaking news.',
#    'url is https://x.com/wojespn',
#    'name is Shams Charania',
#    'description is NBA news and updates from The Athletic and Stadium reporter.',
#    'url is https://x.com/ShamsCharania',
#    'name is Field Yates',
#    'description is NFL Insider and fantasy football analyst for ESPN.',
#    'url is https://x.com/FieldYates',
#    'name is Jay Glazer',
#    'description is NFL Insider for FOX Sports, offering exclusive news.',
#    'url is https://x.com/JayGlazer',
#    'name is SportsCenter',
#    "description is ESPN's flagship account for sports highlights and news.",
#    'url is https://x.com/SportsCenter',
#    'name is Bleacher Report',
#    'description is Sports news, highlights, and analysis across all major leagues.',
#    'url is https://x.com/BleacherReport',
#    'name is The Athletic',
#    'description is In-depth sports journalism covering various leagues and teams.',
#    'url is https://x.com/TheAthletic',
#    'name is Pro Football Focus (PFF)',
#    'description is Offering advanced NFL analytics and grades.',
#    'url is https://x.com/PFF',
#    'name is ESPN Stats & Info',
#    'description is Statistical insights and information across all sports.',
#    'url is https://x.com/ESPNStatsInfo',
#    'name is BetMGM',
#    'description is Official account of BetMGM sportsbook, sharing odds and promotions.',
#    'url is https://x.com/BetMGM',
#    'name is DraftKings',
#    'description is Daily fantasy sports and sportsbook updates.',
#    'url is https://x.com/DraftKings',
#    'name is FanDuel',
#    'description is Sportsbook and daily fantasy sports news and promotions.',
#    'url is https://x.com/FanDuel',
#    'name is PointsBet USA',
#    'description is Updates and promotions from PointsBet sportsbook.',
#    'url is https://x.com/PointsBetUSA',
#    'name is Covers',
#    'description is Sports betting news, analysis, and picks.',
#    'url is https://x.com/Covers',
#    'name is The Action Network',
#    'description is Sports betting insights, data, and analysis.',
#    'url is https://x.com/ActionNetworkHQ',
#    'name is VSiN',
#    'description is Vegas Stats & Information Network, offering sports betting news and analysis.',
#    'url is https://x.com/VSiNLive',
#    'name is Bleacher Report Betting',
#    "description is Bleacher Report's sports betting content and picks.",
#    'url is https://x.com/br_betting',
#    'name is Sports Betting Dime',
#    'description is Sports betting news and information.',
#    'url is https://x.com/SBD',
#    'name is Bet The Board Podcast',
#    'description is Podcast focusing on sports betting analysis and picks.',
#    'url is https://x.com/BetTheBoardPod',
#    'name is RJ Bell',
#    'description is Founder of Pregame.com, offering betting insights.',
#    'url is https://x.com/RJinVegas',
#    'name is Joe Fortenbaugh',
#    'description is ESPN sports betting analyst and host.',
#    'url is https://x.com/JoeFortenbaugh',
#    'name is Todd Fuhrman',
#    'description is Former oddsmaker and host of Bet the Board podcast.',
#    'url is https://x.com/ToddFuhrman',
#    'name is Cousin Sal',
#    'description is Sports betting personality and host of Against All Odds podcast.',
#    'url is https://x.com/TheCousinSal',
#    'name is Warren Sharp',
#    'description is Providing NFL analytics and betting insights.',
#    'url is https://x.com/SharpFootball',
#    'name is Sports Gambling Podcast',
#    'description is Offering picks and analysis.',
#    'url is https://x.com/GamblingPodcast',
#    'name is Covers Betting',
#    'description is Dedicated sports betting account.',
#    'url is https://x.com/CoversBetting',
#    'name is BettingPros NFL',
#    'description is NFL betting advice and picks.',
#    'url is https://x.com/BettingProsNFL',
#    'name is BetQL',
#    'description is Sports betting analytics and data-driven picks.',
#    'url is https://x.com/BetQLApp',
#    'name is Sports Insights',
#    'description is Real-time betting data and analytics.',
#    'url is https://x.com/SportsInsights',
#    'name is Odds Shark',
#    'description is Sports betting news, odds, and picks.',
#    'url is https://x.com/OddsShark',
#    'name is WagerTalk',
#    'description is Sports betting tips, picks, and analysis.',
#    'url is https://x.com/WagerTalk',
#    'name is Right Angle Sports',
#    'description is Professional betting group offering insights and picks.',
#    'url is https://x.com/RASPicks',
#    'name is Beating The Book',
#    "description is Gill Alexander's sports betting podcast and insights.",
#    'url is https://x.com/BeatingTheBook',
#    'name is Betting The Odds',
#    'description is Sports betting news and odds updates.',
#    'url is https://x.com/BettingTheOdds',
#    'name is Sports Bet Expert',
#    'description is Expert sports betting picks and analysis.',
#    'url is https://x.com/SportsBetExpert',
#    'name is Betting Predator',
#    'description is Sports betting analysis and predictions.',
#    'url is https://x.com/BettingPredator',
#    'name is Betting Odds UK',
#    'description is UK-focused sports betting odds and news.',
#    'url is https://x.com/BettingOddsUK',
#    'name is Betting Tips 4 You',
#    'description is Daily sports betting tips and predictions.',
#    'url is https://x.com/BettingTips4You',
#    'name is Betting Expert',
#    'description is Expert sports betting picks and insights.',
#    'url is https://x.com/Betting_Expert',
#    'name is Betting Gods',
#    'description is Professional sports betting advice and analysis.',
#    'url is https://x.com/BettingGods',
#    'name is Betting Metrics',
#    'description is Analytics and tools for smarter betting decisions.',
#    'url is https://x.com/BettingMetrics',
#    'name is Betting Pros',
#    'description is Comprehensive sports betting advice and picks.',
#    'url is https://x.com/BettingPros',
#    'name is Wager Talk',
#    'description is In-depth sports betting discussions and analysis.',
#    'url is https://x.com/WagerTalk',
#    'name is The Bookies Report',
#    'description is Insights into the sports betting world.',
#    'url is https://x.com/TheBookiesReport',
#    'name is BetQL App',
#    'description is Data-driven betting predictions and insights.',
#    'url is https://x.com/BetQLApp',
#    'name is Sharp App',
#    'description is Data-driven picks and betting insights.',
#    'url is https://x.com/TheSharpApp',
#    'name is Sports Line',
#    'description is Sports betting tips and tools.',
#    'url is https://x.com/SportsLine',
#    'name is Bet Labs Sports',
#    'description is Analytical tools for crafting winning strategies.',
#    'url is https://x.com/BetLabsSports',
#    'name is NFL',
#    'description is Official account of the National Football League.',
#    'url is https://x.com/NFL',
#    'name is NBA',
#    'description is Official account of the National Basketball Association.',
#    'url is https://x.com/NBA',
#    'name is MLB',
#    'description is Official account of Major League Baseball.',
#    'url is https://x.com/MLB',
#    'name is NHL',
#    'description is Official account of the National Hockey League.',
#    'url is https://x.com/NHL',
#    'name is ESPN',
#    'description is Global sports network with highlights and analysis.',
#    'url is https://x.com/ESPN',
#    'name is Fox Sports',
#    'description is Updates and highlights from Fox Sports.',
#    'url is https://x.com/FOXSports',
#    'name is CBS Sports',
#    'description is Sports coverage and updates from CBS Sports.',
#    'url is https://x.com/CBSSports',
#    'name is NBC Sports',
#    'description is Sports news and updates from NBC Sports.',
#    'url is https://x.com/NBCSports',
#    'name is Bleacher Report',
#    'description is Sports highlights and analysis.',
#    'url is https://x.com/BleacherReport',
#    'name is The Athletic',
#    'description is Long-form sports journalism.',
#    'url is https://x.com/TheAthletic',
#    'name is SportsCenter',
#    'description is ESPN’s flagship account for breaking news.',
#    'url is https://x.com/SportsCenter',
#    'name is Pro Football Focus (PFF)',
#    'description is Advanced analytics and grades.',
#    'url is https://x.com/PFF',
#    'name is ESPN Stats & Info',
#    'description is Sports statistics and insights.',
#    'url is https://x.com/ESPNStatsInfo'])]

# %%
output_dir = './Sport Bettor AI'
for name, lists in outputs:
    clean_and_split_data(name, lists, output_dir)
# Out:
# output file: ./Sport Bettor AI\Dataset#5210Game data_processed_part1.txt
# File ./Sport Bettor AI\Dataset#5210Game data_processed_part1.txt has been created with 40 lines.
# output file: ./Sport Bettor AI\Dataset#5210Game data_processed_part2.txt
# File ./Sport Bettor AI\Dataset#5210Game data_processed_part2.txt has been created with 21 lines.
# output file: ./Sport Bettor AI\Dataset#5212Example instructions_processed_part1.txt
# File ./Sport Bettor AI\Dataset#5212Example instructions_processed_part1.txt has been created with 24 lines.
# output file: ./Sport Bettor AI\Dataset#5213Overtime data interpretation_processed_part1.txt
# File ./Sport Bettor AI\Dataset#5213Overtime data interpretation_processed_part1.txt has been created with 33 lines.
# output file: ./Sport Bettor AI\Dataset#6809sports_betting_accounts_processed_part1.txt
# File ./Sport Bettor AI\Dataset#6809sports_betting_accounts_processed_part1.txt has been created with 40 lines.
# output file: ./Sport Bettor AI\Dataset#6809sports_betting_accounts_processed_part2.txt
# File ./Sport Bettor AI\Dataset#6809sports_betting_accounts_processed_part2.txt has been created with 40 lines.
# output file: ./Sport Bettor AI\Dataset#6809sports_betting_accounts_processed_part3.txt
# File ./Sport Bettor AI\Dataset#6809sports_betting_accounts_processed_part3.txt has been created with 40 lines.
# output file: ./Sport Bettor AI\Dataset#6809sports_betting_accounts_processed_part4.txt
# File ./Sport Bettor AI\Dataset#6809sports_betting_accounts_processed_part4.txt has been created with 40 lines.
# output file: ./Sport Bettor AI\Dataset#6809sports_betting_accounts_processed_part5.txt
# File ./Sport Bettor AI\Dataset#6809sports_betting_accounts_processed_part5.txt has been created with 30 lines.
