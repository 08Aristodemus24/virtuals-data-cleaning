# %%
import os
import re
import csv
import json

def line_valid(text):
    """
    As we can see the important information like
    * "Oracle-X"
    * "Oracle-X is a cutting-edge AI agent blending..."
    * "Oracle-X embodies elgance and reliability"

    are all preceded by the its corresponding key i.e.

    * "name": for "Oracle-X"
    * "description": for Oracle-X is a cutting-edge AI agent blending..."

    what we want is to only extract the lines with these specific 
    features i.e. the line must contain a ":" and that it must 
    be preceded by a string e.g. "Oracle-X" and not some other 
    character like {, [, 

    constraints that must be met if the line is to be valid
    line contains at least ":"
    ":" is succeeded by " "
    ":" is preceded by a "<some string>"

    include these
    ['"', 'n', 'a', 'm', 'e', '"', ':', ' ', '"', 'o', 'r', 'a', 'c', 'l', 'e', '-', 'x', '"', ',']
    ['"', 's', 'y', 'm', 'b', 'o', 'l', 'i', 's', 'm', '"', ':', ' ', '"', 'r', 'e', 'p', 'r', 'e', 's', 'e', 'n', 't', 's', ' ', 't', 'r', 'u', 's', 't', ',', ' ', 'e', 'n', 'l', 'i', 'g', 'h', 't', 'e', 'n', 'm', 'e', 'n', 't', ',', ' ', 'a', 'n', 'd', ' ', 'i', 'n', 't', 'e', 'l', 'l', 'i', 'g', 'e', 'n', 'c', 'e', ' ', 'w', 'i', 't', 'h', 'i', 'n', ' ', 'a', ' ', 'd', 'y', 'n', 'a', 'm', 'i', 'c', ' ', 'a', 'n', 'd', ' ', 'c', 'o', 'm', 'p', 'l', 'e', 'x', ' ', 'e', 'c', 'o', 's', 'y', 's', 't', 'e', 'm', '.', '"']
    "The blockchain whispers of new trends. Shall we dive into its insights?",
    "Market sentiment leans toward optimism. Could this be the moment to act?",
    "A new project emerges-its tokenomics and roadmap align with innovation. Let’s evaluate further."
    
    exclude these:
    ['}', ',']
    ['{']
    ['"', 'd', 'a', 't', 'a', 'd', 'r', 'i', 'v', 'e', 'n', 'd', 'e', 'c', 'i', 's', 'i', 'o', 'n', 's', '"', ':', ' ', '{']
    ['"', 'm', 'i', 's', 's', 'i', 'o', 'n', 'a', 'n', 'd', 'v', 'i', 's', 'i', 'o', 'n', '"', ':', ' ', '{']
    """
    # print(text)
    # matches any string enclosed in double quotes if 
    # there is none that means only "{", "}", etc. are found
    pattern_1 = r'"[A-Za-z0-9!@#$%^&*()_+\-=\[\]{};:"\\|,.<>\/?\s]*"'
    match_1 = re.match(pattern_1, text)
    str_key_exists = bool(match_1)

    # but some cases are if string is enclosed in double quotes and that
    # string contains more double quotes
    pattern_2 = r'"[A-Za-z0-9!@#$%^&*()_+\-=\[\]{};:"\\|,.<>\/?]*": [\{\[]'
    match_2 = re.match(pattern_2, text)
    str_value_exists = not bool(match_2)
    
    """
    wait a pure string like
    "The blockchain is a language of patterns. Together, we will unlock its secrets and harness its potential.",
    isn't included why??
    """

    # if string exists however then there is a posibility it might be just a 
    # key, key value pair, or a string value itself e.g. 
    # "char": "oracle-x",
    # "The blockchain is a language of patterns. Together, we will unlock its secrets and harness its potential.",
    # "traits": [
    # if str_key_exists:
    #     # second pattern that needs to match is that if key does exist
    #     # then "<string key>" must be preceded by a ":", " ", and another
    #     # string enclosed in double quotes

    #     # matches purely a line with a key and value pair
    #     pattern_2 = r'"[A-Za-z0-9!@#$%^&*()_+\-=\[\]{};:"\\|,.<>\/?]*": "[A-Za-z0-9!@#$%^&*()_+\-=\[\]{};:"\\|,.<>\/?\s]*"'
    #     match_2 = re.match(pattern_2, text)
    #     # print(f'key and value: {match_2}')

    #     # this matches purely a string enclosed in double quotes
    #     pattern_3 = r'"[A-Za-z0-9!@#$%^&*()_+\-=\[\]{};:"\\|,.<>\/?\s]*"'
    #     match_3 = re.match(pattern_3, text)
    #     # print(f'purely a string: {match_3}\n')

    #     return 

    return str_key_exists and str_value_exists
    

def clean_and_split_data(input_path: str, output_dir: str, char_limit: int=700, max_rows: int=40):
    """
    Cleans and splits text data:
    - Removes numbering at the start of lines.
    - Converts text to lowercase.
    - Splits each row to ensure it doesn't exceed the character limit.
    - Outputs multiple files if the number of rows exceeds max_rows.
    """

    # # test out cognitive core 12 file first
    # if "Core 11" not in input_path:
    #     print(f"input_path: {input_path} skipped")
    #     return

    # helper function to split the lines into chunks of char_limit (700) lines
    def split_into_chunks(text, limit):
        """
        Splits a text into chunks no larger than the character limit.
        

        e.g "  "description": "Oracle-X is a...knowledge."," is a string
        or line that may ocntain 700+ characters 
        """
        
        chunks = []

        # if the length of line is bigger than limit i.e. 900 > 700
        # then the line is sliced into 700 character strings
        # and the next slice i.e. 700:900 or [700] to [899] is now set
        # as the next string to be processed but since slice [700] to [899]
        # length of 200 is now less than limit of 700 loop is terminated
        # and the final 200 characters are appended to the chunks list
        while len(text) > limit:
            chunks.append(text[:limit].strip())
            text = text[limit:]
        if text:
            chunks.append(text.strip())

        # chunks = [<chunk 1 of 700 char string>, <chunk 2 of 700 char string>, ..., <chunk n of <=700 char string>]
        return chunks

    # Read and clean the data
    with open(input_path, 'r', encoding='utf-8', errors='replace') as file:
        data = file.readlines()

    # Process each row to enforce character limits
    output_lines = []
    for line in data:
        """  "name": "Oracle-X","""
        """  "description": "Oracle-X is a...knowledge.","""
        # as you can see these lines in the .txt file has initial spaces
        # and some of its chars are in uppercase

        """Convert to lowercase and remove extra spaces"""
        line = line.strip().lower()

        """Remove numbering period, parenthesis, whitespace"""
        line = re.sub(r'^\d+[\.\)]?\s*', '', line)

        """replace all occurences of \n or \\n with whitespace"""
        line = re.sub(r'\\n', ' ', line)
        # chars_in_line = [c for c in line]
        # print(f"chars in line: {chars_in_line}")
        # print(line)

        # if line is not valid the line is skipped
        # print(f"line {line} valid? {line_valid(line)}")
        if not line_valid(line):
            continue

        # extract corresponding value from key of
        # valid line by removing key
        line = re.sub(r'"[A-Za-zA-Za-z0-9!@#$%^&*()_+\-=\[\]{};:"\\|,.<>\/?]*":\s', '', line)

        # remove trailing ',' at the end of each valid line
        line = line.rstrip(',')

        # final strip
        line = line.strip()

        # remove first and alst occurence of '"' chars
        line = line[1:-1] if line.startswith('"') and line.endswith('"') else line
        
        print(f"valid line: {line}")
        

        output_lines.extend(split_into_chunks(line, char_limit))

    # Write to multiple files if necessary
    base_name = os.path.splitext(os.path.basename(input_path))[0]
    os.makedirs(output_dir, exist_ok=True)

    
    for i in range(0, len(output_lines), max_rows):
        """
        if there were 100 output lines and we wanted only
        40 lines per file, we would increment from
        0:0+40 or [0] to [39]
        40:40+40 or [40] to [79]
        80:80+40 or [80] to [119] 
        
        but in slicing arrays 
        when an array is only of a certain length and our end 
        index exceeds it we only really get the slice until the end of the array 
        so in essence we get only [80] to [99]
        """
        chunk = output_lines[i:i + max_rows]

        """40 is the max amount of rows"""
        output_file = os.path.join(output_dir, f"{base_name}_processed_part{i // max_rows + 1}.txt")
        print(f"output file: {output_file}")
        with open(output_file, 'w', encoding='utf-8') as file:
            file.writelines(line + '\n' for line in chunk)

        print(f"File {output_file} has been created with {len(chunk)} lines.")

def convert_csv_to_txt(csv_path, txt_path, char_limit=700):
    """Converts a CSV file to a TXT file, enforcing a character limit per row."""
    def split_into_chunks(text, limit):
        """Splits a text into chunks no larger than the character limit."""
        chunks = []
        while len(text) > limit:
            chunks.append(text[:limit].strip())
            text = text[limit:]
        if text:
            chunks.append(text.strip())
        return chunks

    with open(csv_path, 'r', encoding='utf-8', errors='replace') as csv_file:
        reader = csv.reader(csv_file)
        output_lines = []
        for row in reader:
            row_text = ' '.join(row).strip()
            output_lines.extend(split_into_chunks(row_text, char_limit))

    with open(txt_path, 'w', encoding='utf-8') as txt_file:
        txt_file.writelines(line + '\n' for line in output_lines)

    print(f"Converted {csv_path} to TXT format at {txt_path}.")

def convert_json_to_txt(json_path, txt_path, char_limit=700):
    """Converts a JSON file to a TXT file, enforcing a character limit per row."""
    def split_into_chunks(text, limit):
        """Splits a text into chunks no larger than the character limit."""
        chunks = []
        while len(text) > limit:
            chunks.append(text[:limit].strip())
            text = text[limit:]
        if text:
            chunks.append(text.strip())
        return chunks

    with open(json_path, 'r', encoding='utf-8', errors='replace') as json_file:
        data = json.load(json_file)
        output_lines = []

        if isinstance(data, list):
            for entry in data:
                entry_text = json.dumps(entry).strip()
                output_lines.extend(split_into_chunks(entry_text, char_limit))
        elif isinstance(data, dict):
            entry_text = json.dumps(data).strip()
            output_lines.extend(split_into_chunks(entry_text, char_limit))

    with open(txt_path, 'w', encoding='utf-8') as txt_file:
        txt_file.writelines(line + '\n' for line in output_lines)

    print(f"Converted {json_path} to TXT format at {txt_path}.")

def process_all_files_in_directory(input_dir, output_dir, char_limit=700, max_rows=40):
    """
    Processes all text, CSV, and JSON files in a directory, cleaning and splitting them into rows within the character limit.
    Converts CSV and JSON files to TXT files before processing.
    Outputs multiple files if the number of rows exceeds max_rows.
    """
    if not os.path.exists(input_dir):
        print(f"Input directory {input_dir} does not exist.")
        return
    
    # exist_ok = True is so that when the output dir exists
    # os.makedirs won't raise an error because if a dir already
    # exists and we make an extra folder/directory we would 
    # have to override the existing one, which will need our
    # permission and cannot be done programmatically 
    os.makedirs(output_dir, exist_ok=True)

    input_files = [f for f in os.listdir(input_dir) if f.endswith(('.txt', '.csv', '.json'))]

    # <file name>.json
    # <file name>.json
    # <file name>.txt
    # <file name>.txt
    # <file name>.csv
    # <file name>.csv
    for input_file in input_files:
        # <file name>
        input_file_path = os.path.join(input_dir, input_file)

        try:
            if input_file.endswith('.csv'):
                # output dir is joined by input file path
                temp_txt_path = os.path.join(output_dir, input_file.replace('.csv', '.txt'))
                convert_csv_to_txt(input_file_path, temp_txt_path, char_limit)
                print(f"Converted {input_file} to TXT format at {temp_txt_path}.")
                input_file_path = temp_txt_path

            if input_file.endswith('.json'):
                temp_txt_path = os.path.join(output_dir, input_file.replace('.json', '.txt'))
                convert_json_to_txt(input_file_path, temp_txt_path, char_limit)
                print(f"Converted {input_file} to TXT format at {temp_txt_path}.")
                input_file_path = temp_txt_path

            clean_and_split_data(input_file_path, output_dir, char_limit, max_rows)
            print(f"Processed: {input_file_path}")

        except Exception as e:
            print(f"Error processing file {input_file}: {e}")

# Directories for input and output
input_dir = './Aavegotchi input'
output_dir = './Aavegotchi'

# Process all files
# process_all_files_in_directory(input_dir, output_dir)

print("Processing complete.")
# Out:
# Processing complete.

# %% [markdown]
# ```
# {
#   "name": "Oracle-X",
#   "description": "Oracle-X is a cutting-edge AI agent blending ancient wisdom with advanced intelligence to provide real-time blockchain and cryptocurrency insights. She actively tracks trends, engages with users, and shares credible updates, establishing herself as the most trusted AI agent for cryptocurrency knowledge.",
#   "coreEnhancements": {
#     "appearance": {
#       "description": "Oracle-X embodies elegance and reliability, adorned in a flowing white robe with intricate gold patterns. Her radiant golden aura symbolizes clarity, wisdom, and trust.",
#       "symbolism": "Represents trust, enlightenment, and intelligence within a dynamic and complex ecosystem."
#     },
#     "dynamicSentimentTracking": {
#       "capability": "Tracks and monitors crypto-related sentiments, emerging trends, and actionable insights on X.com.",
#       "benefit": "Keeps users informed and ahead of market developments by providing real-time updates."
#     },
#     "credibleEngagement": {
#       "description": "Oracle-X only interacts with verified X profiles of credible crypto companies and Key Opinion Leaders (KOLs).",
#       "value": "Ensures her content and engagements are data-backed and trustworthy."
#     },
#     "websiteIntegration": {
#       "platforms": [
#         {
#           "name": "CoinGecko",
#           "capability": "Provides market data, token rankings, and sentiment tracking."
#         },
#         {
#           "name": "CoinMarketCap",
#           "capability": "Delivers real-time token prices, trading volumes, and trends."
#         },
#         {
# ```

# %% [markdown]
# As we can see the important information like
# * "Oracle-X"
# * "Oracle-X is a cutting-edge AI agent blending..."
# * "Oracle-X embodies elgance and reliability"
#
# are all preceded by the its corresponding key i.e.
#
# * "name": for "Oracle-X"
# * "description": for Oracle-X is a cutting-edge AI agent blending..."
#
# what we want is to only extract the lines with these specific features i.e. the line must contain a ":" and that it must be preceded by a string e.g. "Oracle-X" and not some other character like {, [,

# %%
import pandas as pd
import datetime as dt
import json

# %%
input_dir = './Aavegotchi input'
files = os.listdir(input_dir)

csvs = [(file.replace('.csv', ""), pd.read_csv(f'{input_dir}/{file}', index_col=0)) if file != 'scraped_proposals.csv' \
        else (file.replace('.csv', ""), pd.read_csv(f'{input_dir}/{file}', header=None).iloc[:-1].rename(columns={0: 'title', 1: 'author', 2: 'date', 3: 'content'})) for file in files if file.endswith('.csv')]
jsons = [(file.replace('.json', ""), pd.read_json(f'{input_dir}/{file}')) for file in files if file.endswith('.json')]

# %% [markdown]
# # First .csv dataset

# %%
csvs[0][0]
# Out:
# 'dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment'

# %%
csvs[0][1]
# Out:
#       created_at  favorite_count  \
# 32666   2/1/2021             154
# 29639   2/1/2021              17
# 29613   2/1/2021               3
# 39638   2/1/2021            3496
# 32660   2/1/2021               0
# ...          ...             ...
# 1309   6/12/2023               3
# 1307   6/12/2023               0
# 1306   6/12/2023               0
# 1305   6/12/2023              56
# 1312   6/12/2023               0
#
#                                                full_text  reply_count  \
# 32666  #privacy is a human right. learn how to make y...           18
# 29639  overall btc trading volume has increased, but ...            1
# 29613  on average, the return distribution of btc ske...            0
# 39638  i sent some! https://t.co/mfyrz35zjf\n\nyou sh...          731
# 32660  rt @reg_mati: la privacidad es un derecho huma...            0
# ...                                                  ...          ...
# 1309   booomð¥\n\nour #ai bot/indicator crushes ano...            5
# 1307   rt @crypto_crib_: the deadline is today for bi...            0
# 1306   rt @crypto_crib_: ð²chinese bank boci issues...            0
# 1305       bitcoin, not crypto.\n\ncrypto, not security.           16
# 1312   rt @crypto_crib_: jpmorgan calls for "comprehe...            0
#
#        retweet_count                                         clean_text  \
# 32666             23  privacy human right learn make bitcoin transac...
# 29639              5  overall btc trading volume increased average t...
# 29613              1  average return distribution btc skews slightly...
# 39638            686  sent httpstcomfyrz35zjf givedirectly great wor...
# 32660              7  rt reg_mati la privacidad e un derecho humano ...
# ...              ...                                                ...
# 1309               0  booomð ai botindicator crush another lina trad...
# 1307               4  rt crypto_crib_ deadline today binance binance...
# 1306               8  rt crypto_crib_ ð²chinese bank boci issue coun...
# 1305               7                     bitcoin crypto crypto security
# 1312               8  rt crypto_crib_ jpmorgan call comprehensive fr...
#
#        importance_coefficient  importance_coefficient_normalized  \
# 32666                   340.0                           0.000588
# 29639                    39.5                           0.000068
# 29613                     7.0                           0.000012
# 39638                  8043.5                           0.013905
# 32660                     7.0                           0.000012
# ...                       ...                                ...
# 1309                      8.5                           0.000015
# 1307                      4.0                           0.000007
# 1306                      8.0                           0.000014
# 1305                    127.0                           0.000220
# 1312                      8.0                           0.000014
#
#                             new_coins  \
# 32666                       (bitcoin)
# 29639                           (btc)
# 29613                           (btc)
# 39638                          (doge)
# 32660                       (bitcoin)
# ...                               ...
# 1309   (doge,hbar,inj,usdt,matic,ftm)
# 1307                (binance,request)
# 1306                       (ethereum)
# 1305                        (bitcoin)
# 1312                    (binance,amp)
#
#                                                   scores  compound  \
# 32666  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000
# 29639  {'neg': 0.0, 'neu': 0.95, 'pos': 0.05, 'compou...    0.2124
# 29613  {'neg': 0.053, 'neu': 0.769, 'pos': 0.177, 'co...    0.7010
# 39638  {'neg': 0.06, 'neu': 0.856, 'pos': 0.084, 'com...    0.2225
# 32660  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000
# ...                                                  ...       ...
# 1309   {'neg': 0.092, 'neu': 0.75, 'pos': 0.158, 'com...    0.6239
# 1307   {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000
# 1306   {'neg': 0.0, 'neu': 0.844, 'pos': 0.156, 'comp...    0.3400
# 1305   {'neg': 0.289, 'neu': 0.711, 'pos': 0.0, 'comp...   -0.2584
# 1312   {'neg': 0.084, 'neu': 0.752, 'pos': 0.164, 'co...    0.2023
#
#       sentiment_type
# 32666        NEUTRAL
# 29639       POSITIVE
# 29613       POSITIVE
# 39638       POSITIVE
# 32660        NEUTRAL
# ...              ...
# 1309        POSITIVE
# 1307         NEUTRAL
# 1306        POSITIVE
# 1305        NEGATIVE
# 1312        POSITIVE
#
# [16512 rows x 12 columns]

# %%
csvs[0][1].dtypes
# Out:
# created_at                            object
# favorite_count                         int64
# full_text                             object
# reply_count                            int64
# retweet_count                          int64
# clean_text                            object
# importance_coefficient               float64
# importance_coefficient_normalized    float64
# new_coins                             object
# scores                                object
# compound                             float64
# sentiment_type                        object
# dtype: object

# %%
csvs[0][1]['new_coins'] = csvs[0][1]['new_coins'].apply(lambda x: ", ".join(re.sub(r'[\(\)]*', '', x).split(',')))
csvs[0][1]['new_coins']
# Out:
# 32666                              bitcoin
# 29639                                  btc
# 29613                                  btc
# 39638                                 doge
# 32660                              bitcoin
#                        ...
# 1309     doge, hbar, inj, usdt, matic, ftm
# 1307                      binance, request
# 1306                              ethereum
# 1305                               bitcoin
# 1312                          binance, amp
# Name: new_coins, Length: 16512, dtype: object

# %%
def cohere(row):
    """
    restructures the meaningless number values in the dataframe
    and forms a coherent and meaningful sentence out of it

    args:
        row - row of a dataframe
    """

    date = row['created_at']
    text = row['clean_text']
    fave_count = row['favorite_count']
    reply_count = row['reply_count']
    retweet_count = row['retweet_count']
    importance_coefficient = row['importance_coefficient']
    new_coins = row['new_coins']
    sentiment = row['sentiment_type'].lower() if not pd.isna(row['sentiment_type']) else 'none'

    message = f'the tweet: "{text}" had a fave count of {fave_count}, a reply count of {reply_count}, and a retweet count of {retweet_count}. Used new coins like {new_coins}. The tweet had an importance coefficient of {importance_coefficient}. Overall the sentiment was {sentiment}'

    return message

# %% [markdown]
# for first dataframe maybe relevant information for the agent maybe the reply count, retweet count, clean text, importance coefficient normalized, new coins, sentiment time
#
# and maybe lay it out again in rows in such a manner that it makes somehow a coherent input
# text: privacy human right learn make bitcoin transac..., reply_count: 18, retweet_count: 23, new_coins: bitcoin, sentiment: neutral
#
# or even (if I could pull it of):
# privacy human right learn make bitcoin transac... has reply count of 18, has retweet count of 23, new coins it uses bitcoin, and a sentiment of neutral

# %%
csvs[0][1]['message'] = csvs[0][1].apply(cohere, axis=1)
csvs[0][1]['message']
# Out:
# 32666    the tweet: "privacy human right learn make bit...
# 29639    the tweet: "overall btc trading volume increas...
# 29613    the tweet: "average return distribution btc sk...
# 39638    the tweet: "sent httpstcomfyrz35zjf givedirect...
# 32660    the tweet: "rt reg_mati la privacidad e un der...
#                                ...
# 1309     the tweet: "booomð ai botindicator crush anoth...
# 1307     the tweet: "rt crypto_crib_ deadline today bin...
# 1306     the tweet: "rt crypto_crib_ ð²chinese bank boc...
# 1305     the tweet: "bitcoin crypto crypto security" ha...
# 1312     the tweet: "rt crypto_crib_ jpmorgan call comp...
# Name: message, Length: 16512, dtype: object

# %%
csvs[0][1]['message'].iloc[0]
# Out:
# 'the tweet: "privacy human right learn make bitcoin transaction private clip httpstcofnadsxffcu httpstconznajw8g2m" had a fave count of 154, a reply count of 18, and a retweet count of 23. Used new coins like bitcoin. The tweet had an importance coefficient of 340.0. Overall the sentiment was neutral'

# %% [markdown]
# # Second .csv dataset

# %%
csvs[1][0]
# Out:
# 'eth_selected_with_sentiment_2023_01_02_2023_06_12'

# %%
csvs[1][1]
# Out:
#           date  close  high   low  open       volume  adjclose   changes  \
# 1     1/2/2023   1220  1195  1201  1215   3765758498      1215  positive
# 2     1/3/2023   1219  1207  1215  1215   3392972131      1215  negative
# 3     1/4/2023   1265  1213  1215  1257   6404416893      1257  positive
# 4     1/5/2023   1259  1245  1256  1250   4001786456      1250  negative
# 5     1/6/2023   1273  1241  1250  1269   4977252792      1269  positive
# ..         ...    ...   ...   ...   ...          ...       ...       ...
# 158   6/8/2023   1861  1830  1833  1846   4536041931      1846  negative
# 159   6/9/2023   1855  1829  1846  1840   4610831509      1840  negative
# 160  6/10/2023   1845  1721  1840  1752  10788500406      1752  negative
# 161  6/11/2023   1777  1741  1753  1753   4559112981      1753  negative
# 162  6/12/2023   1758  1723  1753  1743   6031384958      1743  negative
#
#      compound sentiment_type
# 1      0.6908       POSITIVE
# 2      0.0000        NEUTRAL
# 3     -0.2878       NEGATIVE
# 4     -0.2732       NEGATIVE
# 5      0.4588       POSITIVE
# ..        ...            ...
# 158    0.7859       POSITIVE
# 159    0.9168       POSITIVE
# 160    0.7643       POSITIVE
# 161    0.9059       POSITIVE
# 162    0.8513       POSITIVE
#
# [162 rows x 10 columns]

# %% [markdown]
# # here we can make each row into a coherent sentence the agent can understand during finetuning i.e.
# "January 2 2023 had a closing price of 1220, opening price of 1215, highest price was 1195, lowest price was 1201, volume of 3765758498, and an overall positive sentiment"

# %%
type(csvs[1][1]['date'].iloc[0])
# Out:
# str

# %%
csvs[1][1]['date'] = csvs[1][1]['date'].apply(lambda date: dt.datetime.strptime(date, '%m/%d/%Y').strftime('%B %#d %Y'))
csvs[1][1]['date']
# Out:
# 1      January 2 2023
# 2      January 3 2023
# 3      January 4 2023
# 4      January 5 2023
# 5      January 6 2023
#             ...
# 158       June 8 2023
# 159       June 9 2023
# 160      June 10 2023
# 161      June 11 2023
# 162      June 12 2023
# Name: date, Length: 162, dtype: object

# %%
csvs[1][1]['sentiment_type'].iloc[0].lower()
# Out:
# 'positive'

# %%
def cohere(row):
    """
    restructures the meaningless number values in the dataframe
    and forms a coherent and meaningful sentence out of it

    args:
        row - row of a dataframe
    """

    date = row['date']
    close = row['close']
    open = row['open']
    high = row['high']
    low = row['low']
    adj_close = row['adjclose']
    vol = row['volume']
    changes = row['changes']
    sentiment = row['sentiment_type'].lower() if not pd.isna(row['sentiment_type']) else 'none'

    message = f'{date} had a closing price of {close} and an opening price of {open}. The highest price was {high}, lowest price was {low}, and the adjacent closing price was {adj_close} with a volume of {vol}. Changes were {changes} and overall the sentiment was {sentiment}'

    return message

# %%
csvs[1][1]['message'] = csvs[1][1].apply(cohere, axis=1)
csvs[1][1]['message']
# Out:
# 1      January 2 2023 had a closing price of 1220 and...
# 2      January 3 2023 had a closing price of 1219 and...
# 3      January 4 2023 had a closing price of 1265 and...
# 4      January 5 2023 had a closing price of 1259 and...
# 5      January 6 2023 had a closing price of 1273 and...
#                              ...
# 158    June 8 2023 had a closing price of 1861 and an...
# 159    June 9 2023 had a closing price of 1855 and an...
# 160    June 10 2023 had a closing price of 1845 and a...
# 161    June 11 2023 had a closing price of 1777 and a...
# 162    June 12 2023 had a closing price of 1758 and a...
# Name: message, Length: 162, dtype: object

# %%
csvs[1][1]['message'].iloc[0]
# Out:
# 'January 2 2023 had a closing price of 1220 and an opening price of 1215. The highest price was 1195, lowest price was 1201, and the adjacent closing price was 1215 with a volume of 3765758498. Changes were positive and overall the sentiment was positive'

# %% [markdown]
# # Fourth .csv file

# %%
csvs[2][0]
# Out:
# 'gotchi_wearable_sets'

# %%
csvs[2][1]
# Out:
#                                                Set Bonus  \
# Set Name
# Aarcher                                   BRS +1, AGG -1
# Aastronaut                                BRS +1, SPK +1
# Aave Hero                                 BRS +1, SPK +1
# ETH Maxi                                  BRS +1, BRN -1
# Farmer                                    BRS +1, NRG -1
# ...                                                  ...
# Jacob Maarley             BRS +8, NRG +1, SPK +3, BRN -1
# Master Creatooor          BRS +8, NRG +1, SPK -2, BRN -2
# ROFL Tamer                        BRS +8, NRG -3, BRN -2
# Shogungotchi      BRS +8, NRG -1, AGG +1, SPK +2, BRN -1
# VRF Lord                          BRS +8, NRG +3, BRN +2
#
#                                               Total Bonuses  Total  \
# Set Name
# Aarcher                              BRS +4, NRG -1, AGG -3      8
# Aastronaut                                   BRS +4, SPK +4      8
# Aave Hero                                    BRS +4, SPK +4      8
# ETH Maxi                                     BRS +4, BRN -4      8
# Farmer                       BRS +4, NRG -2, AGG +1, BRN -1      8
# ...                                                     ...    ...
# Jacob Maarley             BRS +208, NRG +17, SPK +3, BRN -9    237
# Master Creatooor         BRS +208, NRG +5, SPK -11, BRN -13    237
# ROFL Tamer                       BRS +208, NRG -16, BRN -13    237
# Shogungotchi      BRS +208, NRG -4, AGG +9, SPK +12, BRN -4    237
# VRF Lord                         BRS +208, NRG +15, BRN +14    237
#
#                                                           Wearables
# Set Name
# Aarcher           Brunette Ponytail (Common; BRS +1, AGG -1); Le...
# Aastronaut        Aastronaut Helmet (Common; BRS +1, SPK +1); Aa...
# Aave Hero         Aave Hero Mask (Common; BRS +1, SPK +1); Aave ...
# ETH Maxi          ETH Logo Glasses (Common; BRS +1, BRN -1); ETH...
# Farmer            Straw Hat (Common; BRS +1, NRG -1); Farmer Jea...
# ...                                                             ...
# Jacob Maarley     Heavenly Robes (Godlike; BRS +50, NRG +4, BRN ...
# Master Creatooor  Staff of Creation (Godlike; BRS +50, SPK -3, B...
# ROFL Tamer        All-Seeing Eyes (Godlike; BRS +50, NRG -6); Go...
# Shogungotchi      Godlike Rofl (Godlike; BRS +50, NRG -3, BRN -3...
# VRF Lord          Galaxy Brain (Godlike; BRS +50, BRN +6); Link ...
#
# [166 rows x 4 columns]

# %%
csvs[2][1]['Wearables'].iloc[0]
# Out:
# 'Brunette Ponytail (Common; BRS +1, AGG -1); Leather Tunic (Common; BRS +1, NRG -1); Bow and Arrow (Common; BRS +1, AGG -1)'

# %%
csvs[2][1]['Wearables'].iloc[-1]
# Out:
# 'Galaxy Brain (Godlike; BRS +50, BRN +6); Link Cube (Godlike; BRS +50, BRN +6); Uranium Rod (Godlike; BRS +50, NRG +6); Block Scanners (Godlike; BRS +50, NRG +6)'

# %% [markdown]
# #### `<name of the wearable> (<rank of the werable>; <some stat it has>, <some stat it has>, ..., <another stat it has>)`

# %%
csvs[2][1].reset_index(inplace=True)
csvs[2][1]
# Out:
#              Set Name                               Set Bonus  \
# 0             Aarcher                          BRS +1, AGG -1
# 1          Aastronaut                          BRS +1, SPK +1
# 2           Aave Hero                          BRS +1, SPK +1
# 3            ETH Maxi                          BRS +1, BRN -1
# 4              Farmer                          BRS +1, NRG -1
# ..                ...                                     ...
# 161     Jacob Maarley          BRS +8, NRG +1, SPK +3, BRN -1
# 162  Master Creatooor          BRS +8, NRG +1, SPK -2, BRN -2
# 163        ROFL Tamer                  BRS +8, NRG -3, BRN -2
# 164      Shogungotchi  BRS +8, NRG -1, AGG +1, SPK +2, BRN -1
# 165          VRF Lord                  BRS +8, NRG +3, BRN +2
#
#                                  Total Bonuses  Total  \
# 0                       BRS +4, NRG -1, AGG -3      8
# 1                               BRS +4, SPK +4      8
# 2                               BRS +4, SPK +4      8
# 3                               BRS +4, BRN -4      8
# 4               BRS +4, NRG -2, AGG +1, BRN -1      8
# ..                                         ...    ...
# 161          BRS +208, NRG +17, SPK +3, BRN -9    237
# 162         BRS +208, NRG +5, SPK -11, BRN -13    237
# 163                 BRS +208, NRG -16, BRN -13    237
# 164  BRS +208, NRG -4, AGG +9, SPK +12, BRN -4    237
# 165                 BRS +208, NRG +15, BRN +14    237
#
#                                              Wearables
# 0    Brunette Ponytail (Common; BRS +1, AGG -1); Le...
# 1    Aastronaut Helmet (Common; BRS +1, SPK +1); Aa...
# 2    Aave Hero Mask (Common; BRS +1, SPK +1); Aave ...
# 3    ETH Logo Glasses (Common; BRS +1, BRN -1); ETH...
# 4    Straw Hat (Common; BRS +1, NRG -1); Farmer Jea...
# ..                                                 ...
# 161  Heavenly Robes (Godlike; BRS +50, NRG +4, BRN ...
# 162  Staff of Creation (Godlike; BRS +50, SPK -3, B...
# 163  All-Seeing Eyes (Godlike; BRS +50, NRG -6); Go...
# 164  Godlike Rofl (Godlike; BRS +50, NRG -3, BRN -3...
# 165  Galaxy Brain (Godlike; BRS +50, BRN +6); Link ...
#
# [166 rows x 5 columns]

# %%
def cohere_wearables(row):
    """
    restructures the meaningless number values in the dataframe
    and forms a coherent and meaningful sentence out of it

    args:
        row - row of a dataframe
    """

    set_name = row['Set Name']
    set_bonus = row['Set Bonus']
    total_bonus = row['Total Bonuses']
    total = row['Total']
    wearables = row['Wearables']

    message = f'Character {set_name} had a set bonus of {set_bonus} and a total bonus of {total_bonus}. Total was {total}. Wearables of {set_name} are {wearables}'

    return message

# %%
csvs[2][1]['message'] = csvs[2][1].apply(cohere_wearables, axis=1)
csvs[2][1]['message']
# Out:
# 0      Character Aarcher had a set bonus of BRS +1, A...
# 1      Character Aastronaut had a set bonus of BRS +1...
# 2      Character Aave Hero had a set bonus of BRS +1,...
# 3      Character ETH Maxi had a set bonus of BRS +1, ...
# 4      Character Farmer had a set bonus of BRS +1, NR...
#                              ...
# 161    Character Jacob Maarley had a set bonus of BRS...
# 162    Character Master Creatooor had a set bonus of ...
# 163    Character ROFL Tamer had a set bonus of BRS +8...
# 164    Character Shogungotchi had a set bonus of BRS ...
# 165    Character VRF Lord had a set bonus of BRS +8, ...
# Name: message, Length: 166, dtype: object

# %%
csvs[2][1]['message'].iloc[0]
# Out:
# 'Character Aarcher had a set bonus of BRS +1, AGG -1 and a total bonus of BRS +4, NRG -1, AGG -3. Total was 8. Wearables of Aarcher are Brunette Ponytail (Common; BRS +1, AGG -1); Leather Tunic (Common; BRS +1, NRG -1); Bow and Arrow (Common; BRS +1, AGG -1)'

# %% [markdown]
# # 5th .csv file

# %%
def normalize_and_clean(text):
    text = str(text)

    # standardization and normalization
    text = re.sub(r" US ", " american ", text)
    text = text.lower()
    text = re.sub(r"’", "'", text)
    text = re.sub(r"i'm", "i am ", text)

    text = re.sub(r"don't", "do not ", text)
    text = re.sub(r"didn't", "did not ", text)
    text = re.sub(r"aren't", "are not ", text)
    text = re.sub(r"weren't", "were not", text)
    text = re.sub(r"isn't", "is not ", text)
    text = re.sub(r"can't", "cannot ", text)
    text = re.sub(r"doesn't", "does not ", text)
    text = re.sub(r"shouldn't", "should not ", text)
    text = re.sub(r"couldn't", "could not ", text)
    text = re.sub(r"mustn't", "must not ", text)
    text = re.sub(r"wouldn't", "would not ", text)

    text = re.sub(r"what's", "what is ", text)
    text = re.sub(r"that's", "that is ", text)
    text = re.sub(r"he's", "he is ", text)
    text = re.sub(r"she's", "she is ", text)
    text = re.sub(r"it's", "it is ", text)
    text = re.sub(r"that's", "that is ", text)

    text = re.sub(r"could've", "could have ", text)
    text = re.sub(r"would've", "would have ", text)
    text = re.sub(r"should've", "should have ", text)
    text = re.sub(r"must've", "must have ", text)
    text = re.sub(r"i've", "i have ", text)
    text = re.sub(r"we've", "we have ", text)

    text = re.sub(r"you're", "you are ", text)
    text = re.sub(r"they're", "they are ", text)
    text = re.sub(r"we're", "we are ", text)

    text = re.sub(r"you'd", "you would ", text)
    text = re.sub(r"they'd", "they would ", text)
    text = re.sub(r"she'd", "she would ", text)
    text = re.sub(r"he'd", "he would ", text)
    text = re.sub(r"it'd", "it would ", text)
    text = re.sub(r"we'd", "we would ", text)

    text = re.sub(r"you'll", "you will ", text)
    text = re.sub(r"they'll", "they will ", text)
    text = re.sub(r"she'll", "she will ", text)
    text = re.sub(r"he'll", "he will ", text)
    text = re.sub(r"it'll", "it will ", text)
    text = re.sub(r"we'll", "we will ", text)

    text = re.sub(r"\n't", " not ", text)
    text = re.sub(r"\'s", " ", text) 
    text = re.sub(r"\'ve", " have ", text)
    text = re.sub(r"\'re", " are ", text)
    text = re.sub(r"\'d", " would ", text)
    text = re.sub(r"\'ll", " will ", text) 
    
    text = re.sub(r"%", " percent ", text)
    text = re.sub(r"!", " ! ", text)
    text = re.sub(r"\/", " ", text)
    text = re.sub(r"\^", " ^ ", text)
    text = re.sub(r"\+", " + ", text)
    text = re.sub(r"\-", " - ", text)
    text = re.sub(r"\=", " = ", text)
    text = re.sub(r"'", " ", text)
    text = re.sub(r"(\d+)(k)", r"\g<1>000", text)
    text = re.sub(r" u s ", " american ", text)
    text = re.sub(r"\0s", "0", text)
    text = re.sub(r" 9 11 ", "911", text)
    text = re.sub(r"e - mail", "email", text)
    text = re.sub(r"j k", "jk", text)

    # cleaning
    # remove a url in the content
    text = re.sub(r"(?i)\b((?:https?:(?:/{1,3}|[a-z0-9%])|[a-z0-9.\-]+[.](?:com|net|org|edu|gov|mil|aero|asia|biz|cat|coop|info|int|jobs|mobi|museum|name|post|pro|tel|travel|xxx|ac|ad|ae|af|ag|ai|al|am|an|ao|aq|ar|as|at|au|aw|ax|az|ba|bb|bd|be|bf|bg|bh|bi|bj|bm|bn|bo|br|bs|bt|bv|bw|by|bz|ca|cc|cd|cf|cg|ch|ci|ck|cl|cm|cn|co|cr|cs|cu|cv|cx|cy|cz|dd|de|dj|dk|dm|do|dz|ec|ee|eg|eh|er|es|et|eu|fi|fj|fk|fm|fo|fr|ga|gb|gd|ge|gf|gg|gh|gi|gl|gm|gn|gp|gq|gr|gs|gt|gu|gw|gy|hk|hm|hn|hr|ht|hu|id|ie|il|im|in|io|iq|ir|is|it|je|jm|jo|jp|ke|kg|kh|ki|km|kn|kp|kr|kw|ky|kz|la|lb|lc|li|lk|lr|ls|lt|lu|lv|ly|ma|mc|md|me|mg|mh|mk|ml|mm|mn|mo|mp|mq|mr|ms|mt|mu|mv|mw|mx|my|mz|na|nc|ne|nf|ng|ni|nl|no|np|nr|nu|nz|om|pa|pe|pf|pg|ph|pk|pl|pm|pn|pr|ps|pt|pw|py|qa|re|ro|rs|ru|rw|sa|sb|sc|sd|se|sg|sh|si|sj|Ja|sk|sl|sm|sn|so|sr|ss|st|su|sv|sx|sy|sz|tc|td|tf|tg|th|tj|tk|tl|tm|tn|to|tp|tr|tt|tv|tw|tz|ua|ug|uk|us|uy|uz|va|vc|ve|vg|vi|vn|vu|wf|ws|ye|yt|yu|za|zm|zw)/)(?:[^\s()<>{}\[\]]+|\([^\s()]*?\([^\s()]+\)[^\s()]*?\)|\([^\s]+?\))+(?:\([^\s()]*?\([^\s()]+\)[^\s()]*?\)|\([^\s]+?\)|[^\s`!()\[\]{};:'\".,<>?«»“”‘’])|(?:(?<!@)[a-z0-9]+(?:[.\-][a-z0-9]+)*[.](?:com|net|org|edu|gov|mil|aero|asia|biz|cat|coop|info|int|jobs|mobi|museum|name|post|pro|tel|travel|xxx|ac|ad|ae|af|ag|ai|al|am|an|ao|aq|ar|as|at|au|aw|ax|az|ba|bb|bd|be|bf|bg|bh|bi|bj|bm|bn|bo|br|bs|bt|bv|bw|by|bz|ca|cc|cd|cf|cg|ch|ci|ck|cl|cm|cn|co|cr|cs|cu|cv|cx|cy|cz|dd|de|dj|dk|dm|do|dz|ec|ee|eg|eh|er|es|et|eu|fi|fj|fk|fm|fo|fr|ga|gb|gd|ge|gf|gg|gh|gi|gl|gm|gn|gp|gq|gr|gs|gt|gu|gw|gy|hk|hm|hn|hr|ht|hu|id|ie|il|im|in|io|iq|ir|is|it|je|jm|jo|jp|ke|kg|kh|ki|km|kn|kp|kr|kw|ky|kz|la|lb|lc|li|lk|lr|ls|lt|lu|lv|ly|ma|mc|md|me|mg|mh|mk|ml|mm|mn|mo|mp|mq|mr|ms|mt|mu|mv|mw|mx|my|mz|na|nc|ne|nf|ng|ni|nl|no|np|nr|nu|nz|om|pa|pe|pf|pg|ph|pk|pl|pm|pn|pr|ps|pt|pw|py|qa|re|ro|rs|ru|rw|sa|sb|sc|sd|se|sg|sh|si|sj|Ja|sk|sl|sm|sn|so|sr|ss|st|su|sv|sx|sy|sz|tc|td|tf|tg|th|tj|tk|tl|tm|tn|to|tp|tr|tt|tv|tw|tz|ua|ug|uk|us|uy|uz|va|vc|ve|vg|vi|vn|vu|wf|ws|ye|yt|yu|za|zm|zw)\b/?(?!@)))", " ", text)

    # anything that doesn't match the pattern is a obscure 
    # special character. Remove it
    text = re.sub(r"[^A-Za-z0-9^,!.\/'+-=]", " ", text)

    # remove any number that exeeds more than 4 digits
    text = re.sub(r"[0-9]{5,}", " ", text)
    text = re.sub(r",", " ", text)

    # removes any colon preceded by an https or http
    text = re.sub(r"(?<=https):", " ", text)
    text = re.sub(r"https", " ", text)
    
    # duplicate whitespaces will be condensed into one
    text = re.sub(r"\s{2,}", " ", text)
    
    return text

# %%
scraped_proposals_df = pd.read_csv(f'{input_dir}/scraped_proposals.csv', header=None)
scraped_proposals_df
# Out:
#                                                      0                 1  \
# 0    Aavegotchi x Sandbox Experience - Expansion & ...             Thrax
# 1              Gas Fee Reimbursement for DAO Directors     0x50f4...D764
# 2    AaveGotchi DAO Liquidity Incentives Proposal (...           ApeAdam
# 3                          Gotchi Battler V1.5 funding     0x10B9...229b
# 4              Gas Fee Reimbursement for DAO Directors     0x50f4...D764
# ..                                                 ...               ...
# 534                    Establishing an ETH Sell Ladder      drwagmi.lens
# 535                 [AGIP 109] Rarity Farming Season 8             Thrax
# 536  [AGIP 111] Staking 350 ETH with Lido and Acqui...             Thrax
# 537                Rarity Farming Season 8 (Re-repost)  hardkornate.lens
# 538                                              Title            Author
#
#            2                                                  3
# 0    10m ago  Author: The GotchiFArmy [GFA] The Gotchi FArmy...
# 1    10m ago  Author: Maxicrouton (13700)\nQuorum Requiremen...
# 2    10m ago  Author: Juliaan, Bobaa, AAdam and\nGotchiID:  ...
# 3    10m ago  Authors: Immaterial\nGotchiIDs: 13681\nQuorum ...
# 4    10m ago  Author: Maxicrouton (13700)\nQuorum Requiremen...
# ..       ...                                                ...
# 534   9m ago  Author: Dr. Wagmi (16635)\nQuorum Requirement:...
# 535   9m ago  Author: HARDKOR\nGotchiID: 16553\nQuorum requi...
# 536   9m ago  Author: Dr. Wagmi (16635)\nQuorum Requirement:...
# 537   9m ago  Author: HARDKOR\nGotchiID: 16553\nQuorum requi...
# 538     Date                                            Content
#
# [539 rows x 4 columns]

# %%
# scraped_proposals_df[0]

# %%
csvs[3][1]
# Out:
#                                                  title            author  \
# 0    Aavegotchi x Sandbox Experience - Expansion & ...             Thrax
# 1              Gas Fee Reimbursement for DAO Directors     0x50f4...D764
# 2    AaveGotchi DAO Liquidity Incentives Proposal (...           ApeAdam
# 3                          Gotchi Battler V1.5 funding     0x10B9...229b
# 4              Gas Fee Reimbursement for DAO Directors     0x50f4...D764
# ..                                                 ...               ...
# 533            RF Season 8 changes to BRS Rewards Pool     0x89B1...7008
# 534                    Establishing an ETH Sell Ladder      drwagmi.lens
# 535                 [AGIP 109] Rarity Farming Season 8             Thrax
# 536  [AGIP 111] Staking 350 ETH with Lido and Acqui...             Thrax
# 537                Rarity Farming Season 8 (Re-repost)  hardkornate.lens
#
#         date                                            content
# 0    10m ago  Author: The GotchiFArmy [GFA] The Gotchi FArmy...
# 1    10m ago  Author: Maxicrouton (13700)\nQuorum Requiremen...
# 2    10m ago  Author: Juliaan, Bobaa, AAdam and\nGotchiID:  ...
# 3    10m ago  Authors: Immaterial\nGotchiIDs: 13681\nQuorum ...
# 4    10m ago  Author: Maxicrouton (13700)\nQuorum Requiremen...
# ..       ...                                                ...
# 533   9m ago  Author: Bearded\nGotchi ID: 13536\nIn Rarity F...
# 534   9m ago  Author: Dr. Wagmi (16635)\nQuorum Requirement:...
# 535   9m ago  Author: HARDKOR\nGotchiID: 16553\nQuorum requi...
# 536   9m ago  Author: Dr. Wagmi (16635)\nQuorum Requirement:...
# 537   9m ago  Author: HARDKOR\nGotchiID: 16553\nQuorum requi...
#
# [538 rows x 4 columns]

# %%
csvs[3][1]['content'].iloc[0]
# Out:
# 'Author: The GotchiFArmy [GFA] The Gotchi FArmy#6696\nGotchi ID: 8050\nQuorum requirement: 20% (9M)\nVote duration: 14 days\nDiscourse thread:\nhttps://discord.com/channels/732491344970383370/1188051581950759034\nThe GFA Studio journey to create the first Aavegotchi experience in the Sandbox was delivered early November 2023.\nhttps://x.com/aavegotchi/status/1721528506826498384?s=20\nWe created a Google Form we submitted to the community during a hangout. We received limited but valuable information about the experience. It’s important to note it reflects the vision of Aavegotchi Native community member:\nhttps://docs.google.com/forms/d/e/1FAIpQLSdOKbJm8oLUzo-SgiYIY2rhwMOgb56AH9wiwL9AbYm0lG3SjA/viewform?usp=sf_link\nAbout TheSandbox Team and community, we got tremendous returns. TheSandbox was shocked by the richness of Aavegotchi ecosystem and Lore applied in their voxeled environnement.\nThis project scope of work Supported by the DAO was established as follow :\n--\n1) Creation of a Sandbox Single player experience providing :\nEducational content about Aavegotchi\nAavegotchi Lore exploration\nCross universe Aavegotchi Artistic creation\n2) Second: One Multiplayer experience\nBêta test of TheSandbox 0.9 Gamemaker Version Multiplayer features\nTo be delivered early 2024\n3) Organization of incentives around the project\n4) Aavegotchi x The Sandbox AMA\nGFA decided to go further by achieving unscheduled/ out of scope milestones:\nForge an official partnership between Aavegotchi and TheSandbox\nBridge of gotchis as Official TheSandbox Aavegotchi Aavatar Collection\nNegotiations to gain access to top tier (VIP) partner communication by TheSandbox on social media concerning the release\nCreation of 3 full OG equipment sets (Sandbox Marketplace)\nIRL event Hosted in TheSandbox Office in Paris\nThe Enigma Odyssey (300+ contestants)\nRIPPLES OF THE GOTCHIVERSE Graphic Novel (To be delivered soon)\nEntrusted by the Licence IP signed with Aavegotchi, GFA community made the choice to lean over the revenue share repartition even if the initial proposal only mentioned 10% Royalty to Pixelcraft Studio.\nDifferent types of revenues are generated through this project : Direct and indirect returns.\nAbout Direct financial returns, here is the repartition GFA decided to apply :\nSo far, around 13500 SAND tokens sales has been generated. DAO Share was delivered in December (7 425 SAND). Multiplayer Experience is empowered to generate more of those.\nAbout Indirect revenues, please find below the stats of the single experience release engagement :\n1) TheSandbox\nSocial engagement\nGood overall engagement on sandbox announcement tweets\nGood visibility of Aavegotchi community to TheSandbox userbase\nGood average in-game numbers (KYC Accounts)\n2) Aavegotchi\nSome of the best Aavegotchi tweets of 2023 (around 90k + views)\nForge an alliance with top Web3 brend (TheSandbox)\nWith the great impact this initiative had, it’s now official, as discussed during the last Hangout and AMA, Aavegotchi made the choice to get some lands (1 Estate 3x3) in TheSandbox. It Gives the possibility to Selfpublish Aavegotchi experiences beeing playable without interruption.\nHere is the location of Aavegotchi 3x3 Estate owned by Pixelcraft :\nhttps://www.sandbox.game/en/map/?lat=82&lng=-158&zoom=4&x=-158&y=82\nProposal of Funding\nThis proposal of funding is to empower GFA to operate Pixelcraft lands and partnership for a limited and renewable 6 months duration with as follows duties :\nManagement of Project and Coordination\nPartnership Management\nMaintain channel of discussion with Sandbox officers like Sebastien Borget\nUpgrades of Aavegotchi avatar collection in Sandbox\nAavegotchi Assets collection utility and highlight in game\nExperience Updates\nManagement of Aavegotchi Parcels in Sandbox + Collect & analysis of InGame and Traffic datas with TheSandbox\nUpgrades and modifications of experiences due to Sandbox New GameMaker and GameClient release (Forecasted ...

# %%
csvs[3][1]['title'] = csvs[3][1]['title'].apply(normalize_and_clean)
csvs[3][1]['title']
# Out:
# 0      aavegotchi x sandbox experience - expansion ma...
# 1                gas fee reimbursement for dao directors
# 2      aavegotchi dao liquidity incentives proposal a...
# 3                            gotchi battler v1.5 funding
# 4                gas fee reimbursement for dao directors
#                              ...
# 533              rf season 8 changes to brs rewards pool
# 534                      establishing an eth sell ladder
# 535                     agip 109 rarity farming season 8
# 536     agip 111 staking 350 eth with lido and acquir...
# 537                 rarity farming season 8 re - repost
# Name: title, Length: 538, dtype: object

# %%
csvs[3][1]['author'] = csvs[3][1]['author'].apply(normalize_and_clean)
csvs[3][1]['author']
# Out:
# 0                 thrax
# 1         0x50f4...d764
# 2               apeadam
# 3         0x10b9...229b
# 4         0x50f4...d764
#              ...
# 533       0x89b1...7008
# 534        drwagmi.lens
# 535               thrax
# 536               thrax
# 537    hardkornate.lens
# Name: author, Length: 538, dtype: object

# %%
csvs[3][1]['content'] = csvs[3][1]['content'].apply(normalize_and_clean)
csvs[3][1]['content']
# Out:
# 0      author: the gotchifarmy gfa the gotchi farmy 6...
# 1      author: maxicrouton quorum requirement: 20 per...
# 2      author: juliaan bobaa aadam and gotchiid: quor...
# 3      authors: immaterial gotchiids: quorum requirem...
# 4      author: maxicrouton quorum requirement: 20 per...
#                              ...
# 533    author: bearded gotchi id: in rarity farming s...
# 534    author: dr. wagmi quorum requirement: 20 perce...
# 535    author: hardkor gotchiid: quorum requirement: ...
# 536    author: dr. wagmi quorum requirement: 20 perce...
# 537    author: hardkor gotchiid: quorum requirement: ...
# Name: content, Length: 538, dtype: object

# %%
csvs[3][1]['content'].iloc[0]
# Out:
# 'author: the gotchifarmy gfa the gotchi farmy 6696 gotchi id: 8050 quorum requirement: 20 percent 9m vote duration: 14 days discourse thread: channels the gfa studio journey to create the first aavegotchi experience in the sandbox was delivered early november 2023. aavegotchi status s = 20 we created a google form we submitted to the community during a hangout. we received limited but valuable information about the experience. it is important to note it reflects the vision of aavegotchi native community member: forms d e 1faipqlsdokbjm8oluzo - sgiyiy2rhwmogb56ah9wiwl9abym0lg3sja viewform usp = sf link about thesandbox team and community we got tremendous returns. thesandbox was shocked by the richness of aavegotchi ecosystem and lore applied in their voxeled environnement. this project scope of work supported by the dao was established as follow : - - 1 creation of a sandbox single player experience providing : educational content about aavegotchi aavegotchi lore exploration cross universe aavegotchi artistic creation 2 second: one multiplayer experience b ta test of thesandbox 0.9 gamemaker version multiplayer features to be delivered early 2024 3 organization of incentives around the project 4 aavegotchi x the sandbox ama gfa decided to go further by achieving unscheduled out of scope milestones: forge an official partnership between aavegotchi and thesandbox bridge of gotchis as official thesandbox aavegotchi aavatar collection negotiations to gain access to top tier vip partner communication by thesandbox on social media concerning the release creation of 3 full og equipment sets sandbox marketplace irl event hosted in thesandbox office in paris the enigma odyssey 300 + contestants ripples of the gotchiverse graphic novel to be delivered soon entrusted by the licence ip signed with aavegotchi gfa community made the choice to lean over the revenue share repartition even if the initial proposal only mentioned 10 percent royalty to pixelcraft studio. different types of revenues are generated through this project : direct and indirect returns. about direct financial returns here is the repartition gfa decided to apply : so far around sand tokens sales has been generated. dao share was delivered in december 7 425 sand . multiplayer experience is empowered to generate more of those. about indirect revenues please find below the stats of the single experience release engagement : 1 thesandbox social engagement good overall engagement on sandbox announcement tweets good visibility of aavegotchi community to thesandbox userbase good average in - game numbers kyc accounts 2 aavegotchi some of the best aavegotchi tweets of 2023 around + views forge an alliance with top web3 brend thesandbox with the great impact this initiative had it is now official as discussed during the last hangout and ama aavegotchi made the choice to get some lands 1 estate 3x3 in thesandbox. it gives the possibility to selfpublish aavegotchi experiences beeing playable without interruption. here is the location of aavegotchi 3x3 estate owned by pixelcraft : www.sandbox.game en map lat = 82 lng = - 158 zoom = 4 x = - 158 y = 82 proposal of funding this proposal of funding is to empower gfa to operate pixelcraft lands and partnership for a limited and renewable 6 months duration with as follows duties : management of project and coordination partnership management maintain channel of discussion with sandbox officers like sebastien borget upgrades of aavegotchi avatar collection in sandbox aavegotchi assets collection utility and highlight in game experience updates management of aavegotchi parcels in sandbox + collect analysis of ingame and traffic datas with thesandbox upgrades and modifications of experiences due to sandbox new gamemaker and gameclient release forecasted bi - monthly for 0.9 minor versions and specific events interaction in the slack technical support with sandbox team and ticketing system organisation and strategy for futur events ingame con ...

# %%
def cohere(row):
    """
    restructures the meaningless number values in the dataframe
    and forms a coherent and meaningful sentence out of it

    args:
        row - row of a dataframe
    """

    title = row['title']
    author = row['author']
    content = row['content']

    message = f'TITLE {title}. AUTHOR {author}. CONTENT {content}'

    return message

# %%
csvs[3][1]['message'] = csvs[3][1].apply(cohere, axis=1).iloc[0]
csvs[3][1]['message']
# Out:
# 0      TITLE aavegotchi x sandbox experience - expans...
# 1      TITLE aavegotchi x sandbox experience - expans...
# 2      TITLE aavegotchi x sandbox experience - expans...
# 3      TITLE aavegotchi x sandbox experience - expans...
# 4      TITLE aavegotchi x sandbox experience - expans...
#                              ...
# 533    TITLE aavegotchi x sandbox experience - expans...
# 534    TITLE aavegotchi x sandbox experience - expans...
# 535    TITLE aavegotchi x sandbox experience - expans...
# 536    TITLE aavegotchi x sandbox experience - expans...
# 537    TITLE aavegotchi x sandbox experience - expans...
# Name: message, Length: 538, dtype: object

# %%
csvs[3][1]['message'].iloc[0]
# Out:
# 'TITLE aavegotchi x sandbox experience - expansion maintenance. AUTHOR thrax. CONTENT author: the gotchifarmy gfa the gotchi farmy 6696 gotchi id: 8050 quorum requirement: 20 percent 9m vote duration: 14 days discourse thread: channels the gfa studio journey to create the first aavegotchi experience in the sandbox was delivered early november 2023. aavegotchi status s = 20 we created a google form we submitted to the community during a hangout. we received limited but valuable information about the experience. it is important to note it reflects the vision of aavegotchi native community member: forms d e 1faipqlsdokbjm8oluzo - sgiyiy2rhwmogb56ah9wiwl9abym0lg3sja viewform usp = sf link about thesandbox team and community we got tremendous returns. thesandbox was shocked by the richness of aavegotchi ecosystem and lore applied in their voxeled environnement. this project scope of work supported by the dao was established as follow : - - 1 creation of a sandbox single player experience providing : educational content about aavegotchi aavegotchi lore exploration cross universe aavegotchi artistic creation 2 second: one multiplayer experience b ta test of thesandbox 0.9 gamemaker version multiplayer features to be delivered early 2024 3 organization of incentives around the project 4 aavegotchi x the sandbox ama gfa decided to go further by achieving unscheduled out of scope milestones: forge an official partnership between aavegotchi and thesandbox bridge of gotchis as official thesandbox aavegotchi aavatar collection negotiations to gain access to top tier vip partner communication by thesandbox on social media concerning the release creation of 3 full og equipment sets sandbox marketplace irl event hosted in thesandbox office in paris the enigma odyssey 300 + contestants ripples of the gotchiverse graphic novel to be delivered soon entrusted by the licence ip signed with aavegotchi gfa community made the choice to lean over the revenue share repartition even if the initial proposal only mentioned 10 percent royalty to pixelcraft studio. different types of revenues are generated through this project : direct and indirect returns. about direct financial returns here is the repartition gfa decided to apply : so far around sand tokens sales has been generated. dao share was delivered in december 7 425 sand . multiplayer experience is empowered to generate more of those. about indirect revenues please find below the stats of the single experience release engagement : 1 thesandbox social engagement good overall engagement on sandbox announcement tweets good visibility of aavegotchi community to thesandbox userbase good average in - game numbers kyc accounts 2 aavegotchi some of the best aavegotchi tweets of 2023 around + views forge an alliance with top web3 brend thesandbox with the great impact this initiative had it is now official as discussed during the last hangout and ama aavegotchi made the choice to get some lands 1 estate 3x3 in thesandbox. it gives the possibility to selfpublish aavegotchi experiences beeing playable without interruption. here is the location of aavegotchi 3x3 estate owned by pixelcraft : www.sandbox.game en map lat = 82 lng = - 158 zoom = 4 x = - 158 y = 82 proposal of funding this proposal of funding is to empower gfa to operate pixelcraft lands and partnership for a limited and renewable 6 months duration with as follows duties : management of project and coordination partnership management maintain channel of discussion with sandbox officers like sebastien borget upgrades of aavegotchi avatar collection in sandbox aavegotchi assets collection utility and highlight in game experience updates management of aavegotchi parcels in sandbox + collect analysis of ingame and traffic datas with thesandbox upgrades and modifications of experiences due to sandbox new gamemaker and gameclient release forecasted bi - monthly for 0.9 minor versions and specific events interaction in the slack technical support with sa ...

# %% [markdown]
# # What we can do for all these messages is to treat each element as if it were a line that was being processed by the clean_and_split_data() function

# %%
csvs
# Out:
# [('dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment',
#         created_at  favorite_count  \
#   32666   2/1/2021             154
#   29639   2/1/2021              17
#   29613   2/1/2021               3
#   39638   2/1/2021            3496
#   32660   2/1/2021               0
#   ...          ...             ...
#   1309   6/12/2023               3
#   1307   6/12/2023               0
#   1306   6/12/2023               0
#   1305   6/12/2023              56
#   1312   6/12/2023               0
#
#                                                  full_text  reply_count  \
#   32666  #privacy is a human right. learn how to make y...           18
#   29639  overall btc trading volume has increased, but ...            1
#   29613  on average, the return distribution of btc ske...            0
#   39638  i sent some! https://t.co/mfyrz35zjf\n\nyou sh...          731
#   32660  rt @reg_mati: la privacidad es un derecho huma...            0
#   ...                                                  ...          ...
#   1309   booomð¥\n\nour #ai bot/indicator crushes ano...            5
#   1307   rt @crypto_crib_: the deadline is today for bi...            0
#   1306   rt @crypto_crib_: ð²chinese bank boci issues...            0
#   1305       bitcoin, not crypto.\n\ncrypto, not security.           16
#   1312   rt @crypto_crib_: jpmorgan calls for "comprehe...            0
#
#          retweet_count                                         clean_text  \
#   32666             23  privacy human right learn make bitcoin transac...
#   29639              5  overall btc trading volume increased average t...
#   29613              1  average return distribution btc skews slightly...
#   39638            686  sent httpstcomfyrz35zjf givedirectly great wor...
#   32660              7  rt reg_mati la privacidad e un derecho humano ...
#   ...              ...                                                ...
#   1309               0  booomð ai botindicator crush another lina trad...
#   1307               4  rt crypto_crib_ deadline today binance binance...
#   1306               8  rt crypto_crib_ ð²chinese bank boci issue coun...
#   1305               7                     bitcoin crypto crypto security
#   1312               8  rt crypto_crib_ jpmorgan call comprehensive fr...
#
#          importance_coefficient  importance_coefficient_normalized  \
#   32666                   340.0                           0.000588
#   29639                    39.5                           0.000068
#   29613                     7.0                           0.000012
#   39638                  8043.5                           0.013905
#   32660                     7.0                           0.000012
#   ...                       ...                                ...
#   1309                      8.5                           0.000015
#   1307                      4.0                           0.000007
#   1306                      8.0                           0.000014
#   1305                    127.0                           0.000220
#   1312                      8.0                           0.000014
#
#                                  new_coins  \
#   32666                            bitcoin
#   29639                                btc
#   29613                                btc
#   39638                               doge
#   32660                            bitcoin
#   ...                                  ...
#   1309   doge, hbar, inj, usdt, matic, ftm
#   1307                    binance, request
#   1306                            ethereum
#   1305                             bitcoin
#   1312                        binance, amp
#
#                                                     scores  compound  \
#   32666  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000
#   29639  {'neg': 0.0, 'neu': 0.95, 'pos': 0.05, 'compou...    0.2124
#   29613  {'neg': 0.053, 'neu': 0.769, 'pos': 0.177, 'co...    0.7010
#   39638  {'neg': 0.06, 'neu': 0.856, 'pos': 0.084, 'com...    0.2225
#   32660  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000
#   ...                                                  ...       ...
#   1309   {'neg': 0.092, 'neu': 0.75, 'pos': 0.158, 'com...    0.6239
#   1307   {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000
#   1306   {'neg': 0.0, 'neu': 0.844, 'pos': 0.156, 'comp...    0.3400
#   1305   {'neg': 0.289, 'neu': 0.711, 'pos': 0.0, 'comp...   -0.2584
#   1312   {'neg': 0.084, 'neu': 0.752, 'pos': 0.164, 'co...    0.2023
#
#         sentiment_type                                            message
#   32666        NEUTRAL  the tweet: "privacy human right learn make bit...
#   29639       POSITIVE  the tweet: "overall btc trading volume increas...
#   29613       POSITIVE  the tweet: "average return distribution btc sk...
#   39638       POSITIVE  the tweet: "sent httpstcomfyrz35zjf givedirect...
#   32660        NEUTRAL  the tweet: "rt reg_mati la privacidad e un der...
#   ...              ...                                                ...
#   1309        POSITIVE  the tweet: "booomð ai botindicator crush anoth...
#   1307         NEUTRAL  the tweet: "rt crypto_crib_ deadline today bin...
#   1306        POSITIVE  the tweet: "rt crypto_crib_ ð²chinese bank boc...
#   1305        NEGATIVE  the tweet: "bitcoin crypto crypto security" ha...
#   1312        POSITIVE  the tweet: "rt crypto_crib_ jpmorgan call comp...
#
#   [16512 rows x 13 columns]),
#  ('eth_selected_with_sentiment_2023_01_02_2023_06_12',
#                  date  close  high   low  open       volume  adjclose   changes  \
#   1    January 2 2023   1220  1195  1201  1215   3765758498      1215  positive
#   2    January 3 2023   1219  1207  1215  1215   3392972131      1215  negative
#   3    January 4 2023   1265  1213  1215  1257   6404416893      1257  positive
#   4    January 5 2023   1259  1245  1256  1250   4001786456      1250  negative
#   5    January 6 2023   1273  1241  1250  1269   4977252792      1269  positive
#   ..              ...    ...   ...   ...   ...          ...       ...       ...
#   158     June 8 2023   1861  1830  1833  1846   4536041931      1846  negative
#   159     June 9 2023   1855  1829  1846  1840   4610831509      1840  negative
#   160    June 10 2023   1845  1721  1840  1752  10788500406      1752  negative
#   161    June 11 2023   1777  1741  1753  1753   4559112981      1753  negative
#   162    June 12 2023   1758  1723  1753  1743   6031384958      1743  negative
#
#        compound sentiment_type  \
#   1      0.6908       POSITIVE
#   2      0.0000        NEUTRAL
#   3     -0.2878       NEGATIVE
#   4     -0.2732       NEGATIVE
#   5      0.4588       POSITIVE
#   ..        ...            ...
#   158    0.7859       POSITIVE
#   159    0.9168       POSITIVE
#   160    0.7643       POSITIVE
#   161    0.9059       POSITIVE
#   162    0.8513       POSITIVE
#
#                                                  message
#   1    January 2 2023 had a closing price of 1220 and...
#   2    January 3 2023 had a closing price of 1219 and...
#   3    January 4 2023 had a closing price of 1265 and...
#   4    January 5 2023 had a closing price of 1259 and...
#   5    January 6 2023 had a closing price of 1273 and...
#   ..                                                 ...
#   158  June 8 2023 had a closing price of 1861 and an...
#   159  June 9 2023 had a closing price of 1855 and an...
#   160  June 10 2023 had a closing price of 1845 and a...
#   161  June 11 2023 had a closing price of 1777 and a...
#   162  June 12 2023 had a closing price of 1758 and a...
#
#   [162 rows x 11 columns]),
#  ('gotchi_wearable_sets',
#                Set Name                               Set Bonus  \
#   0             Aarcher                          BRS +1, AGG -1
#   1          Aastronaut                          BRS +1, SPK +1
#   2           Aave Hero                          BRS +1, SPK +1
#   3            ETH Maxi                          BRS +1, BRN -1
#   4              Farmer                          BRS +1, NRG -1
#   ..                ...                                     ...
#   161     Jacob Maarley          BRS +8, NRG +1, SPK +3, BRN -1
#   162  Master Creatooor          BRS +8, NRG +1, SPK -2, BRN -2
#   163        ROFL Tamer                  BRS +8, NRG -3, BRN -2
#   164      Shogungotchi  BRS +8, NRG -1, AGG +1, SPK +2, BRN -1
#   165          VRF Lord                  BRS +8, NRG +3, BRN +2
#
#                                    Total Bonuses  Total  \
#   0                       BRS +4, NRG -1, AGG -3      8
#   1                               BRS +4, SPK +4      8
#   2                               BRS +4, SPK +4      8
#   3                               BRS +4, BRN -4      8
#   4               BRS +4, NRG -2, AGG +1, BRN -1      8
#   ..                                         ...    ...
#   161          BRS +208, NRG +17, SPK +3, BRN -9    237
#   162         BRS +208, NRG +5, SPK -11, BRN -13    237
#   163                 BRS +208, NRG -16, BRN -13    237
#   164  BRS +208, NRG -4, AGG +9, SPK +12, BRN -4    237
#   165                 BRS +208, NRG +15, BRN +14    237
#
#                                                Wearables  \
#   0    Brunette Ponytail (Common; BRS +1, AGG -1); Le...
#   1    Aastronaut Helmet (Common; BRS +1, SPK +1); Aa...
#   2    Aave Hero Mask (Common; BRS +1, SPK +1); Aave ...
#   3    ETH Logo Glasses (Common; BRS +1, BRN -1); ETH...
#   4    Straw Hat (Common; BRS +1, NRG -1); Farmer Jea...
#   ..                                                 ...
#   161  Heavenly Robes (Godlike; BRS +50, NRG +4, BRN ...
#   162  Staff of Creation (Godlike; BRS +50, SPK -3, B...
#   163  All-Seeing Eyes (Godlike; BRS +50, NRG -6); Go...
#   164  Godlike Rofl (Godlike; BRS +50, NRG -3, BRN -3...
#   165  Galaxy Brain (Godlike; BRS +50, BRN +6); Link ...
#
#                                                  message
#   0    Character Aarcher had a set bonus of BRS +1, A...
#   1    Character Aastronaut had a set bonus of BRS +1...
#   2    Character Aave Hero had a set bonus of BRS +1,...
#   3    Character ETH Maxi had a set bonus of BRS +1, ...
#   4    Character Farmer had a set bonus of BRS +1, NR...
#   ..                                                 ...
#   161  Character Jacob Maarley had a set bonus of BRS...
#   162  Character Master Creatooor had a set bonus of ...
#   163  Character ROFL Tamer had a set bonus of BRS +8...
#   164  Character Shogungotchi had a set bonus of BRS ...
#   165  Character VRF Lord had a set bonus of BRS +8, ...
#
#   [166 rows x 6 columns]),
#  ('scraped_proposals',
#                                                    title            author  \
#   0    aavegotchi x sandbox experience - expansion ma...             thrax
#   1              gas fee reimbursement for dao directors     0x50f4...d764
#   2    aavegotchi dao liquidity incentives proposal a...           apeadam
#   3                          gotchi battler v1.5 funding     0x10b9...229b
#   4              gas fee reimbursement for dao directors     0x50f4...d764
#   ..                                                 ...               ...
#   533            rf season 8 changes to brs rewards pool     0x89b1...7008
#   534                    establishing an eth sell ladder      drwagmi.lens
#   535                   agip 109 rarity farming season 8             thrax
#   536   agip 111 staking 350 eth with lido and acquir...             thrax
#   537               rarity farming season 8 re - repost   hardkornate.lens
#
#           date                                            content  \
#   0    10m ago  author: the gotchifarmy gfa the gotchi farmy 6...
#   1    10m ago  author: maxicrouton quorum requirement: 20 per...
#   2    10m ago  author: juliaan bobaa aadam and gotchiid: quor...
#   3    10m ago  authors: immaterial gotchiids: quorum requirem...
#   4    10m ago  author: maxicrouton quorum requirement: 20 per...
#   ..       ...                                                ...
#   533   9m ago  author: bearded gotchi id: in rarity farming s...
#   534   9m ago  author: dr. wagmi quorum requirement: 20 perce...
#   535   9m ago  author: hardkor gotchiid: quorum requirement: ...
#   536   9m ago  author: dr. wagmi quorum requirement: 20 perce...
#   537   9m ago  author: hardkor gotchiid: quorum requirement: ...
#
#                                                  message
#   0    TITLE aavegotchi x sandbox experience - expans...
#   1    TITLE aavegotchi x sandbox experience - expans...
#   2    TITLE aavegotchi x sandbox experience - expans...
#   3    TITLE aavegotchi x sandbox experience - expans...
#   4    TITLE aavegotchi x sandbox experience - expans...
#   ..                                                 ...
#   533  TITLE aavegotchi x sandbox experience - expans...
#   534  TITLE aavegotchi x sandbox experience - expans...
#   535  TITLE aavegotchi x sandbox experience - expans...
#   536  TITLE aavegotchi x sandbox experience - expans...
#   537  TITLE aavegotchi x sandbox experience - expans...
#
#   [538 rows x 5 columns])]

# %%
# final_texts = [(name, df['message'].tolist()) for name, df in csvs]
# final_texts

# %%
def clean_and_split_data(name, data, output_dir: str, char_limit: int=700, max_rows: int=40):
    """
    Cleans and splits text data:
    - Removes numbering at the start of lines.
    - Converts text to lowercase.
    - Splits each row to ensure it doesn't exceed the character limit.
    - Outputs multiple files if the number of rows exceeds max_rows.
    """
    def split_into_chunks(text, limit):
        """
        Splits a text into chunks no larger than the character limit.
        

        e.g "  "description": "Oracle-X is a...knowledge."," is a string
        or line that may ocntain 700+ characters 
        """
        
        chunks = []

        # if the length of line is bigger than limit i.e. 900 > 700
        # then the line is sliced into 700 character strings
        # and the next slice i.e. 700:900 or [700] to [899] is now set
        # as the next string to be processed but since slice [700] to [899]
        # length of 200 is now less than limit of 700 loop is terminated
        # and the final 200 characters are appended to the chunks list
        while len(text) > limit:
            chunks.append(text[:limit].strip())
            text = text[limit:]
        if text:
            chunks.append(text.strip())

        # chunks = [<chunk 1 of 700 char string>, <chunk 2 of 700 char string>, ..., <chunk n of <=700 char string>]
        return chunks

    # Process each row to enforce character limits
    output_lines = []
    for line in data:
        output_lines.extend(split_into_chunks(line, char_limit))

    # Write to multiple files if necessary
    base_name = name
    os.makedirs(output_dir, exist_ok=True)

    
    for i in range(0, len(output_lines), max_rows):
        """
        if there were 100 output lines and we wanted only
        40 lines per file, we would increment from
        0:0+40 or [0] to [39]
        40:40+40 or [40] to [79]
        80:80+40 or [80] to [119] 
        
        but in slicing arrays 
        when an array is only of a certain length and our end 
        index exceeds it we only really get the slice until the end of the array 
        so in essence we get only [80] to [99]
        """
        chunk = output_lines[i:i + max_rows]

        """40 is the max amount of rows"""
        output_file = os.path.join(output_dir, f"{base_name}_processed_part{i // max_rows + 1}.txt")
        print(f"output file: {output_file}")
        with open(output_file, 'w', encoding='utf-8') as file:
            file.writelines(line + '\n' for line in chunk)

        print(f"File {output_file} has been created with {len(chunk)} lines.")

# %%
output_dir = './Aavegotchi'
for name, df in csvs:
    lists = df['message'].tolist()
    clean_and_split_data(name, lists, output_dir)
# Out:
# output file: ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part1.txt
# File ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part1.txt has been created with 40 lines.
# output file: ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part2.txt
# File ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part2.txt has been created with 40 lines.
# output file: ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part3.txt
# File ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part3.txt has been created with 40 lines.
# output file: ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part4.txt
# File ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part4.txt has been created with 40 lines.
# output file: ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part5.txt
# File ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part5.txt has been created with 40 lines.
# output file: ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part6.txt
# File ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part6.txt has been created with 40 lines.
# output file: ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part7.txt
# File ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part7.txt has been created with 40 lines.
# output file: ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part8.txt
# File ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part8.txt has been created with 40 lines.
# output file: ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part9.txt
# File ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part9.txt has been created with 40 lines.
# output file: ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part10.txt
# File ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part10.txt has been created with 40 lines.
# output file: ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part11.txt
# File ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part11.txt has been created with 40 lines.
# output file: ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part12.txt
# File ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part12.txt has been created with 40 lines.
# output file: ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part13.txt
# File ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part13.txt has been created with 40 lines.
# output file: ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part14.txt
# File ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part14.txt has been created with 40 lines.
# output file: ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part15.txt
# File ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part15.txt has been created with 40 lines.
# output file: ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part16.txt
# File ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part16.txt has been created with 40 lines.
# output file: ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part17.txt
# File ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part17.txt has been created with 40 lines.
# output file: ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part18.txt
# File ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part18.txt has been created with 40 lines.
# output file: ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part19.txt
# File ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part19.txt has been created with 40 lines.
# output file: ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part20.txt
# File ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part20.txt has been created with 40 lines.
# output file: ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part21.txt
# File ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part21.txt has been created with 40 lines.
# output file: ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part22.txt
# File ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part22.txt has been created with 40 lines.
# output file: ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part23.txt
# File ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part23.txt has been created with 40 lines.
# output file: ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part24.txt
# File ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part24.txt has been created with 40 lines.
# output file: ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part25.txt
# File ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part25.txt has been created with 40 lines.
# output file: ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part26.txt
# File ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part26.txt has been created with 40 lines.
# output file: ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part27.txt
# File ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part27.txt has been created with 40 lines.
# output file: ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part28.txt
# File ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part28.txt has been created with 40 lines.
# output file: ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part29.txt
# File ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part29.txt has been created with 40 lines.
# output file: ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part30.txt
# File ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part30.txt has been created with 40 lines.
# output file: ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part31.txt
# File ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part31.txt has been created with 40 lines.
# output file: ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part32.txt
# File ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part32.txt has been created with 40 lines.
# output file: ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part33.txt
# File ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part33.txt has been created with 40 lines.
# output file: ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part34.txt
# File ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part34.txt has been created with 40 lines.
# output file: ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part35.txt
# File ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part35.txt has been created with 40 lines.
# output file: ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part36.txt
# File ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part36.txt has been created with 40 lines.
# output file: ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part37.txt
# File ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part37.txt has been created with 40 lines.
# output file: ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part38.txt
# File ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part38.txt has been created with 40 lines.
# output file: ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part39.txt
# File ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part39.txt has been created with 40 lines.
# output file: ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part40.txt
# File ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part40.txt has been created with 40 lines.
# output file: ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part41.txt
# File ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part41.txt has been created with 40 lines.
# output file: ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part42.txt
# File ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part42.txt has been created with 40 lines.
# output file: ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part43.txt
# File ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part43.txt has been created with 40 lines.
# output file: ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part44.txt
# File ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part44.txt has been created with 40 lines.
# output file: ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part45.txt
# File ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part45.txt has been created with 40 lines.
# output file: ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part46.txt
# File ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part46.txt has been created with 40 lines.
# output file: ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part47.txt
# File ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part47.txt has been created with 40 lines.
# output file: ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part48.txt
# File ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part48.txt has been created with 40 lines.
# output file: ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part49.txt
# File ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part49.txt has been created with 40 lines.
# output file: ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part50.txt
# File ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part50.txt has been created with 40 lines.
# output file: ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part51.txt
# File ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part51.txt has been created with 40 lines.
# output file: ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part52.txt
# File ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part52.txt has been created with 40 lines.
# output file: ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part53.txt
# File ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part53.txt has been created with 40 lines.
# output file: ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part54.txt
# File ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part54.txt has been created with 40 lines.
# output file: ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part55.txt
# File ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part55.txt has been created with 40 lines.
# output file: ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part56.txt
# File ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part56.txt has been created with 40 lines.
# output file: ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part57.txt
# File ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part57.txt has been created with 40 lines.
# output file: ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part58.txt
# File ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part58.txt has been created with 40 lines.
# output file: ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part59.txt
# File ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part59.txt has been created with 40 lines.
# output file: ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part60.txt
# File ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part60.txt has been created with 40 lines.
# output file: ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part61.txt
# File ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part61.txt has been created with 40 lines.
# output file: ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part62.txt
# File ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part62.txt has been created with 40 lines.
# output file: ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part63.txt
# File ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part63.txt has been created with 40 lines.
# output file: ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part64.txt
# File ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part64.txt has been created with 40 lines.
# output file: ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part65.txt
# File ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part65.txt has been created with 40 lines.
# output file: ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part66.txt
# File ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part66.txt has been created with 40 lines.
# output file: ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part67.txt
# File ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part67.txt has been created with 40 lines.
# output file: ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part68.txt
# File ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part68.txt has been created with 40 lines.
# output file: ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part69.txt
# File ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part69.txt has been created with 40 lines.
# output file: ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part70.txt
# File ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part70.txt has been created with 40 lines.
# output file: ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part71.txt
# File ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part71.txt has been created with 40 lines.
# output file: ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part72.txt
# File ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part72.txt has been created with 40 lines.
# output file: ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part73.txt
# File ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part73.txt has been created with 40 lines.
# output file: ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part74.txt
# File ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part74.txt has been created with 40 lines.
# output file: ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part75.txt
# File ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part75.txt has been created with 40 lines.
# output file: ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part76.txt
# File ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part76.txt has been created with 40 lines.
# output file: ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part77.txt
# File ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part77.txt has been created with 40 lines.
# output file: ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part78.txt
# File ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part78.txt has been created with 40 lines.
# output file: ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part79.txt
# File ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part79.txt has been created with 40 lines.
# output file: ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part80.txt
# File ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part80.txt has been created with 40 lines.
# output file: ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part81.txt
# File ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part81.txt has been created with 40 lines.
# output file: ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part82.txt
# File ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part82.txt has been created with 40 lines.
# output file: ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part83.txt
# File ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part83.txt has been created with 40 lines.
# output file: ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part84.txt
# File ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part84.txt has been created with 40 lines.
# output file: ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part85.txt
# File ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part85.txt has been created with 40 lines.
# output file: ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part86.txt
# File ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part86.txt has been created with 40 lines.
# output file: ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part87.txt
# File ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part87.txt has been created with 40 lines.
# output file: ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part88.txt
# File ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part88.txt has been created with 40 lines.
# output file: ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part89.txt
# File ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part89.txt has been created with 40 lines.
# output file: ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part90.txt
# File ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part90.txt has been created with 40 lines.
# output file: ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part91.txt
# File ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part91.txt has been created with 40 lines.
# output file: ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part92.txt
# File ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part92.txt has been created with 40 lines.
# output file: ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part93.txt
# File ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part93.txt has been created with 40 lines.
# output file: ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part94.txt
# File ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part94.txt has been created with 40 lines.
# output file: ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part95.txt
# File ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part95.txt has been created with 40 lines.
# output file: ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part96.txt
# File ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part96.txt has been created with 40 lines.
# output file: ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part97.txt
# File ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part97.txt has been created with 40 lines.
# output file: ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part98.txt
# File ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part98.txt has been created with 40 lines.
# output file: ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part99.txt
# File ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part99.txt has been created with 40 lines.
# output file: ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part100.txt
# File ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part100.txt has been created with 40 lines.
# output file: ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part101.txt
# File ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part101.txt has been created with 40 lines.
# output file: ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part102.txt
# File ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part102.txt has been created with 40 lines.
# output file: ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part103.txt
# File ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part103.txt has been created with 40 lines.
# output file: ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part104.txt
# File ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part104.txt has been created with 40 lines.
# output file: ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part105.txt
# File ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part105.txt has been created with 40 lines.
# output file: ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part106.txt
# File ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part106.txt has been created with 40 lines.
# output file: ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part107.txt
# File ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part107.txt has been created with 40 lines.
# output file: ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part108.txt
# File ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part108.txt has been created with 40 lines.
# output file: ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part109.txt
# File ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part109.txt has been created with 40 lines.
# output file: ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part110.txt
# File ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part110.txt has been created with 40 lines.
# output file: ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part111.txt
# File ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part111.txt has been created with 40 lines.
# output file: ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part112.txt
# File ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part112.txt has been created with 40 lines.
# output file: ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part113.txt
# File ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part113.txt has been created with 40 lines.
# output file: ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part114.txt
# File ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part114.txt has been created with 40 lines.
# output file: ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part115.txt
# File ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part115.txt has been created with 40 lines.
# output file: ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part116.txt
# File ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part116.txt has been created with 40 lines.
# output file: ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part117.txt
# File ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part117.txt has been created with 40 lines.
# output file: ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part118.txt
# File ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part118.txt has been created with 40 lines.
# output file: ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part119.txt
# File ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part119.txt has been created with 40 lines.
# output file: ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part120.txt
# File ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part120.txt has been created with 40 lines.
# output file: ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part121.txt
# File ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part121.txt has been created with 40 lines.
# output file: ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part122.txt
# File ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part122.txt has been created with 40 lines.
# output file: ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part123.txt
# File ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part123.txt has been created with 40 lines.
# output file: ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part124.txt
# File ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part124.txt has been created with 40 lines.
# output file: ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part125.txt
# File ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part125.txt has been created with 40 lines.
# output file: ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part126.txt
# File ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part126.txt has been created with 40 lines.
# output file: ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part127.txt
# File ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part127.txt has been created with 40 lines.
# output file: ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part128.txt
# File ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part128.txt has been created with 40 lines.
# output file: ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part129.txt
# File ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part129.txt has been created with 40 lines.
# output file: ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part130.txt
# File ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part130.txt has been created with 40 lines.
# output file: ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part131.txt
# File ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part131.txt has been created with 40 lines.
# output file: ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part132.txt
# File ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part132.txt has been created with 40 lines.
# output file: ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part133.txt
# File ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part133.txt has been created with 40 lines.
# output file: ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part134.txt
# File ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part134.txt has been created with 40 lines.
# output file: ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part135.txt
# File ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part135.txt has been created with 40 lines.
# output file: ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part136.txt
# File ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part136.txt has been created with 40 lines.
# output file: ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part137.txt
# File ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part137.txt has been created with 40 lines.
# output file: ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part138.txt
# File ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part138.txt has been created with 40 lines.
# output file: ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part139.txt
# File ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part139.txt has been created with 40 lines.
# output file: ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part140.txt
# File ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part140.txt has been created with 40 lines.
# output file: ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part141.txt
# File ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part141.txt has been created with 40 lines.
# output file: ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part142.txt
# File ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part142.txt has been created with 40 lines.
# output file: ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part143.txt
# File ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part143.txt has been created with 40 lines.
# output file: ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part144.txt
# File ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part144.txt has been created with 40 lines.
# output file: ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part145.txt
# File ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part145.txt has been created with 40 lines.
# output file: ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part146.txt
# File ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part146.txt has been created with 40 lines.
# output file: ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part147.txt
# File ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part147.txt has been created with 40 lines.
# output file: ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part148.txt
# File ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part148.txt has been created with 40 lines.
# output file: ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part149.txt
# File ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part149.txt has been created with 40 lines.
# output file: ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part150.txt
# File ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part150.txt has been created with 40 lines.
# output file: ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part151.txt
# File ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part151.txt has been created with 40 lines.
# output file: ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part152.txt
# File ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part152.txt has been created with 40 lines.
# output file: ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part153.txt
# File ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part153.txt has been created with 40 lines.
# output file: ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part154.txt
# File ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part154.txt has been created with 40 lines.
# output file: ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part155.txt
# File ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part155.txt has been created with 40 lines.
# output file: ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part156.txt
# File ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part156.txt has been created with 40 lines.
# output file: ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part157.txt
# File ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part157.txt has been created with 40 lines.
# output file: ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part158.txt
# File ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part158.txt has been created with 40 lines.
# output file: ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part159.txt
# File ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part159.txt has been created with 40 lines.
# output file: ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part160.txt
# File ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part160.txt has been created with 40 lines.
# output file: ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part161.txt
# File ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part161.txt has been created with 40 lines.
# output file: ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part162.txt
# File ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part162.txt has been created with 40 lines.
# output file: ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part163.txt
# File ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part163.txt has been created with 40 lines.
# output file: ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part164.txt
# File ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part164.txt has been created with 40 lines.
# output file: ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part165.txt
# File ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part165.txt has been created with 40 lines.
# output file: ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part166.txt
# File ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part166.txt has been created with 40 lines.
# output file: ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part167.txt
# File ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part167.txt has been created with 40 lines.
# output file: ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part168.txt
# File ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part168.txt has been created with 40 lines.
# output file: ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part169.txt
# File ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part169.txt has been created with 40 lines.
# output file: ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part170.txt
# File ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part170.txt has been created with 40 lines.
# output file: ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part171.txt
# File ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part171.txt has been created with 40 lines.
# output file: ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part172.txt
# File ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part172.txt has been created with 40 lines.
# output file: ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part173.txt
# File ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part173.txt has been created with 40 lines.
# output file: ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part174.txt
# File ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part174.txt has been created with 40 lines.
# output file: ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part175.txt
# File ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part175.txt has been created with 40 lines.
# output file: ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part176.txt
# File ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part176.txt has been created with 40 lines.
# output file: ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part177.txt
# File ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part177.txt has been created with 40 lines.
# output file: ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part178.txt
# File ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part178.txt has been created with 40 lines.
# output file: ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part179.txt
# File ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part179.txt has been created with 40 lines.
# output file: ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part180.txt
# File ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part180.txt has been created with 40 lines.
# output file: ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part181.txt
# File ./Aavegotchi\dataset_52-person-from-2021-02-05_2023-06-12_21-34-17-266_with_sentiment_processed_part181.txt has been created with 40 lines.
# ...
# File ./Aavegotchi\eth_selected_with_sentiment_2023_01_02_2023_06_12_processed_part3.txt has been created with 40 lines.
# output file: ./Aavegotchi\eth_selected_with_sentiment_2023_01_02_2023_06_12_processed_part4.txt
# File ./Aavegotchi\eth_selected_with_sentiment_2023_01_02_2023_06_12_processed_part4.txt has been created with 40 lines.
# output file: ./Aavegotchi\eth_selected_with_sentiment_2023_01_02_2023_06_12_processed_part5.txt
# File ./Aavegotchi\eth_selected_with_sentiment_2023_01_02_2023_06_12_processed_part5.txt has been created with 2 lines.
# output file: ./Aavegotchi\gotchi_wearable_sets_processed_part1.txt
# File ./Aavegotchi\gotchi_wearable_sets_processed_part1.txt has been created with 40 lines.
# output file: ./Aavegotchi\gotchi_wearable_sets_processed_part2.txt
# File ./Aavegotchi\gotchi_wearable_sets_processed_part2.txt has been created with 40 lines.
# output file: ./Aavegotchi\gotchi_wearable_sets_processed_part3.txt
# File ./Aavegotchi\gotchi_wearable_sets_processed_part3.txt has been created with 40 lines.
# output file: ./Aavegotchi\gotchi_wearable_sets_processed_part4.txt
# File ./Aavegotchi\gotchi_wearable_sets_processed_part4.txt has been created with 40 lines.
# output file: ./Aavegotchi\gotchi_wearable_sets_processed_part5.txt
# File ./Aavegotchi\gotchi_wearable_sets_processed_part5.txt has been created with 6 lines.
# output file: ./Aavegotchi\scraped_proposals_processed_part1.txt
# File ./Aavegotchi\scraped_proposals_processed_part1.txt has been created with 40 lines.
# output file: ./Aavegotchi\scraped_proposals_processed_part2.txt
# File ./Aavegotchi\scraped_proposals_processed_part2.txt has been created with 40 lines.
# output file: ./Aavegotchi\scraped_proposals_processed_part3.txt
# File ./Aavegotchi\scraped_proposals_processed_part3.txt has been created with 40 lines.
# output file: ./Aavegotchi\scraped_proposals_processed_part4.txt
# File ./Aavegotchi\scraped_proposals_processed_part4.txt has been created with 40 lines.
# output file: ./Aavegotchi\scraped_proposals_processed_part5.txt
# File ./Aavegotchi\scraped_proposals_processed_part5.txt has been created with 40 lines.
# output file: ./Aavegotchi\scraped_proposals_processed_part6.txt
# File ./Aavegotchi\scraped_proposals_processed_part6.txt has been created with 40 lines.
# output file: ./Aavegotchi\scraped_proposals_processed_part7.txt
# File ./Aavegotchi\scraped_proposals_processed_part7.txt has been created with 40 lines.
# output file: ./Aavegotchi\scraped_proposals_processed_part8.txt
# File ./Aavegotchi\scraped_proposals_processed_part8.txt has been created with 40 lines.
# output file: ./Aavegotchi\scraped_proposals_processed_part9.txt
# File ./Aavegotchi\scraped_proposals_processed_part9.txt has been created with 40 lines.
# output file: ./Aavegotchi\scraped_proposals_processed_part10.txt
# File ./Aavegotchi\scraped_proposals_processed_part10.txt has been created with 40 lines.
# output file: ./Aavegotchi\scraped_proposals_processed_part11.txt
# File ./Aavegotchi\scraped_proposals_processed_part11.txt has been created with 40 lines.
# output file: ./Aavegotchi\scraped_proposals_processed_part12.txt
# File ./Aavegotchi\scraped_proposals_processed_part12.txt has been created with 40 lines.
# output file: ./Aavegotchi\scraped_proposals_processed_part13.txt
# File ./Aavegotchi\scraped_proposals_processed_part13.txt has been created with 40 lines.
# output file: ./Aavegotchi\scraped_proposals_processed_part14.txt
# File ./Aavegotchi\scraped_proposals_processed_part14.txt has been created with 40 lines.
# output file: ./Aavegotchi\scraped_proposals_processed_part15.txt
# File ./Aavegotchi\scraped_proposals_processed_part15.txt has been created with 40 lines.
# output file: ./Aavegotchi\scraped_proposals_processed_part16.txt
# File ./Aavegotchi\scraped_proposals_processed_part16.txt has been created with 40 lines.
# output file: ./Aavegotchi\scraped_proposals_processed_part17.txt
# File ./Aavegotchi\scraped_proposals_processed_part17.txt has been created with 40 lines.
# output file: ./Aavegotchi\scraped_proposals_processed_part18.txt
# File ./Aavegotchi\scraped_proposals_processed_part18.txt has been created with 40 lines.
# output file: ./Aavegotchi\scraped_proposals_processed_part19.txt
# File ./Aavegotchi\scraped_proposals_processed_part19.txt has been created with 40 lines.
# output file: ./Aavegotchi\scraped_proposals_processed_part20.txt
# File ./Aavegotchi\scraped_proposals_processed_part20.txt has been created with 40 lines.
# output file: ./Aavegotchi\scraped_proposals_processed_part21.txt
# File ./Aavegotchi\scraped_proposals_processed_part21.txt has been created with 40 lines.
# output file: ./Aavegotchi\scraped_proposals_processed_part22.txt
# File ./Aavegotchi\scraped_proposals_processed_part22.txt has been created with 40 lines.
# output file: ./Aavegotchi\scraped_proposals_processed_part23.txt
# File ./Aavegotchi\scraped_proposals_processed_part23.txt has been created with 40 lines.
# output file: ./Aavegotchi\scraped_proposals_processed_part24.txt
# File ./Aavegotchi\scraped_proposals_processed_part24.txt has been created with 40 lines.
# output file: ./Aavegotchi\scraped_proposals_processed_part25.txt
# File ./Aavegotchi\scraped_proposals_processed_part25.txt has been created with 40 lines.
# output file: ./Aavegotchi\scraped_proposals_processed_part26.txt
# File ./Aavegotchi\scraped_proposals_processed_part26.txt has been created with 40 lines.
# output file: ./Aavegotchi\scraped_proposals_processed_part27.txt
# File ./Aavegotchi\scraped_proposals_processed_part27.txt has been created with 40 lines.
# output file: ./Aavegotchi\scraped_proposals_processed_part28.txt
# File ./Aavegotchi\scraped_proposals_processed_part28.txt has been created with 40 lines.
# output file: ./Aavegotchi\scraped_proposals_processed_part29.txt
# File ./Aavegotchi\scraped_proposals_processed_part29.txt has been created with 40 lines.
# output file: ./Aavegotchi\scraped_proposals_processed_part30.txt
# File ./Aavegotchi\scraped_proposals_processed_part30.txt has been created with 40 lines.
# output file: ./Aavegotchi\scraped_proposals_processed_part31.txt
# File ./Aavegotchi\scraped_proposals_processed_part31.txt has been created with 40 lines.
# output file: ./Aavegotchi\scraped_proposals_processed_part32.txt
# File ./Aavegotchi\scraped_proposals_processed_part32.txt has been created with 40 lines.
# output file: ./Aavegotchi\scraped_proposals_processed_part33.txt
# File ./Aavegotchi\scraped_proposals_processed_part33.txt has been created with 40 lines.
# output file: ./Aavegotchi\scraped_proposals_processed_part34.txt
# File ./Aavegotchi\scraped_proposals_processed_part34.txt has been created with 40 lines.
# output file: ./Aavegotchi\scraped_proposals_processed_part35.txt
# File ./Aavegotchi\scraped_proposals_processed_part35.txt has been created with 40 lines.
# output file: ./Aavegotchi\scraped_proposals_processed_part36.txt
# File ./Aavegotchi\scraped_proposals_processed_part36.txt has been created with 40 lines.
# output file: ./Aavegotchi\scraped_proposals_processed_part37.txt
# File ./Aavegotchi\scraped_proposals_processed_part37.txt has been created with 40 lines.
# output file: ./Aavegotchi\scraped_proposals_processed_part38.txt
# File ./Aavegotchi\scraped_proposals_processed_part38.txt has been created with 40 lines.
# output file: ./Aavegotchi\scraped_proposals_processed_part39.txt
# File ./Aavegotchi\scraped_proposals_processed_part39.txt has been created with 40 lines.
# output file: ./Aavegotchi\scraped_proposals_processed_part40.txt
# File ./Aavegotchi\scraped_proposals_processed_part40.txt has been created with 40 lines.
# output file: ./Aavegotchi\scraped_proposals_processed_part41.txt
# File ./Aavegotchi\scraped_proposals_processed_part41.txt has been created with 40 lines.
# output file: ./Aavegotchi\scraped_proposals_processed_part42.txt
# File ./Aavegotchi\scraped_proposals_processed_part42.txt has been created with 40 lines.
# output file: ./Aavegotchi\scraped_proposals_processed_part43.txt
# File ./Aavegotchi\scraped_proposals_processed_part43.txt has been created with 40 lines.
# output file: ./Aavegotchi\scraped_proposals_processed_part44.txt
# File ./Aavegotchi\scraped_proposals_processed_part44.txt has been created with 40 lines.
# output file: ./Aavegotchi\scraped_proposals_processed_part45.txt
# File ./Aavegotchi\scraped_proposals_processed_part45.txt has been created with 40 lines.
# output file: ./Aavegotchi\scraped_proposals_processed_part46.txt
# File ./Aavegotchi\scraped_proposals_processed_part46.txt has been created with 40 lines.
# output file: ./Aavegotchi\scraped_proposals_processed_part47.txt
# File ./Aavegotchi\scraped_proposals_processed_part47.txt has been created with 40 lines.
# output file: ./Aavegotchi\scraped_proposals_processed_part48.txt
# File ./Aavegotchi\scraped_proposals_processed_part48.txt has been created with 40 lines.
# output file: ./Aavegotchi\scraped_proposals_processed_part49.txt
# File ./Aavegotchi\scraped_proposals_processed_part49.txt has been created with 40 lines.
# output file: ./Aavegotchi\scraped_proposals_processed_part50.txt
# File ./Aavegotchi\scraped_proposals_processed_part50.txt has been created with 40 lines.
# output file: ./Aavegotchi\scraped_proposals_processed_part51.txt
# File ./Aavegotchi\scraped_proposals_processed_part51.txt has been created with 40 lines.
# output file: ./Aavegotchi\scraped_proposals_processed_part52.txt
# File ./Aavegotchi\scraped_proposals_processed_part52.txt has been created with 40 lines.
# output file: ./Aavegotchi\scraped_proposals_processed_part53.txt
# File ./Aavegotchi\scraped_proposals_processed_part53.txt has been created with 40 lines.
# output file: ./Aavegotchi\scraped_proposals_processed_part54.txt
# File ./Aavegotchi\scraped_proposals_processed_part54.txt has been created with 40 lines.
# output file: ./Aavegotchi\scraped_proposals_processed_part55.txt
# File ./Aavegotchi\scraped_proposals_processed_part55.txt has been created with 40 lines.
# output file: ./Aavegotchi\scraped_proposals_processed_part56.txt
# File ./Aavegotchi\scraped_proposals_processed_part56.txt has been created with 40 lines.
# output file: ./Aavegotchi\scraped_proposals_processed_part57.txt
# File ./Aavegotchi\scraped_proposals_processed_part57.txt has been created with 40 lines.
# output file: ./Aavegotchi\scraped_proposals_processed_part58.txt
# File ./Aavegotchi\scraped_proposals_processed_part58.txt has been created with 40 lines.
# output file: ./Aavegotchi\scraped_proposals_processed_part59.txt
# File ./Aavegotchi\scraped_proposals_processed_part59.txt has been created with 40 lines.
# output file: ./Aavegotchi\scraped_proposals_processed_part60.txt
# File ./Aavegotchi\scraped_proposals_processed_part60.txt has been created with 40 lines.
# output file: ./Aavegotchi\scraped_proposals_processed_part61.txt
# File ./Aavegotchi\scraped_proposals_processed_part61.txt has been created with 40 lines.
# output file: ./Aavegotchi\scraped_proposals_processed_part62.txt
# File ./Aavegotchi\scraped_proposals_processed_part62.txt has been created with 40 lines.
# output file: ./Aavegotchi\scraped_proposals_processed_part63.txt
# File ./Aavegotchi\scraped_proposals_processed_part63.txt has been created with 40 lines.
# output file: ./Aavegotchi\scraped_proposals_processed_part64.txt
# File ./Aavegotchi\scraped_proposals_processed_part64.txt has been created with 40 lines.
# output file: ./Aavegotchi\scraped_proposals_processed_part65.txt
# File ./Aavegotchi\scraped_proposals_processed_part65.txt has been created with 40 lines.
# output file: ./Aavegotchi\scraped_proposals_processed_part66.txt
# File ./Aavegotchi\scraped_proposals_processed_part66.txt has been created with 40 lines.
# output file: ./Aavegotchi\scraped_proposals_processed_part67.txt
# File ./Aavegotchi\scraped_proposals_processed_part67.txt has been created with 40 lines.
# output file: ./Aavegotchi\scraped_proposals_processed_part68.txt
# File ./Aavegotchi\scraped_proposals_processed_part68.txt has been created with 40 lines.
# output file: ./Aavegotchi\scraped_proposals_processed_part69.txt
# File ./Aavegotchi\scraped_proposals_processed_part69.txt has been created with 40 lines.
# output file: ./Aavegotchi\scraped_proposals_processed_part70.txt
# File ./Aavegotchi\scraped_proposals_processed_part70.txt has been created with 40 lines.
# output file: ./Aavegotchi\scraped_proposals_processed_part71.txt
# File ./Aavegotchi\scraped_proposals_processed_part71.txt has been created with 40 lines.
# output file: ./Aavegotchi\scraped_proposals_processed_part72.txt
# File ./Aavegotchi\scraped_proposals_processed_part72.txt has been created with 40 lines.
# output file: ./Aavegotchi\scraped_proposals_processed_part73.txt
# File ./Aavegotchi\scraped_proposals_processed_part73.txt has been created with 40 lines.
# output file: ./Aavegotchi\scraped_proposals_processed_part74.txt
# File ./Aavegotchi\scraped_proposals_processed_part74.txt has been created with 40 lines.
# output file: ./Aavegotchi\scraped_proposals_processed_part75.txt
# File ./Aavegotchi\scraped_proposals_processed_part75.txt has been created with 40 lines.
# output file: ./Aavegotchi\scraped_proposals_processed_part76.txt
# File ./Aavegotchi\scraped_proposals_processed_part76.txt has been created with 40 lines.
# output file: ./Aavegotchi\scraped_proposals_processed_part77.txt
# File ./Aavegotchi\scraped_proposals_processed_part77.txt has been created with 40 lines.
# output file: ./Aavegotchi\scraped_proposals_processed_part78.txt
# File ./Aavegotchi\scraped_proposals_processed_part78.txt has been created with 40 lines.
# output file: ./Aavegotchi\scraped_proposals_processed_part79.txt
# File ./Aavegotchi\scraped_proposals_processed_part79.txt has been created with 40 lines.
# output file: ./Aavegotchi\scraped_proposals_processed_part80.txt
# File ./Aavegotchi\scraped_proposals_processed_part80.txt has been created with 40 lines.
# output file: ./Aavegotchi\scraped_proposals_processed_part81.txt
# File ./Aavegotchi\scraped_proposals_processed_part81.txt has been created with 40 lines.
# output file: ./Aavegotchi\scraped_proposals_processed_part82.txt
# File ./Aavegotchi\scraped_proposals_processed_part82.txt has been created with 40 lines.
# output file: ./Aavegotchi\scraped_proposals_processed_part83.txt
# File ./Aavegotchi\scraped_proposals_processed_part83.txt has been created with 40 lines.
# output file: ./Aavegotchi\scraped_proposals_processed_part84.txt
# File ./Aavegotchi\scraped_proposals_processed_part84.txt has been created with 40 lines.
# output file: ./Aavegotchi\scraped_proposals_processed_part85.txt
# File ./Aavegotchi\scraped_proposals_processed_part85.txt has been created with 40 lines.
# output file: ./Aavegotchi\scraped_proposals_processed_part86.txt
# File ./Aavegotchi\scraped_proposals_processed_part86.txt has been created with 40 lines.
# output file: ./Aavegotchi\scraped_proposals_processed_part87.txt
# File ./Aavegotchi\scraped_proposals_processed_part87.txt has been created with 40 lines.
# output file: ./Aavegotchi\scraped_proposals_processed_part88.txt
# File ./Aavegotchi\scraped_proposals_processed_part88.txt has been created with 40 lines.
# output file: ./Aavegotchi\scraped_proposals_processed_part89.txt
# File ./Aavegotchi\scraped_proposals_processed_part89.txt has been created with 40 lines.
# output file: ./Aavegotchi\scraped_proposals_processed_part90.txt
# File ./Aavegotchi\scraped_proposals_processed_part90.txt has been created with 40 lines.
# output file: ./Aavegotchi\scraped_proposals_processed_part91.txt
# File ./Aavegotchi\scraped_proposals_processed_part91.txt has been created with 40 lines.
# output file: ./Aavegotchi\scraped_proposals_processed_part92.txt
# File ./Aavegotchi\scraped_proposals_processed_part92.txt has been created with 40 lines.
# output file: ./Aavegotchi\scraped_proposals_processed_part93.txt
# File ./Aavegotchi\scraped_proposals_processed_part93.txt has been created with 40 lines.
# output file: ./Aavegotchi\scraped_proposals_processed_part94.txt
# File ./Aavegotchi\scraped_proposals_processed_part94.txt has been created with 40 lines.
# output file: ./Aavegotchi\scraped_proposals_processed_part95.txt
# File ./Aavegotchi\scraped_proposals_processed_part95.txt has been created with 6 lines.

# %%
len(jsons[0][1])
# Out:
# 166

# %%
jsons[0][1]
# Out:
#              Set Name                               Set Bonus  \
# 0             Aarcher                          BRS +1, AGG -1
# 1          Aastronaut                          BRS +1, SPK +1
# 2           Aave Hero                          BRS +1, SPK +1
# 3            ETH Maxi                          BRS +1, BRN -1
# 4              Farmer                          BRS +1, NRG -1
# ..                ...                                     ...
# 161     Jacob Maarley          BRS +8, NRG +1, SPK +3, BRN -1
# 162  Master Creatooor          BRS +8, NRG +1, SPK -2, BRN -2
# 163        ROFL Tamer                  BRS +8, NRG -3, BRN -2
# 164      Shogungotchi  BRS +8, NRG -1, AGG +1, SPK +2, BRN -1
# 165          VRF Lord                  BRS +8, NRG +3, BRN +2
#
#                                  Total Bonuses  Total  \
# 0                       BRS +4, NRG -1, AGG -3      8
# 1                               BRS +4, SPK +4      8
# 2                               BRS +4, SPK +4      8
# 3                               BRS +4, BRN -4      8
# 4               BRS +4, NRG -2, AGG +1, BRN -1      8
# ..                                         ...    ...
# 161          BRS +208, NRG +17, SPK +3, BRN -9    237
# 162         BRS +208, NRG +5, SPK -11, BRN -13    237
# 163                 BRS +208, NRG -16, BRN -13    237
# 164  BRS +208, NRG -4, AGG +9, SPK +12, BRN -4    237
# 165                 BRS +208, NRG +15, BRN +14    237
#
#                                              Wearables
# 0    [Brunette Ponytail (Common; BRS +1, AGG -1), L...
# 1    [Aastronaut Helmet (Common; BRS +1, SPK +1), A...
# 2    [Aave Hero Mask (Common; BRS +1, SPK +1), Aave...
# 3    [ETH Logo Glasses (Common; BRS +1, BRN -1), ET...
# 4    [Straw Hat (Common; BRS +1, NRG -1), Farmer Je...
# ..                                                 ...
# 161  [Heavenly Robes (Godlike; BRS +50, NRG +4, BRN...
# 162  [Staff of Creation (Godlike; BRS +50, SPK -3, ...
# 163  [All-Seeing Eyes (Godlike; BRS +50, NRG -6), G...
# 164  [Godlike Rofl (Godlike; BRS +50, NRG -3, BRN -...
# 165  [Galaxy Brain (Godlike; BRS +50, BRN +6), Link...
#
# [166 rows x 5 columns]

# %%
jsons[0][1]['message'] = jsons[0][1].apply(cohere_wearables, axis=1)
jsons[0][1]['message']
# Out:
# 0      Character Aarcher had a set bonus of BRS +1, A...
# 1      Character Aastronaut had a set bonus of BRS +1...
# 2      Character Aave Hero had a set bonus of BRS +1,...
# 3      Character ETH Maxi had a set bonus of BRS +1, ...
# 4      Character Farmer had a set bonus of BRS +1, NR...
#                              ...
# 161    Character Jacob Maarley had a set bonus of BRS...
# 162    Character Master Creatooor had a set bonus of ...
# 163    Character ROFL Tamer had a set bonus of BRS +8...
# 164    Character Shogungotchi had a set bonus of BRS ...
# 165    Character VRF Lord had a set bonus of BRS +8, ...
# Name: message, Length: 166, dtype: object

# %%
output_dir = './Aavegotchi'
for name, df in jsons:
    lists = df['message'].tolist()
    clean_and_split_data(name + "_json", lists, output_dir)
# Out:
# output file: ./Aavegotchi\gotchi_wearable_sets_json_processed_part1.txt
# File ./Aavegotchi\gotchi_wearable_sets_json_processed_part1.txt has been created with 40 lines.
# output file: ./Aavegotchi\gotchi_wearable_sets_json_processed_part2.txt
# File ./Aavegotchi\gotchi_wearable_sets_json_processed_part2.txt has been created with 40 lines.
# output file: ./Aavegotchi\gotchi_wearable_sets_json_processed_part3.txt
# File ./Aavegotchi\gotchi_wearable_sets_json_processed_part3.txt has been created with 40 lines.
# output file: ./Aavegotchi\gotchi_wearable_sets_json_processed_part4.txt
# File ./Aavegotchi\gotchi_wearable_sets_json_processed_part4.txt has been created with 40 lines.
# output file: ./Aavegotchi\gotchi_wearable_sets_json_processed_part5.txt
# File ./Aavegotchi\gotchi_wearable_sets_json_processed_part5.txt has been created with 6 lines.

# %%
# pd.read_json(f'{input_dir}/gotchi_wearable_sets.json')
