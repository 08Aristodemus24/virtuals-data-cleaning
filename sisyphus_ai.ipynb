# %%
import pandas as pd
import os
import json
import datetime as dt
from dateutil import parser 
import re
from concurrent.futures import ThreadPoolExecutor
from utilities.preprocessors import normalize_and_clean, extract_keys_values, clean_and_split_data

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
input_dir = './SisyphusAI input'
files = os.listdir(input_dir)
files
# Out:
# ['Dataset#5642tweets-sample.txt',
#  'Dataset#5643dataset_twitter-scraper_2024-11-02_16-42-39-127.json']

# %%
def read_json_files(input_dir: str, files: list[str]):
    def helper(file_name):
        with open(f'{input_dir}/{file_name}', 'r') as file:
            data = json.load(file)
            file.close()

        new_name = file_name.replace('.json', '')
        return new_name, data

    # concurrently read and load all .json files
    with ThreadPoolExecutor() as exe:
        jsons = dict(list(exe.map(helper, files)))
    return jsons

# %%
json_files = [file for file in files if file.endswith('.json')]
jsons = read_json_files(input_dir=input_dir, files=json_files)
jsons
# Out:
# {'Dataset#5643dataset_twitter-scraper_2024-11-02_16-42-39-127': [{'id': 0,
#    'location': '',
#    'conversation_id_str': '1424036915980943368',
#    'created_at': 'Sat Aug 07 15:57:12 +0000 2021',
#    'display_text_range': [0, 32],
#    'entities': {'user_mentions': [],
#     'urls': [],
#     'hashtags': [],
#     'symbols': [],
#     'media': []},
#    'favorite_count': 1148,
#    'favorited': False,
#    'full_text': 'One must imagine Sisyphus happy.',
#    'id_str': '1424036915980943368',
#    'lang': 'en',
#    'permalink': '/0xSisyphus/status/1424036915980943368',
#    'possibly_sensitive': False,
#    'quote_count': 25,
#    'reply_count': 218,
#    'retweet_count': 131,
#    'retweeted': False,
#    'text': 'One must imagine Sisyphus happy.',
#    'user': {'blocking': False,
#     'created_at': 'Wed Mar 03 01:58:19 +0000 2021',
#     'default_profile': True,
#     'default_profile_image': False,
#     'description': 'Roll boulder up hill, it rolls back down.',
#     'entities': {'description': {'urls': []}, 'url': {}},
#     'fast_followers_count': 0,
#     'favourites_count': 93910,
#     'follow_request_sent': False,
#     'followed_by': False,
#     'followers_count': 136966,
#     'following': False,
#     'friends_count': 400,
#     'has_custom_timelines': False,
#     'id': 0,
#     'id_str': '1366930865574584323',
#     'is_translator': False,
#     'listed_count': 3012,
#     'location': '',
#     'media_count': 1502,
#     'name': 'Sisyphus',
#     'normal_followers_count': 136966,
#     'notifications': False,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1366930865574584323/1628902848',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1749647387247693825/IGD_vcy6_normal.jpg',
#     'protected': False,
#     'screen_name': '0xSisyphus',
#     'show_all_inline_media': False,
#     'statuses_count': 34643,
#     'time_zone': '',
#     'translator_type': 'none',
#     'url': '',
#     'utc_offset': 0,
#     'verified': False,
#     'withheld_in_countries': [],
#     'withheld_scope': '',
#     'is_blue_verified': True},
#    'startUrl': 'https://twitter.com/0xSisyphus'},
#   {'id': 0,
#    'location': '',
#    'conversation_id_str': '1759743974711935094',
#    'created_at': 'Tue Feb 20 00:57:12 +0000 2024',
#    'display_text_range': [0, 118],
#    'entities': {'user_mentions': [],
#     'urls': [],
#     'hashtags': [],
#     'symbols': [],
#     'media': []},
#    'favorite_count': 72487,
#    'favorited': False,
#    'full_text': 'Do crackheads ever say, “I’m too broke to smoke crack tonight”?\n\nNo. They get up and make it happen.\n\nLesson in there.',
#    'id_str': '1759743974711935094',
#    'lang': 'en',
#    'permalink': '/0xSisyphus/status/1759743974711935094',
#    'possibly_sensitive': False,
#    'quote_count': 898,
#    'reply_count': 338,
#    'retweet_count': 13693,
#    'retweeted': False,
#    'text': 'Do crackheads ever say, “I’m too broke to smoke crack tonight”?\n\nNo. They get up and make it happen.\n\nLesson in there.',
#    'user': {'blocking': False,
#     'created_at': 'Wed Mar 03 01:58:19 +0000 2021',
#     'default_profile': True,
#     'default_profile_image': False,
#     'description': 'Roll boulder up hill, it rolls back down.',
#     'entities': {'description': {'urls': []}, 'url': {}},
#     'fast_followers_count': 0,
#     'favourites_count': 93910,
#     'follow_request_sent': False,
#     'followed_by': False,
#     'followers_count': 136966,
#     'following': False,
#     'friends_count': 400,
#     'has_custom_timelines': False,
#     'id': 0,
#     'id_str': '1366930865574584323',
#     'is_translator': False,
#     'listed_count': 3012,
#     'location': '',
#     'media_count': 1502,
#     'name': 'Sisyphus',
#     'normal_followers_count': 136966,
#     'notifications': False,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1366930865574584323/1628902848',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1749647387247693825/IGD_vcy6_normal.jpg',
#     'protected': False,
#     'screen_name': '0xSisyphus',
#     'show_all_inline_media': False,
#     'statuses_count': 34643,
#     'time_zone': '',
#     'translator_type': 'none',
#     'url': '',
#     'utc_offset': 0,
#     'verified': False,
#     'withheld_in_countries': [],
#     'withheld_scope': '',
#     'is_blue_verified': True},
#    'startUrl': 'https://twitter.com/0xSisyphus'},
#   {'id': 0,
#    'location': '',
#    'conversation_id_str': '1764650746119590063',
#    'created_at': 'Mon Mar 04 13:54:58 +0000 2024',
#    'display_text_range': [0, 55],
#    'entities': {'user_mentions': [],
#     'urls': [],
#     'hashtags': [],
#     'symbols': [],
#     'media': []},
#    'favorite_count': 9570,
#    'favorited': False,
#    'full_text': "I've fumbled generational wealth like 6 times this week",
#    'id_str': '1764650746119590063',
#    'lang': 'en',
#    'permalink': '/0xSisyphus/status/1764650746119590063',
#    'possibly_sensitive': False,
#    'quote_count': 105,
#    'reply_count': 200,
#    'retweet_count': 892,
#    'retweeted': False,
#    'text': "I've fumbled generational wealth like 6 times this week",
#    'user': {'blocking': False,
#     'created_at': 'Wed Mar 03 01:58:19 +0000 2021',
#     'default_profile': True,
#     'default_profile_image': False,
#     'description': 'Roll boulder up hill, it rolls back down.',
#     'entities': {'description': {'urls': []}, 'url': {}},
#     'fast_followers_count': 0,
#     'favourites_count': 93910,
#     'follow_request_sent': False,
#     'followed_by': False,
#     'followers_count': 136966,
#     'following': False,
#     'friends_count': 400,
#     'has_custom_timelines': False,
#     'id': 0,
#     'id_str': '1366930865574584323',
#     'is_translator': False,
#     'listed_count': 3012,
#     'location': '',
#     'media_count': 1502,
#     'name': 'Sisyphus',
#     'normal_followers_count': 136966,
#     'notifications': False,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1366930865574584323/1628902848',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1749647387247693825/IGD_vcy6_normal.jpg',
#     'protected': False,
#     'screen_name': '0xSisyphus',
#     'show_all_inline_media': False,
#     'statuses_count': 34643,
#     'time_zone': '',
#     'translator_type': 'none',
#     'url': '',
#     'utc_offset': 0,
#     'verified': False,
#     'withheld_in_countries': [],
#     'withheld_scope': '',
#     'is_blue_verified': True},
#    'startUrl': 'https://twitter.com/0xSisyphus'},
#   {'id': 0,
#    'location': '',
#    'conversation_id_str': '1746637532295479496',
#    'created_at': 'Sun Jan 14 20:56:53 +0000 2024',
#    'display_text_range': [0, 180],
#    'entities': {'user_mentions': [],
#     'urls': [],
#     'hashtags': [],
#     'symbols': [],
#     'media': []},
#    'favorite_count': 1221,
#    'favorited': False,
#    'full_text': "The most evergreen meme will always be the founder's pet\n\nIf Vitalik had a pet, the resultant coin would likely be in the top 20. We will simply have to get Raj's one there instead",
#    'id_str': '1746637532295479496',
#    'lang': 'en',
#    'permalink': '/0xSisyphus/status/1746637532295479496',
#    'possibly_sensitive': False,
#    'quote_count': 26,
#    'reply_count': 4702,
#    'retweet_count': 999,
#    'retweeted': False,
#    'text': "The most evergreen meme will always be the founder's pet\n\nIf Vitalik had a pet, the resultant coin would likely be in the top 20. We will simply have to get Raj's one there instead",
#    'user': {'blocking': False,
#     'created_at': 'Wed Mar 03 01:58:19 +0000 2021',
#     'default_profile': True,
#     'default_profile_image': False,
#     'description': 'Roll boulder up hill, it rolls back down.',
#     'entities': {'description': {'urls': []}, 'url': {}},
#     'fast_followers_count': 0,
#     'favourites_count': 93910,
#     'follow_request_sent': False,
#     'followed_by': False,
#     'followers_count': 136966,
#     'following': False,
#     'friends_count': 400,
#     'has_custom_timelines': False,
#     'id': 0,
#     'id_str': '1366930865574584323',
#     'is_translator': False,
#     'listed_count': 3012,
#     'location': '',
#     'media_count': 1502,
#     'name': 'Sisyphus',
#     'normal_followers_count': 136966,
#     'notifications': False,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1366930865574584323/1628902848',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1749647387247693825/IGD_vcy6_normal.jpg',
#     'protected': False,
#     'screen_name': '0xSisyphus',
#     'show_all_inline_media': False,
#     'statuses_count': 34643,
#     'time_zone': '',
#     'translator_type': 'none',
#     'url': '',
#     'utc_offset': 0,
#     'verified': False,
#     'withheld_in_countries': [],
#     'withheld_scope': '',
#     'is_blue_verified': True},
#    'startUrl': 'https://twitter.com/0xSisyphus'},
#   {'id': 0,
#    'location': '',
#    'conversation_id_str': '1442274497269223425',
#    'created_at': 'Sun Sep 26 23:46:50 +0000 2021',
#    'display_text_range': [0, 133],
#    'entities': {'user_mentions': [],
#     'urls': [],
#     'hashtags': [],
#     'symbols': [],
#     'media': [{'display_url': 'pic.x.com/xgTzfprftm',
#       'expanded_url': 'https://x.com/0xSisyphus/status/1442274497269223425/photo/1',
#       'id_str': '1442274378293645313',
#       'indices': [134, 157],
#       'media_key': '3_1442274378293645313',
#       'media_url_https': 'https://pbs.twimg.com/media/FAP859LXEAEBnfv.jpg',
#       'type': 'photo',
#       'url': 'https://t.co/xgTzfprftm',
#       'ext_media_availability': {'status': 'Available'},
#       'features': {'large': {'faces': []},
#        'medium': {'faces': []},
#        'small': {'faces': []},
#        'orig': {'faces': []}},
#       'sizes': {'large': {'h': 878, 'w': 1234, 'resize': 'fit'},
#        'medium': {'h': 854, 'w': 1200, 'resize': 'fit'},
#        'small': {'h': 484, 'w': 680, 'resize': 'fit'},
#        'thumb': {'h': 150, 'w': 150, 'resize': 'crop'}},
#       'original_info': {'height': 878,
#        'width': 1234,
#        'focus_rects': [{'x': 0, 'y': 187, 'w': 1234, 'h': 691},
#         {'x': 84, 'y': 0, 'w': 878, 'h': 878},
#         {'x': 138, 'y': 0, 'w': 770, 'h': 878},
#         {'x': 304, 'y': 0, 'w': 439, 'h': 878},
#         {'x': 0, 'y': 0, 'w': 1234, 'h': 878}]}}]},
#    'extended_entities': {'media': [{'display_url': 'pic.x.com/xgTzfprftm',
#       'expanded_url': 'https://x.com/0xSisyphus/status/1442274497269223425/photo/1',
#       'id_str': '1442274378293645313',
#       'indices': [134, 157],
#       'media_key': '3_1442274378293645313',
#       'media_url_https': 'https://pbs.twimg.com/media/FAP859LXEAEBnfv.jpg',
#       'type': 'photo',
#       'url': 'https://t.co/xgTzfprftm',
#       'ext_media_availability': {'status': 'Available'},
#       'features': {'large': {'faces': []},
#        'medium': {'faces': []},
#        'small': {'faces': []},
#        'orig': {'faces': []}},
#       'sizes': {'large': {'h': 878, 'w': 1234, 'resize': 'fit'},
#        'medium': {'h': 854, 'w': 1200, 'resize': 'fit'},
#        'small': {'h': 484, 'w': 680, 'resize': 'fit'},
#        'thumb': {'h': 150, 'w': 150, 'resize': 'crop'}},
#       'original_info': {'height': 878,
#        'width': 1234,
#        'focus_rects': [{'x': 0, 'y': 187, 'w': 1234, 'h': 691},
#         {'x': 84, 'y': 0, 'w': 878, 'h': 878},
#         {'x': 138, 'y': 0, 'w': 770, 'h': 878},
#         {'x': 304, 'y': 0, 'w': 439, 'h': 878},
#         {'x': 0, 'y': 0, 'w': 1234, 'h': 878}]}}]},
#    'favorite_count': 3771,
#    'favorited': False,
#    'full_text': 'some levels im watching on the 450-year chart for stocks\n\nthink pretty strong support at 1930s levels, if we break there back to 1812 https://t.co/xgTzfprftm',
#    'id_str': '1442274497269223425',
#    'lang': 'en',
#    'permalink': '/0xSisyphus/status/1442274497269223425',
#    'possibly_sensitive': False,
#    'quote_count': 121,
#    'reply_count': 140,
#    'retweet_count': 527,
#    'retweeted': False,
#    'text': 'some levels im watching on the 450-year chart for stocks\n\nthink pretty strong support at 1930s levels, if we break there back to 1812 https://t.co/xgTzfprftm',
#    'user': {'blocking': False,
#     'created_at': 'Wed Mar 03 01:58:19 +0000 2021',
#     'default_profile': True,
#     'default_profile_image': False,
#     'description': 'Roll boulder up hill, it rolls back down.',
#     'entities': {'description': {'urls': []}, 'url': {}},
#     'fast_followers_count': 0,
#     'favourites_count': 93910,
#     'follow_request_sent': False,
#     'followed_by': False,
#     'followers_count': 136966,
#     'following': False,
#     'friends_count': 400,
#     'has_custom_timelines': False,
#     'id': 0,
#     'id_str': '1366930865574584323',
#     'is_translator': False,
#     'listed_count': 3012,
#     'location': '',
#     'media_count': 1502,
#     'name': 'Sisyphus',
#     'normal_followers_count': 136966,
#     'notifications': False,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1366930865574584323/1628902848',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1749647387247693825/IGD_vcy6_normal.jpg',
#     'protected': False,
#     'screen_name': '0xSisyphus',
#     'show_all_inline_media': False,
#     'statuses_count': 34643,
#     'time_zone': '',
#     'translator_type': 'none',
#     'url': '',
#     'utc_offset': 0,
#     'verified': False,
#     'withheld_in_countries': [],
#     'withheld_scope': '',
#     'is_blue_verified': True},
#    'startUrl': 'https://twitter.com/0xSisyphus'},
#   {'id': 0,
#    'location': '',
#    'conversation_id_str': '1592329743671906304',
#    'created_at': 'Tue Nov 15 01:32:49 +0000 2022',
#    'display_text_range': [0, 159],
#    'entities': {'user_mentions': [],
#     'urls': [],
#     'hashtags': [],
#     'symbols': [],
#     'media': []},
#    'favorite_count': 3305,
#    'favorited': False,
#    'full_text': 'SBF mentions a video game in the NYT piece, called "Storybook Brawl" \n\nIt turns out FTX actually owns this game, he used the article as a promoted ad basically',
#    'id_str': '1592329743671906304',
#    'lang': 'en',
#    'permalink': '/0xSisyphus/status/1592329743671906304',
#    'possibly_sensitive': False,
#    'quote_count': 100,
#    'reply_count': 170,
#    'retweet_count': 264,
#    'retweeted': False,
#    'text': 'SBF mentions a video game in the NYT piece, called "Storybook Brawl" \n\nIt turns out FTX actually owns this game, he used the article as a promoted ad basically',
#    'user': {'blocking': False,
#     'created_at': 'Wed Mar 03 01:58:19 +0000 2021',
#     'default_profile': True,
#     'default_profile_image': False,
#     'description': 'Roll boulder up hill, it rolls back down.',
#     'entities': {'description': {'urls': []}, 'url': {}},
#     'fast_followers_count': 0,
#     'favourites_count': 93910,
#     'follow_request_sent': False,
#     'followed_by': False,
#     'followers_count': 136966,
#     'following': False,
#     'friends_count': 400,
#     'has_custom_timelines': False,
#     'id': 0,
#     'id_str': '1366930865574584323',
#     'is_translator': False,
#     'listed_count': 3012,
#     'location': '',
#     'media_count': 1502,
#     'name': 'Sisyphus',
#     'normal_followers_count': 136966,
#     'notifications': False,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1366930865574584323/1628902848',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1749647387247693825/IGD_vcy6_normal.jpg',
#     'protected': False,
#     'screen_name': '0xSisyphus',
#     'show_all_inline_media': False,
#     'statuses_count': 34643,
#     'time_zone': '',
#     'translator_type': 'none',
#     'url': '',
#     'utc_offset': 0,
#     'verified': False,
#     'withheld_in_countries': [],
#     'withheld_scope': '',
#     'is_blue_verified': True},
#    'startUrl': 'https://twitter.com/0xSisyphus'},
#   {'id': 0,
#    'location': '',
#    'conversation_id_str': '1593413144201904129',
#    'created_at': 'Fri Nov 18 01:17:52 +0000 2022',
#    'display_text_range': [0, 72],
#    'entities': {'user_mentions': [],
#     'urls': [],
#     'hashtags': [],
#     'symbols': [],
#     'media': [{'display_url': 'pic.x.com/aFhbuT2wyn',
#       'expanded_url': 'https://x.com/0xSisyphus/status/1593413144201904129/photo/1',
#       'id_str': '1593413140569522177',
#       'indices': [73, 96],
#       'media_key': '3_1593413140569522177',
#       'media_url_https': 'https://pbs.twimg.com/media/FhzwzyAWAAETTz-.jpg',
#       'type': 'photo',
#       'url': 'https://t.co/aFhbuT2wyn',
#       'ext_media_availability': {'status': 'Available'},
#       'features': {'large': {'faces': [{'x': 607, 'y': 188, 'h': 44, 'w': 44},
#          {'x': 508, 'y': 192, 'h': 44, 'w': 44},
#          {'x': 306, 'y': 145, 'h': 56, 'w': 56}]},
#        'medium': {'faces': [{'x': 607, 'y': 188, 'h': 44, 'w': 44},
#          {'x': 508, 'y': 192, 'h': 44, 'w': 44},
#          {'x': 306, 'y': 145, 'h': 56, 'w': 56}]},
#        'small': {'faces': [{'x': 607, 'y': 188, 'h': 44, 'w': 44},
#          {'x': 508, 'y': 192, 'h': 44, 'w': 44},
#          {'x': 306, 'y': 145, 'h': 56, 'w': 56}]},
#        'orig': {'faces': [{'x': 607, 'y': 188, 'h': 44, 'w': 44},
#          {'x': 508, 'y': 192, 'h': 44, 'w': 44},
#          {'x': 306, 'y': 145, 'h': 56, 'w': 56}]}},
#       'sizes': {'large': {'h': 336, 'w': 670, 'resize': 'fit'},
#        'medium': {'h': 336, 'w': 670, 'resize': 'fit'},
#        'small': {'h': 336, 'w': 670, 'resize': 'fit'},
#        'thumb': {'h': 150, 'w': 150, 'resize': 'crop'}},
#       'original_info': {'height': 336,
#        'width': 670,
#        'focus_rects': [{'x': 70, 'y': 0, 'w': 600, 'h': 336},
#         {'x': 334, 'y': 0, 'w': 336, 'h': 336},
#         {'x': 375, 'y': 0, 'w': 295, 'h': 336},
#         {'x': 502, 'y': 0, 'w': 168, 'h': 336},
#         {'x': 0, 'y': 0, 'w': 670, 'h': 336}]}}]},
#    'extended_entities': {'media': [{'display_url': 'pic.x.com/aFhbuT2wyn',
#       'expanded_url': 'https://x.com/0xSisyphus/status/1593413144201904129/photo/1',
#       'id_str': '1593413140569522177',
#       'indices': [73, 96],
#       'media_key': '3_1593413140569522177',
#       'media_url_https': 'https://pbs.twimg.com/media/FhzwzyAWAAETTz-.jpg',
#       'type': 'photo',
#       'url': 'https://t.co/aFhbuT2wyn',
#       'ext_media_availability': {'status': 'Available'},
#       'features': {'large': {'faces': [{'x': 607, 'y': 188, 'h': 44, 'w': 44},
#          {'x': 508, 'y': 192, 'h': 44, 'w': 44},
#          {'x': 306, 'y': 145, 'h': 56, 'w': 56}]},
#        'medium': {'faces': [{'x': 607, 'y': 188, 'h': 44, 'w': 44},
#          {'x': 508, 'y': 192, 'h': 44, 'w': 44},
#          {'x': 306, 'y': 145, 'h': 56, 'w': 56}]},
#        'small': {'faces': [{'x': 607, 'y': 188, 'h': 44, 'w': 44},
#          {'x': 508, 'y': 192, 'h': 44, 'w': 44},
#          {'x': 306, 'y': 145, 'h': 56, 'w': 56}]},
#        'orig': {'faces': [{'x': 607, 'y': 188, 'h': 44, 'w': 44},
#          {'x': 508, 'y': 192, 'h': 44, 'w': 44},
#          {'x': 306, 'y': 145, 'h': 56, 'w': 56}]}},
#       'sizes': {'large': {'h': 336, 'w': 670, 'resize': 'fit'},
#        'medium': {'h': 336, 'w': 670, 'resize': 'fit'},
#        'small': {'h': 336, 'w': 670, 'resize': 'fit'},
#        'thumb': {'h': 150, 'w': 150, 'resize': 'crop'}},
#       'original_info': {'height': 336,
#        'width': 670,
#        'focus_rects': [{'x': 70, 'y': 0, 'w': 600, 'h': 336},
#         {'x': 334, 'y': 0, 'w': 336, 'h': 336},
#         {'x': 375, 'y': 0, 'w': 295, 'h': 336},
#         {'x': 502, 'y': 0, 'w': 168, 'h': 336},
#         {'x': 0, 'y': 0, 'w': 670, 'h': 336}]}}]},
#    'favorite_count': 3153,
#    'favorited': False,
#    'full_text': 'The Bahamian Supreme Court is now one of the largest holders of Ethereum https://t.co/aFhbuT2wyn',
#    'id_str': '1593413144201904129',
#    'lang': 'en',
#    'permalink': '/0xSisyphus/status/1593413144201904129',
#    'possibly_sensitive': False,
#    'quote_count': 107,
#    'reply_count': 235,
#    'retweet_count': 270,
#    'retweeted': False,
#    'text': 'The Bahamian Supreme Court is now one of the largest holders of Ethereum https://t.co/aFhbuT2wyn',
#    'user': {'blocking': False,
#     'created_at': 'Wed Mar 03 01:58:19 +0000 2021',
#     'default_profile': True,
#     'default_profile_image': False,
#     'description': 'Roll boulder up hill, it rolls back down.',
#     'entities': {'description': {'urls': []}, 'url': {}},
#     'fast_followers_count': 0,
#     'favourites_count': 93910,
#     'follow_request_sent': False,
#     'followed_by': False,
#     'followers_count': 136966,
#     'following': False,
#     'friends_count': 400,
#     'has_custom_timelines': False,
#     'id': 0,
#     'id_str': '1366930865574584323',
#     'is_translator': False,
#     'listed_count': 3012,
#     'location': '',
#     'media_count': 1502,
#     'name': 'Sisyphus',
#     'normal_followers_count': 136966,
#     'notifications': False,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1366930865574584323/1628902848',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1749647387247693825/IGD_vcy6_normal.jpg',
#     'protected': False,
#     'screen_name': '0xSisyphus',
#     'show_all_inline_media': False,
#     'statuses_count': 34643,
#     'time_zone': '',
#     'translator_type': 'none',
#     'url': '',
#     'utc_offset': 0,
#     'verified': False,
#     'withheld_in_countries': [],
#     'withheld_scope': '',
#     'is_blue_verified': True},
#    'startUrl': 'https://twitter.com/0xSisyphus'},
#   {'id': 0,
#    'location': '',
#    'conversation_id_str': '1766836817167311262',
#    'created_at': 'Sun Mar 10 14:41:38 +0000 2024',
#    'display_text_range': [0, 119],
#    'entities': {'user_mentions': [],
#     'urls': [],
#     'hashtags': [],
#     'symbols': [],
#     'media': [{'display_url': 'pic.x.com/dixZE9hXgR',
#       'expanded_url': 'https://x.com/0xSisyphus/status/1766836817167311262/photo/1',
#       'id_str': '1766836807323258880',
#       'indices': [120, 143],
#       'media_key': '3_1766836807323258880',
#       'media_url_https': 'https://pbs.twimg.com/media/GIUQtxSWkAAsZxb.jpg',
#       'type': 'photo',
#       'url': 'https://t.co/dixZE9hXgR',
#       'ext_media_availability': {'status': 'Available'},
#       'features': {'large': {'faces': [{'x': 218,
#           'y': 191,
#           'h': 37,
#           'w': 37}]},
#        'medium': {'faces': [{'x': 218, 'y': 191, 'h': 37, 'w': 37}]},
#        'small': {'faces': [{'x': 218, 'y': 191, 'h': 37, 'w': 37}]},
#        'orig': {'faces': [{'x': 218, 'y': 191, 'h': 37, 'w': 37}]}},
#       'sizes': {'large': {'h': 500, 'w': 564, 'resize': 'fit'},
#        'medium': {'h': 500, 'w': 564, 'resize': 'fit'},
#        'small': {'h': 500, 'w': 564, 'resize': 'fit'},
#        'thumb': {'h': 150, 'w': 150, 'resize': 'crop'}},
#       'original_info': {'height': 500,
#        'width': 564,
#        'focus_rects': [{'x': 0, 'y': 25, 'w': 564, 'h': 316},
#         {'x': 64, 'y': 0, 'w': 500, 'h': 500},
#         {'x': 125, 'y': 0, 'w': 439, 'h': 500},
#         {'x': 314, 'y': 0, 'w': 250, 'h': 500},
#         {'x': 0, 'y': 0, 'w': 564, 'h': 500}]}}]},
#    'extended_entities': {'media': [{'display_url': 'pic.x.com/dixZE9hXgR',
#       'expanded_url': 'https://x.com/0xSisyphus/status/1766836817167311262/photo/1',
#       'id_str': '1766836807323258880',
#       'indices': [120, 143],
#       'media_key': '3_1766836807323258880',
#       'media_url_https': 'https://pbs.twimg.com/media/GIUQtxSWkAAsZxb.jpg',
#       'type': 'photo',
#       'url': 'https://t.co/dixZE9hXgR',
#       'ext_media_availability': {'status': 'Available'},
#       'features': {'large': {'faces': [{'x': 218,
#           'y': 191,
#           'h': 37,
#           'w': 37}]},
#        'medium': {'faces': [{'x': 218, 'y': 191, 'h': 37, 'w': 37}]},
#        'small': {'faces': [{'x': 218, 'y': 191, 'h': 37, 'w': 37}]},
#        'orig': {'faces': [{'x': 218, 'y': 191, 'h': 37, 'w': 37}]}},
#       'sizes': {'large': {'h': 500, 'w': 564, 'resize': 'fit'},
#        'medium': {'h': 500, 'w': 564, 'resize': 'fit'},
#        'small': {'h': 500, 'w': 564, 'resize': 'fit'},
#        'thumb': {'h': 150, 'w': 150, 'resize': 'crop'}},
#       'original_info': {'height': 500,
#        'width': 564,
#        'focus_rects': [{'x': 0, 'y': 25, 'w': 564, 'h': 316},
#         {'x': 64, 'y': 0, 'w': 500, 'h': 500},
#         {'x': 125, 'y': 0, 'w': 439, 'h': 500},
#         {'x': 314, 'y': 0, 'w': 250, 'h': 500},
#         {'x': 0, 'y': 0, 'w': 564, 'h': 500}]}}]},
#    'favorite_count': 2713,
#    'favorited': False,
#    'full_text': 'The key to cryptocurrency investing is to be the guy on the right (and sell for real world assets at appropriate times) https://t.co/dixZE9hXgR',
#    'id_str': '1766836817167311262',
#    'lang': 'en',
#    'permalink': '/0xSisyphus/status/1766836817167311262',
#    'possibly_sensitive': False,
#    'quote_count': 22,
#    'reply_count': 48,
#    'retweet_count': 300,
#    'retweeted': False,
#    'text': 'The key to cryptocurrency investing is to be the guy on the right (and sell for real world assets at appropriate times) https://t.co/dixZE9hXgR',
#    'user': {'blocking': False,
#     'created_at': 'Wed Mar 03 01:58:19 +0000 2021',
#     'default_profile': True,
#     'default_profile_image': False,
#     'description': 'Roll boulder up hill, it rolls back down.',
#     'entities': {'description': {'urls': []}, 'url': {}},
#     'fast_followers_count': 0,
#     'favourites_count': 93910,
#     'follow_request_sent': False,
#     'followed_by': False,
#     'followers_count': 136966,
#     'following': False,
#     'friends_count': 400,
#     'has_custom_timelines': False,
#     'id': 0,
#     'id_str': '1366930865574584323',
#     'is_translator': False,
#     'listed_count': 3012,
#     'location': '',
#     'media_count': 1502,
#     'name': 'Sisyphus',
#     'normal_followers_count': 136966,
#     'notifications': False,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1366930865574584323/1628902848',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1749647387247693825/IGD_vcy6_normal.jpg',
#     'protected': False,
#     'screen_name': '0xSisyphus',
#     'show_all_inline_media': False,
#     'statuses_count': 34643,
#     'time_zone': '',
#     'translator_type': 'none',
#     'url': '',
#     'utc_offset': 0,
#     'verified': False,
#     'withheld_in_countries': [],
#     'withheld_scope': '',
#     'is_blue_verified': True},
#    'startUrl': 'https://twitter.com/0xSisyphus'},
#   {'id': 0,
#    'location': '',
#    'conversation_id_str': '1590382073369747458',
#    'created_at': 'Wed Nov 09 16:33:28 +0000 2022',
#    'display_text_range': [0, 127],
#    'entities': {'user_mentions': [],
#     'urls': [],
#     'hashtags': [],
#     'symbols': [],
#     'media': []},
#    'favorite_count': 2240,
#    'favorited': False,
#    'full_text': 'FTX not disabling trading; remaining users are trading wildly with monopoly money, and it affects prices on all other exchanges',
#    'id_str': '1590382073369747458',
#    'lang': 'en',
#    'permalink': '/0xSisyphus/status/1590382073369747458',
#    'possibly_sensitive': False,
#    'quote_count': 35,
#    'reply_count': 89,
#    'retweet_count': 141,
#    'retweeted': False,
#    'text': 'FTX not disabling trading; remaining users are trading wildly with monopoly money, and it affects prices on all other exchanges',
#    'user': {'blocking': False,
#     'created_at': 'Wed Mar 03 01:58:19 +0000 2021',
#     'default_profile': True,
#     'default_profile_image': False,
#     'description': 'Roll boulder up hill, it rolls back down.',
#     'entities': {'description': {'urls': []}, 'url': {}},
#     'fast_followers_count': 0,
#     'favourites_count': 93910,
#     'follow_request_sent': False,
#     'followed_by': False,
#     'followers_count': 136966,
#     'following': False,
#     'friends_count': 400,
#     'has_custom_timelines': False,
#     'id': 0,
#     'id_str': '1366930865574584323',
#     'is_translator': False,
#     'listed_count': 3012,
#     'location': '',
#     'media_count': 1502,
#     'name': 'Sisyphus',
#     'normal_followers_count': 136966,
#     'notifications': False,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1366930865574584323/1628902848',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1749647387247693825/IGD_vcy6_normal.jpg',
#     'protected': False,
#     'screen_name': '0xSisyphus',
#     'show_all_inline_media': False,
#     'statuses_count': 34643,
#     'time_zone': '',
#     'translator_type': 'none',
#     'url': '',
#     'utc_offset': 0,
#     'verified': False,
#     'withheld_in_countries': [],
#     'withheld_scope': '',
#     'is_blue_verified': True},
#    'startUrl': 'https://twitter.com/0xSisyphus'},
#   {'id': 0,
#    'location': '',
#    'conversation_id_str': '1783654986150457728',
#    'created_at': 'Fri Apr 26 00:31:02 +0000 2024',
#    'display_text_range': [0, 261],
#    'entities': {'user_mentions': [],
#     'urls': [],
#     'hashtags': [],
#     'symbols': [],
#     'media': []},
#    'favorite_count': 2140,
#    'favorited': False,
#    'full_text': 'Memecoins are making people realize nearly all of the “tech” in crypto is a smokescreen designed to sell you a token that does nothing marked up 100x from the private round\n\nThis is why VC’s don’t like memecoins - it threatens their core business, selling vapor',
#    'id_str': '1783654986150457728',
#    'lang': 'en',
#    'permalink': '/0xSisyphus/status/1783654986150457728',
#    'possibly_sensitive': False,
#    'quote_count': 67,
#    'reply_count': 119,
#    'retweet_count': 337,
#    'retweeted': False,
#    'text': 'Memecoins are making people realize nearly all of the “tech” in crypto is a smokescreen designed to sell you a token that does nothing marked up 100x from the private round\n\nThis is why VC’s don’t like memecoins - it threatens their core business, selling vapor',
#    'user': {'blocking': False,
#     'created_at': 'Wed Mar 03 01:58:19 +0000 2021',
#     'default_profile': True,
#     'default_profile_image': False,
#     'description': 'Roll boulder up hill, it rolls back down.',
#     'entities': {'description': {'urls': []}, 'url': {}},
#     'fast_followers_count': 0,
#     'favourites_count': 93910,
#     'follow_request_sent': False,
#     'followed_by': False,
#     'followers_count': 136966,
#     'following': False,
#     'friends_count': 400,
#     'has_custom_timelines': False,
#     'id': 0,
#     'id_str': '1366930865574584323',
#     'is_translator': False,
#     'listed_count': 3012,
#     'location': '',
#     'media_count': 1502,
#     'name': 'Sisyphus',
#     'normal_followers_count': 136966,
#     'notifications': False,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1366930865574584323/1628902848',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1749647387247693825/IGD_vcy6_normal.jpg',
#     'protected': False,
#     'screen_name': '0xSisyphus',
#     'show_all_inline_media': False,
#     'statuses_count': 34643,
#     'time_zone': '',
#     'translator_type': 'none',
#     'url': '',
#     'utc_offset': 0,
#     'verified': False,
#     'withheld_in_countries': [],
#     'withheld_scope': '',
#     'is_blue_verified': True},
#    'startUrl': 'https://twitter.com/0xSisyphus'},
#   {'id': 0,
#    'location': '',
#    'conversation_id_str': '1787656909367148802',
#    'created_at': 'Tue May 07 01:33:14 +0000 2024',
#    'display_text_range': [0, 42],
#    'entities': {'user_mentions': [],
#     'urls': [],
#     'hashtags': [],
#     'symbols': [],
#     'media': [{'display_url': 'pic.x.com/553FYve9Nt',
#       'expanded_url': 'https://x.com/0xSisyphus/status/1787656909367148802/photo/1',
#       'id_str': '1787656885199675392',
#       'indices': [43, 66],
#       'media_key': '3_1787656885199675392',
#       'media_url_https': 'https://pbs.twimg.com/media/GM8IdzaboAAau7S.jpg',
#       'type': 'photo',
#       'url': 'https://t.co/553FYve9Nt',
#       'ext_media_availability': {'status': 'Available'},
#       'features': {'large': {'faces': []},
#        'medium': {'faces': []},
#        'small': {'faces': []},
#        'orig': {'faces': []}},
#       'sizes': {'large': {'h': 1283, 'w': 1179, 'resize': 'fit'},
#        'medium': {'h': 1200, 'w': 1103, 'resize': 'fit'},
#        'small': {'h': 680, 'w': 625, 'resize': 'fit'},
#        'thumb': {'h': 150, 'w': 150, 'resize': 'crop'}},
#       'original_info': {'height': 1283,
#        'width': 1179,
#        'focus_rects': [{'x': 0, 'y': 623, 'w': 1179, 'h': 660},
#         {'x': 0, 'y': 104, 'w': 1179, 'h': 1179},
#         {'x': 0, 'y': 0, 'w': 1125, 'h': 1283},
#         {'x': 0, 'y': 0, 'w': 642, 'h': 1283},
#         {'x': 0, 'y': 0, 'w': 1179, 'h': 1283}]}}]},
#    'extended_entities': {'media': [{'display_url': 'pic.x.com/553FYve9Nt',
#       'expanded_url': 'https://x.com/0xSisyphus/status/1787656909367148802/photo/1',
#       'id_str': '1787656885199675392',
#       'indices': [43, 66],
#       'media_key': '3_1787656885199675392',
#       'media_url_https': 'https://pbs.twimg.com/media/GM8IdzaboAAau7S.jpg',
#       'type': 'photo',
#       'url': 'https://t.co/553FYve9Nt',
#       'ext_media_availability': {'status': 'Available'},
#       'features': {'large': {'faces': []},
#        'medium': {'faces': []},
#        'small': {'faces': []},
#        'orig': {'faces': []}},
#       'sizes': {'large': {'h': 1283, 'w': 1179, 'resize': 'fit'},
#        'medium': {'h': 1200, 'w': 1103, 'resize': 'fit'},
#        'small': {'h': 680, 'w': 625, 'resize': 'fit'},
#        'thumb': {'h': 150, 'w': 150, 'resize': 'crop'}},
#       'original_info': {'height': 1283,
#        'width': 1179,
#        'focus_rects': [{'x': 0, 'y': 623, 'w': 1179, 'h': 660},
#         {'x': 0, 'y': 104, 'w': 1179, 'h': 1179},
#         {'x': 0, 'y': 0, 'w': 1125, 'h': 1283},
#         {'x': 0, 'y': 0, 'w': 642, 'h': 1283},
#         {'x': 0, 'y': 0, 'w': 1179, 'h': 1283}]}}]},
#    'favorite_count': 1755,
#    'favorited': False,
#    'full_text': 'The current state of the Solana blockchain https://t.co/553FYve9Nt',
#    'id_str': '1787656909367148802',
#    'lang': 'en',
#    'permalink': '/0xSisyphus/status/1787656909367148802',
#    'possibly_sensitive': False,
#    'quote_count': 23,
#    'reply_count': 79,
#    'retweet_count': 111,
#    'retweeted': False,
#    'text': 'The current state of the Solana blockchain https://t.co/553FYve9Nt',
#    'user': {'blocking': False,
#     'created_at': 'Wed Mar 03 01:58:19 +0000 2021',
#     'default_profile': True,
#     'default_profile_image': False,
#     'description': 'Roll boulder up hill, it rolls back down.',
#     'entities': {'description': {'urls': []}, 'url': {}},
#     'fast_followers_count': 0,
#     'favourites_count': 93910,
#     'follow_request_sent': False,
#     'followed_by': False,
#     'followers_count': 136966,
#     'following': False,
#     'friends_count': 400,
#     'has_custom_timelines': False,
#     'id': 0,
#     'id_str': '1366930865574584323',
#     'is_translator': False,
#     'listed_count': 3012,
#     'location': '',
#     'media_count': 1502,
#     'name': 'Sisyphus',
#     'normal_followers_count': 136966,
#     'notifications': False,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1366930865574584323/1628902848',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1749647387247693825/IGD_vcy6_normal.jpg',
#     'protected': False,
#     'screen_name': '0xSisyphus',
#     'show_all_inline_media': False,
#     'statuses_count': 34643,
#     'time_zone': '',
#     'translator_type': 'none',
#     'url': '',
#     'utc_offset': 0,
#     'verified': False,
#     'withheld_in_countries': [],
#     'withheld_scope': '',
#     'is_blue_verified': True},
#    'startUrl': 'https://twitter.com/0xSisyphus'},
#   {'id': 0,
#    'location': '',
#    'conversation_id_str': '1570077559995482114',
#    'created_at': 'Wed Sep 14 15:50:35 +0000 2022',
#    'display_text_range': [0, 11],
#    'entities': {'user_mentions': [],
#     'urls': [],
#     'hashtags': [],
#     'symbols': [],
#     'media': [{'display_url': 'pic.x.com/4q8ryqlTEj',
#       'expanded_url': 'https://x.com/0xSisyphus/status/1570077559995482114/photo/1',
#       'id_str': '1570077474595213314',
#       'indices': [12, 35],
#       'media_key': '3_1570077474595213314',
#       'media_url_https': 'https://pbs.twimg.com/media/FcoJJP8XEAIqhgG.png',
#       'type': 'photo',
#       'url': 'https://t.co/4q8ryqlTEj',
#       'ext_media_availability': {'status': 'Available'},
#       'features': {'large': {'faces': [{'x': 35, 'y': 17, 'h': 42, 'w': 42},
#          {'x': 539, 'y': 156, 'h': 63, 'w': 63},
#          {'x': 12, 'y': 183, 'h': 77, 'w': 77},
#          {'x': 357, 'y': 96, 'h': 114, 'w': 114}]},
#        'medium': {'faces': [{'x': 35, 'y': 17, 'h': 42, 'w': 42},
#          {'x': 539, 'y': 156, 'h': 63, 'w': 63},
#          {'x': 12, 'y': 183, 'h': 77, 'w': 77},
#          {'x': 357, 'y': 96, 'h': 114, 'w': 114}]},
#        'small': {'faces': [{'x': 35, 'y': 17, 'h': 42, 'w': 42},
#          {'x': 539, 'y': 156, 'h': 63, 'w': 63},
#          {'x': 12, 'y': 183, 'h': 77, 'w': 77},
#          {'x': 357, 'y': 96, 'h': 114, 'w': 114}]},
#        'orig': {'faces': [{'x': 35, 'y': 17, 'h': 42, 'w': 42},
#          {'x': 539, 'y': 156, 'h': 63, 'w': 63},
#          {'x': 12, 'y': 183, 'h': 77, 'w': 77},
#          {'x': 357, 'y': 96, 'h': 114, 'w': 114}]}},
#       'sizes': {'large': {'h': 374, 'w': 680, 'resize': 'fit'},
#        'medium': {'h': 374, 'w': 680, 'resize': 'fit'},
#        'small': {'h': 374, 'w': 680, 'resize': 'fit'},
#        'thumb': {'h': 150, 'w': 150, 'resize': 'crop'}},
#       'original_info': {'height': 374,
#        'width': 680,
#        'focus_rects': [{'x': 12, 'y': 0, 'w': 668, 'h': 374},
#         {'x': 238, 'y': 0, 'w': 374, 'h': 374},
#         {'x': 261, 'y': 0, 'w': 328, 'h': 374},
#         {'x': 332, 'y': 0, 'w': 187, 'h': 374},
#         {'x': 0, 'y': 0, 'w': 680, 'h': 374}]}}]},
#    'extended_entities': {'media': [{'display_url': 'pic.x.com/4q8ryqlTEj',
#       'expanded_url': 'https://x.com/0xSisyphus/status/1570077559995482114/photo/1',
#       'id_str': '1570077474595213314',
#       'indices': [12, 35],
#       'media_key': '3_1570077474595213314',
#       'media_url_https': 'https://pbs.twimg.com/media/FcoJJP8XEAIqhgG.png',
#       'type': 'photo',
#       'url': 'https://t.co/4q8ryqlTEj',
#       'ext_media_availability': {'status': 'Available'},
#       'features': {'large': {'faces': [{'x': 35, 'y': 17, 'h': 42, 'w': 42},
#          {'x': 539, 'y': 156, 'h': 63, 'w': 63},
#          {'x': 12, 'y': 183, 'h': 77, 'w': 77},
#          {'x': 357, 'y': 96, 'h': 114, 'w': 114}]},
#        'medium': {'faces': [{'x': 35, 'y': 17, 'h': 42, 'w': 42},
#          {'x': 539, 'y': 156, 'h': 63, 'w': 63},
#          {'x': 12, 'y': 183, 'h': 77, 'w': 77},
#          {'x': 357, 'y': 96, 'h': 114, 'w': 114}]},
#        'small': {'faces': [{'x': 35, 'y': 17, 'h': 42, 'w': 42},
#          {'x': 539, 'y': 156, 'h': 63, 'w': 63},
#          {'x': 12, 'y': 183, 'h': 77, 'w': 77},
#          {'x': 357, 'y': 96, 'h': 114, 'w': 114}]},
#        'orig': {'faces': [{'x': 35, 'y': 17, 'h': 42, 'w': 42},
#          {'x': 539, 'y': 156, 'h': 63, 'w': 63},
#          {'x': 12, 'y': 183, 'h': 77, 'w': 77},
#          {'x': 357, 'y': 96, 'h': 114, 'w': 114}]}},
#       'sizes': {'large': {'h': 374, 'w': 680, 'resize': 'fit'},
#        'medium': {'h': 374, 'w': 680, 'resize': 'fit'},
#        'small': {'h': 374, 'w': 680, 'resize': 'fit'},
#        'thumb': {'h': 150, 'w': 150, 'resize': 'crop'}},
#       'original_info': {'height': 374,
#        'width': 680,
#        'focus_rects': [{'x': 12, 'y': 0, 'w': 668, 'h': 374},
#         {'x': 238, 'y': 0, 'w': 374, 'h': 374},
#         {'x': 261, 'y': 0, 'w': 328, 'h': 374},
#         {'x': 332, 'y': 0, 'w': 187, 'h': 374},
#         {'x': 0, 'y': 0, 'w': 680, 'h': 374}]}}]},
#    'favorite_count': 1616,
#    'favorited': False,
#    'full_text': 'CANNON TIME https://t.co/4q8ryqlTEj',
#    'id_str': '1570077559995482114',
#    'lang': 'en',
#    'permalink': '/0xSisyphus/status/1570077559995482114',
#    'possibly_sensitive': False,
#    'quote_count': 9,
#    'reply_count': 43,
#    'retweet_count': 182,
#    'retweeted': False,
#    'text': 'CANNON TIME https://t.co/4q8ryqlTEj',
#    'user': {'blocking': False,
#     'created_at': 'Wed Mar 03 01:58:19 +0000 2021',
#     'default_profile': True,
#     'default_profile_image': False,
#     'description': 'Roll boulder up hill, it rolls back down.',
#     'entities': {'description': {'urls': []}, 'url': {}},
#     'fast_followers_count': 0,
#     'favourites_count': 93910,
#     'follow_request_sent': False,
#     'followed_by': False,
#     'followers_count': 136966,
#     'following': False,
#     'friends_count': 400,
#     'has_custom_timelines': False,
#     'id': 0,
#     'id_str': '1366930865574584323',
#     'is_translator': False,
#     'listed_count': 3012,
#     'location': '',
#     'media_count': 1502,
#     'name': 'Sisyphus',
#     'normal_followers_count': 136966,
#     'notifications': False,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1366930865574584323/1628902848',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1749647387247693825/IGD_vcy6_normal.jpg',
#     'protected': False,
#     'screen_name': '0xSisyphus',
#     'show_all_inline_media': False,
#     'statuses_count': 34643,
#     'time_zone': '',
#     'translator_type': 'none',
#     'url': '',
#     'utc_offset': 0,
#     'verified': False,
#     'withheld_in_countries': [],
#     'withheld_scope': '',
#     'is_blue_verified': True},
#    'startUrl': 'https://twitter.com/0xSisyphus'},
#   {'id': 0,
#    'location': '',
#    'conversation_id_str': '1592286050105192451',
#    'created_at': 'Mon Nov 14 22:39:12 +0000 2022',
#    'display_text_range': [0, 229],
#    'entities': {'user_mentions': [],
#     'urls': [],
#     'hashtags': [],
#     'symbols': [],
#     'media': []},
#    'favorite_count': 1463,
#    'favorited': False,
#    'full_text': 'The NYT article reads as narrative and information control\n\nIt would be very bad for the industry, but good for SBF, if US based non crypto natives believed Binance was responsible for FTX/Alameda losing billions in user deposits',
#    'id_str': '1592286050105192451',
#    'lang': 'en',
#    'permalink': '/0xSisyphus/status/1592286050105192451',
#    'possibly_sensitive': False,
#    'quote_count': 19,
#    'reply_count': 133,
#    'retweet_count': 111,
#    'retweeted': False,
#    'text': 'The NYT article reads as narrative and information control\n\nIt would be very bad for the industry, but good for SBF, if US based non crypto natives believed Binance was responsible for FTX/Alameda losing billions in user deposits',
#    'user': {'blocking': False,
#     'created_at': 'Wed Mar 03 01:58:19 +0000 2021',
#     'default_profile': True,
#     'default_profile_image': False,
#     'description': 'Roll boulder up hill, it rolls back down.',
#     'entities': {'description': {'urls': []}, 'url': {}},
#     'fast_followers_count': 0,
#     'favourites_count': 93910,
#     'follow_request_sent': False,
#     'followed_by': False,
#     'followers_count': 136966,
#     'following': False,
#     'friends_count': 400,
#     'has_custom_timelines': False,
#     'id': 0,
#     'id_str': '1366930865574584323',
#     'is_translator': False,
#     'listed_count': 3012,
#     'location': '',
#     'media_count': 1502,
#     'name': 'Sisyphus',
#     'normal_followers_count': 136966,
#     'notifications': False,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1366930865574584323/1628902848',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1749647387247693825/IGD_vcy6_normal.jpg',
#     'protected': False,
#     'screen_name': '0xSisyphus',
#     'show_all_inline_media': False,
#     'statuses_count': 34643,
#     'time_zone': '',
#     'translator_type': 'none',
#     'url': '',
#     'utc_offset': 0,
#     'verified': False,
#     'withheld_in_countries': [],
#     'withheld_scope': '',
#     'is_blue_verified': True},
#    'startUrl': 'https://twitter.com/0xSisyphus'},
#   {'id': 0,
#    'location': '',
#    'conversation_id_str': '1537078915595919362',
#    'created_at': 'Wed Jun 15 14:25:45 +0000 2022',
#    'display_text_range': [0, 0],
#    'entities': {'user_mentions': [],
#     'urls': [],
#     'hashtags': [],
#     'symbols': [],
#     'media': [{'display_url': 'pic.x.com/URDGPGDA2d',
#       'expanded_url': 'https://x.com/0xSisyphus/status/1537078915595919362/photo/1',
#       'id_str': '1537078908000034816',
#       'indices': [0, 23],
#       'media_key': '3_1537078908000034816',
#       'media_url_https': 'https://pbs.twimg.com/media/FVTNH38WYAA2uj1.png',
#       'type': 'photo',
#       'url': 'https://t.co/URDGPGDA2d',
#       'ext_media_availability': {'status': 'Available'},
#       'features': {'large': {'faces': []},
#        'medium': {'faces': []},
#        'small': {'faces': []},
#        'orig': {'faces': []}},
#       'sizes': {'large': {'h': 1223, 'w': 1280, 'resize': 'fit'},
#        'medium': {'h': 1147, 'w': 1200, 'resize': 'fit'},
#        'small': {'h': 650, 'w': 680, 'resize': 'fit'},
#        'thumb': {'h': 150, 'w': 150, 'resize': 'crop'}},
#       'original_info': {'height': 1223,
#        'width': 1280,
#        'focus_rects': [{'x': 0, 'y': 121, 'w': 1280, 'h': 717},
#         {'x': 57, 'y': 0, 'w': 1223, 'h': 1223},
#         {'x': 207, 'y': 0, 'w': 1073, 'h': 1223},
#         {'x': 557, 'y': 0, 'w': 612, 'h': 1223},
#         {'x': 0, 'y': 0, 'w': 1280, 'h': 1223}]}}]},
#    'extended_entities': {'media': [{'display_url': 'pic.x.com/URDGPGDA2d',
#       'expanded_url': 'https://x.com/0xSisyphus/status/1537078915595919362/photo/1',
#       'id_str': '1537078908000034816',
#       'indices': [0, 23],
#       'media_key': '3_1537078908000034816',
#       'media_url_https': 'https://pbs.twimg.com/media/FVTNH38WYAA2uj1.png',
#       'type': 'photo',
#       'url': 'https://t.co/URDGPGDA2d',
#       'ext_media_availability': {'status': 'Available'},
#       'features': {'large': {'faces': []},
#        'medium': {'faces': []},
#        'small': {'faces': []},
#        'orig': {'faces': []}},
#       'sizes': {'large': {'h': 1223, 'w': 1280, 'resize': 'fit'},
#        'medium': {'h': 1147, 'w': 1200, 'resize': 'fit'},
#        'small': {'h': 650, 'w': 680, 'resize': 'fit'},
#        'thumb': {'h': 150, 'w': 150, 'resize': 'crop'}},
#       'original_info': {'height': 1223,
#        'width': 1280,
#        'focus_rects': [{'x': 0, 'y': 121, 'w': 1280, 'h': 717},
#         {'x': 57, 'y': 0, 'w': 1223, 'h': 1223},
#         {'x': 207, 'y': 0, 'w': 1073, 'h': 1223},
#         {'x': 557, 'y': 0, 'w': 612, 'h': 1223},
#         {'x': 0, 'y': 0, 'w': 1280, 'h': 1223}]}}]},
#    'favorite_count': 1470,
#    'favorited': False,
#    'full_text': 'https://t.co/URDGPGDA2d',
#    'id_str': '1537078915595919362',
#    'lang': 'zxx',
#    'permalink': '/0xSisyphus/status/1537078915595919362',
#    'possibly_sensitive': False,
#    'quote_count': 23,
#    'reply_count': 19,
#    'retweet_count': 225,
#    'retweeted': False,
#    'text': 'https://t.co/URDGPGDA2d',
#    'user': {'blocking': False,
#     'created_at': 'Wed Mar 03 01:58:19 +0000 2021',
#     'default_profile': True,
#     'default_profile_image': False,
#     'description': 'Roll boulder up hill, it rolls back down.',
#     'entities': {'description': {'urls': []}, 'url': {}},
#     'fast_followers_count': 0,
#     'favourites_count': 93910,
#     'follow_request_sent': False,
#     'followed_by': False,
#     'followers_count': 136966,
#     'following': False,
#     'friends_count': 400,
#     'has_custom_timelines': False,
#     'id': 0,
#     'id_str': '1366930865574584323',
#     'is_translator': False,
#     'listed_count': 3012,
#     'location': '',
#     'media_count': 1502,
#     'name': 'Sisyphus',
#     'normal_followers_count': 136966,
#     'notifications': False,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1366930865574584323/1628902848',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1749647387247693825/IGD_vcy6_normal.jpg',
#     'protected': False,
#     'screen_name': '0xSisyphus',
#     'show_all_inline_media': False,
#     'statuses_count': 34643,
#     'time_zone': '',
#     'translator_type': 'none',
#     'url': '',
#     'utc_offset': 0,
#     'verified': False,
#     'withheld_in_countries': [],
#     'withheld_scope': '',
#     'is_blue_verified': True},
#    'startUrl': 'https://twitter.com/0xSisyphus'},
#   {'id': 0,
#    'location': '',
#    'conversation_id_str': '1423333805880979456',
#    'created_at': 'Thu Aug 05 17:23:18 +0000 2021',
#    'display_text_range': [0, 43],
#    'entities': {'user_mentions': [],
#     'urls': [],
#     'hashtags': [],
#     'symbols': [],
#     'media': [{'display_url': 'pic.x.com/vGi0dBtsmO',
#       'expanded_url': 'https://x.com/0xSisyphus/status/1423333805880979456/photo/1',
#       'id_str': '1423333797035188232',
#       'indices': [44, 67],
#       'media_key': '3_1423333797035188232',
#       'media_url_https': 'https://pbs.twimg.com/media/E8CyjBkXIAgB0uk.png',
#       'type': 'photo',
#       'url': 'https://t.co/vGi0dBtsmO',
#       'ext_media_availability': {'status': 'Available'},
#       'features': {'large': {'faces': []},
#        'medium': {'faces': []},
#        'small': {'faces': []},
#        'orig': {'faces': []}},
#       'sizes': {'large': {'h': 486, 'w': 512, 'resize': 'fit'},
#        'medium': {'h': 486, 'w': 512, 'resize': 'fit'},
#        'small': {'h': 486, 'w': 512, 'resize': 'fit'},
# ...
#     'normal_followers_count': 136966,
#     'notifications': False,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1366930865574584323/1628902848',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1749647387247693825/IGD_vcy6_normal.jpg',
#     'protected': False,
#     'screen_name': '0xSisyphus',
#     'show_all_inline_media': False,
#     'statuses_count': 34643,
#     'time_zone': '',
#     'translator_type': 'none',
#     'url': '',
#     'utc_offset': 0,
#     'verified': False,
#     'withheld_in_countries': [],
#     'withheld_scope': '',
#     'is_blue_verified': True},
#    'startUrl': 'https://twitter.com/0xSisyphus'},
#   {'id': 0,
#    'location': '',
#    'conversation_id_str': '1686205146320056320',
#    'created_at': 'Tue Aug 01 02:40:09 +0000 2023',
#    'display_text_range': [0, 280],
#    'entities': {'user_mentions': [],
#     'urls': [],
#     'hashtags': [],
#     'symbols': [],
#     'media': []},
#    'favorite_count': 584,
#    'favorited': False,
#    'full_text': "Base chain today, in summary:\n\n- everyone bridged to chase a coin made by either SBF or a close associate, which then rugged \n- shortly thereafter, the primary DEX on the chain had an exploit where all LP positions could be drained and halted trading\n- you still can't bridge back",
#    'id_str': '1686205146320056320',
#    'lang': 'en',
#    'permalink': '/0xSisyphus/status/1686205146320056320',
#    'possibly_sensitive': False,
#    'quote_count': 21,
#    'reply_count': 40,
#    'retweet_count': 45,
#    'retweeted': False,
#    'text': "Base chain today, in summary:\n\n- everyone bridged to chase a coin made by either SBF or a close associate, which then rugged \n- shortly thereafter, the primary DEX on the chain had an exploit where all LP positions could be drained and halted trading\n- you still can't bridge back",
#    'user': {'blocking': False,
#     'created_at': 'Wed Mar 03 01:58:19 +0000 2021',
#     'default_profile': True,
#     'default_profile_image': False,
#     'description': 'Roll boulder up hill, it rolls back down.',
#     'entities': {'description': {'urls': []}, 'url': {}},
#     'fast_followers_count': 0,
#     'favourites_count': 93910,
#     'follow_request_sent': False,
#     'followed_by': False,
#     'followers_count': 136966,
#     'following': False,
#     'friends_count': 400,
#     'has_custom_timelines': False,
#     'id': 0,
#     'id_str': '1366930865574584323',
#     'is_translator': False,
#     'listed_count': 3012,
#     'location': '',
#     'media_count': 1502,
#     'name': 'Sisyphus',
#     'normal_followers_count': 136966,
#     'notifications': False,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1366930865574584323/1628902848',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1749647387247693825/IGD_vcy6_normal.jpg',
#     'protected': False,
#     'screen_name': '0xSisyphus',
#     'show_all_inline_media': False,
#     'statuses_count': 34643,
#     'time_zone': '',
#     'translator_type': 'none',
#     'url': '',
#     'utc_offset': 0,
#     'verified': False,
#     'withheld_in_countries': [],
#     'withheld_scope': '',
#     'is_blue_verified': True},
#    'startUrl': 'https://twitter.com/0xSisyphus'},
#   {'id': 0,
#    'location': '',
#    'conversation_id_str': '1682469208217595904',
#    'created_at': 'Fri Jul 21 19:14:52 +0000 2023',
#    'display_text_range': [0, 104],
#    'entities': {'user_mentions': [],
#     'urls': [],
#     'hashtags': [],
#     'symbols': [],
#     'media': []},
#    'favorite_count': 593,
#    'favorited': False,
#    'full_text': 'what if there was a way to race crypto currencies\n\nlike you make money if the price of the token goes up',
#    'id_str': '1682469208217595904',
#    'lang': 'en',
#    'permalink': '/0xSisyphus/status/1682469208217595904',
#    'possibly_sensitive': False,
#    'quote_count': 9,
#    'reply_count': 77,
#    'retweet_count': 24,
#    'retweeted': False,
#    'text': 'what if there was a way to race crypto currencies\n\nlike you make money if the price of the token goes up',
#    'user': {'blocking': False,
#     'created_at': 'Wed Mar 03 01:58:19 +0000 2021',
#     'default_profile': True,
#     'default_profile_image': False,
#     'description': 'Roll boulder up hill, it rolls back down.',
#     'entities': {'description': {'urls': []}, 'url': {}},
#     'fast_followers_count': 0,
#     'favourites_count': 93910,
#     'follow_request_sent': False,
#     'followed_by': False,
#     'followers_count': 136966,
#     'following': False,
#     'friends_count': 400,
#     'has_custom_timelines': False,
#     'id': 0,
#     'id_str': '1366930865574584323',
#     'is_translator': False,
#     'listed_count': 3012,
#     'location': '',
#     'media_count': 1502,
#     'name': 'Sisyphus',
#     'normal_followers_count': 136966,
#     'notifications': False,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1366930865574584323/1628902848',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1749647387247693825/IGD_vcy6_normal.jpg',
#     'protected': False,
#     'screen_name': '0xSisyphus',
#     'show_all_inline_media': False,
#     'statuses_count': 34643,
#     'time_zone': '',
#     'translator_type': 'none',
#     'url': '',
#     'utc_offset': 0,
#     'verified': False,
#     'withheld_in_countries': [],
#     'withheld_scope': '',
#     'is_blue_verified': True},
#    'startUrl': 'https://twitter.com/0xSisyphus'},
#   {'id': 0,
#    'location': '',
#    'conversation_id_str': '1757118991858856193',
#    'created_at': 'Mon Feb 12 19:06:28 +0000 2024',
#    'display_text_range': [0, 70],
#    'entities': {'user_mentions': [],
#     'urls': [],
#     'hashtags': [],
#     'symbols': [],
#     'media': []},
#    'favorite_count': 588,
#    'favorited': False,
#    'full_text': 'the whole world will soon rely on gambling to make ends meet\n\nretardio',
#    'id_str': '1757118991858856193',
#    'lang': 'en',
#    'permalink': '/0xSisyphus/status/1757118991858856193',
#    'possibly_sensitive': False,
#    'quote_count': 4,
#    'reply_count': 28,
#    'retweet_count': 49,
#    'retweeted': False,
#    'text': 'the whole world will soon rely on gambling to make ends meet\n\nretardio',
#    'user': {'blocking': False,
#     'created_at': 'Wed Mar 03 01:58:19 +0000 2021',
#     'default_profile': True,
#     'default_profile_image': False,
#     'description': 'Roll boulder up hill, it rolls back down.',
#     'entities': {'description': {'urls': []}, 'url': {}},
#     'fast_followers_count': 0,
#     'favourites_count': 93910,
#     'follow_request_sent': False,
#     'followed_by': False,
#     'followers_count': 136966,
#     'following': False,
#     'friends_count': 400,
#     'has_custom_timelines': False,
#     'id': 0,
#     'id_str': '1366930865574584323',
#     'is_translator': False,
#     'listed_count': 3012,
#     'location': '',
#     'media_count': 1502,
#     'name': 'Sisyphus',
#     'normal_followers_count': 136966,
#     'notifications': False,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1366930865574584323/1628902848',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1749647387247693825/IGD_vcy6_normal.jpg',
#     'protected': False,
#     'screen_name': '0xSisyphus',
#     'show_all_inline_media': False,
#     'statuses_count': 34643,
#     'time_zone': '',
#     'translator_type': 'none',
#     'url': '',
#     'utc_offset': 0,
#     'verified': False,
#     'withheld_in_countries': [],
#     'withheld_scope': '',
#     'is_blue_verified': True},
#    'startUrl': 'https://twitter.com/0xSisyphus'},
#   {'id': 0,
#    'location': '',
#    'conversation_id_str': '1748831107103994286',
#    'created_at': 'Sat Jan 20 22:13:22 +0000 2024',
#    'display_text_range': [0, 268],
#    'entities': {'user_mentions': [],
#     'urls': [],
#     'hashtags': [],
#     'symbols': [],
#     'media': []},
#    'favorite_count': 573,
#    'favorited': False,
#    'full_text': 'Crypto Youtube is an underrated pathway for finding coins\n\nMost of the video content doesnt make its way back to CT and targets a diff userbase with a position size that is perfect for Solana\n\nThe guy who told the world to buy $1 of BTC at $0.10c is now buying "ponke"',
#    'id_str': '1748831107103994286',
#    'lang': 'en',
#    'permalink': '/0xSisyphus/status/1748831107103994286',
#    'possibly_sensitive': False,
#    'quote_count': 5,
#    'reply_count': 99,
#    'retweet_count': 83,
#    'retweeted': False,
#    'text': 'Crypto Youtube is an underrated pathway for finding coins\n\nMost of the video content doesnt make its way back to CT and targets a diff userbase with a position size that is perfect for Solana\n\nThe guy who told the world to buy $1 of BTC at $0.10c is now buying "ponke"',
#    'user': {'blocking': False,
#     'created_at': 'Wed Mar 03 01:58:19 +0000 2021',
#     'default_profile': True,
#     'default_profile_image': False,
#     'description': 'Roll boulder up hill, it rolls back down.',
#     'entities': {'description': {'urls': []}, 'url': {}},
#     'fast_followers_count': 0,
#     'favourites_count': 93910,
#     'follow_request_sent': False,
#     'followed_by': False,
#     'followers_count': 136966,
#     'following': False,
#     'friends_count': 400,
#     'has_custom_timelines': False,
#     'id': 0,
#     'id_str': '1366930865574584323',
#     'is_translator': False,
#     'listed_count': 3012,
#     'location': '',
#     'media_count': 1502,
#     'name': 'Sisyphus',
#     'normal_followers_count': 136966,
#     'notifications': False,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1366930865574584323/1628902848',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1749647387247693825/IGD_vcy6_normal.jpg',
#     'protected': False,
#     'screen_name': '0xSisyphus',
#     'show_all_inline_media': False,
#     'statuses_count': 34643,
#     'time_zone': '',
#     'translator_type': 'none',
#     'url': '',
#     'utc_offset': 0,
#     'verified': False,
#     'withheld_in_countries': [],
#     'withheld_scope': '',
#     'is_blue_verified': True},
#    'is_quote_status': True,
#    'quoted_status': {'id': 0,
#     'location': '',
#     'conversation_id_str': '1748784614829687284',
#     'created_at': 'Sat Jan 20 19:08:37 +0000 2024',
#     'display_text_range': [0, 72],
#     'entities': {'user_mentions': [],
#      'urls': [],
#      'hashtags': [],
#      'symbols': [{'indices': [32, 38], 'text': 'PONKE'}],
#      'media': [{'display_url': 'pic.x.com/UrNZePJcDd',
#        'expanded_url': 'https://x.com/Davincij15/status/1748784614829687284/video/1',
#        'id_str': '1748784156182548480',
#        'indices': [73, 96],
#        'media_key': '13_1748784156182548480',
#        'media_url_https': 'https://pbs.twimg.com/amplify_video_thumb/1748784156182548480/img/8CTjHnSoUKWRjdbK.jpg',
#        'type': 'video',
#        'url': 'https://t.co/UrNZePJcDd',
#        'additional_media_info': {'monetizable': False},
#        'ext_media_availability': {'status': 'Available'},
#        'sizes': {'large': {'h': 1080, 'w': 1920, 'resize': 'fit'},
#         'medium': {'h': 675, 'w': 1200, 'resize': 'fit'},
#         'small': {'h': 383, 'w': 680, 'resize': 'fit'},
#         'thumb': {'h': 150, 'w': 150, 'resize': 'crop'}},
#        'original_info': {'height': 1080, 'width': 1920, 'focus_rects': []},
#        'video_info': {'aspect_ratio': [16, 9],
#         'duration_millis': 73708,
#         'variants': [{'content_type': 'application/x-mpegURL',
#           'url': 'https://video.twimg.com/amplify_video/1748784156182548480/pl/c6Qz9X6s8b1uS4yM.m3u8?tag=14&v=e0c'},
#          {'bitrate': 288000,
#           'content_type': 'video/mp4',
#           'url': 'https://video.twimg.com/amplify_video/1748784156182548480/vid/avc1/480x270/c0KzQ8fHSVKQdkhS.mp4?tag=14'},
#          {'bitrate': 832000,
#           'content_type': 'video/mp4',
#           'url': 'https://video.twimg.com/amplify_video/1748784156182548480/vid/avc1/640x360/osxydhLsSvvTQwmz.mp4?tag=14'},
#          {'bitrate': 2176000,
#           'content_type': 'video/mp4',
#           'url': 'https://video.twimg.com/amplify_video/1748784156182548480/vid/avc1/1280x720/JL1shVvgvAe_J7hr.mp4?tag=14'}]}}]},
#     'extended_entities': {'media': [{'display_url': 'pic.x.com/UrNZePJcDd',
#        'expanded_url': 'https://x.com/Davincij15/status/1748784614829687284/video/1',
#        'id_str': '1748784156182548480',
#        'indices': [73, 96],
#        'media_key': '13_1748784156182548480',
#        'media_url_https': 'https://pbs.twimg.com/amplify_video_thumb/1748784156182548480/img/8CTjHnSoUKWRjdbK.jpg',
#        'type': 'video',
#        'url': 'https://t.co/UrNZePJcDd',
#        'additional_media_info': {'monetizable': False},
#        'ext_media_availability': {'status': 'Available'},
#        'sizes': {'large': {'h': 1080, 'w': 1920, 'resize': 'fit'},
#         'medium': {'h': 675, 'w': 1200, 'resize': 'fit'},
#         'small': {'h': 383, 'w': 680, 'resize': 'fit'},
#         'thumb': {'h': 150, 'w': 150, 'resize': 'crop'}},
#        'original_info': {'height': 1080, 'width': 1920, 'focus_rects': []},
#        'video_info': {'aspect_ratio': [16, 9],
#         'duration_millis': 73708,
#         'variants': [{'content_type': 'application/x-mpegURL',
#           'url': 'https://video.twimg.com/amplify_video/1748784156182548480/pl/c6Qz9X6s8b1uS4yM.m3u8?tag=14&v=e0c'},
#          {'bitrate': 288000,
#           'content_type': 'video/mp4',
#           'url': 'https://video.twimg.com/amplify_video/1748784156182548480/vid/avc1/480x270/c0KzQ8fHSVKQdkhS.mp4?tag=14'},
#          {'bitrate': 832000,
#           'content_type': 'video/mp4',
#           'url': 'https://video.twimg.com/amplify_video/1748784156182548480/vid/avc1/640x360/osxydhLsSvvTQwmz.mp4?tag=14'},
#          {'bitrate': 2176000,
#           'content_type': 'video/mp4',
#           'url': 'https://video.twimg.com/amplify_video/1748784156182548480/vid/avc1/1280x720/JL1shVvgvAe_J7hr.mp4?tag=14'}]}}]},
#     'favorite_count': 1728,
#     'favorited': False,
#     'full_text': 'Like I said I would buy $100 of $PONKE and here it is I have some Ponke. https://t.co/UrNZePJcDd',
#     'id_str': '1748784614829687284',
#     'lang': 'en',
#     'permalink': '/Davincij15/status/1748784614829687284',
#     'possibly_sensitive': False,
#     'quote_count': 130,
#     'reply_count': 571,
#     'retweet_count': 486,
#     'retweeted': False,
#     'text': 'Like I said I would buy $100 of $PONKE and here it is I have some Ponke. https://t.co/UrNZePJcDd',
#     'user': {'blocking': False,
#      'created_at': 'Thu Apr 21 23:08:16 +0000 2011',
#      'default_profile': True,
#      'default_profile_image': False,
#      'description': 'I told you to buy #Bitcoin for $1 in 2011. Don’t miss it again!  ETH=0x94e9A5A128f7B4af0BEeFe32F411F61d244759cE\nSOL=4ekSqR4pNZ5hp4cRyicji1Yj7ZCphgkYQhwZf2ib9Wko',
#      'entities': {'description': {'urls': []},
#       'url': {'urls': [{'display_url': 'davincij15.com',
#          'expanded_url': 'http://davincij15.com',
#          'url': 'https://t.co/8nXgMaC5BF',
#          'indices': [0, 23]}]}},
#      'fast_followers_count': 0,
#      'favourites_count': 20227,
#      'follow_request_sent': False,
#      'followed_by': False,
#      'followers_count': 692467,
#      'following': False,
#      'friends_count': 344,
#      'has_custom_timelines': False,
#      'id': 0,
#      'id_str': '285869396',
#      'is_translator': False,
#      'listed_count': 1951,
#      'location': 'Dubai, United Arab Emirates',
#      'media_count': 1850,
#      'name': 'Davinci Jeremie',
#      'normal_followers_count': 692467,
#      'notifications': False,
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/285869396/1662973988',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1663260345228509191/CCaZbydv_normal.jpg',
#      'protected': False,
#      'screen_name': 'Davincij15',
#      'show_all_inline_media': False,
#      'statuses_count': 11717,
#      'time_zone': '',
#      'translator_type': 'none',
#      'url': 'https://t.co/8nXgMaC5BF',
#      'utc_offset': 0,
#      'verified': False,
#      'withheld_in_countries': [],
#      'withheld_scope': '',
#      'is_blue_verified': True}},
#    'quoted_status_id_str': '1748784614829687284',
#    'quoted_status_permalink': {'display': 'x.com/Davincij15/sta…',
#     'expanded': 'https://twitter.com/Davincij15/status/1748784614829687284',
#     'url': 'https://t.co/6hN3QNfzMI'},
#    'startUrl': 'https://twitter.com/0xSisyphus'}]}

# %%
len(jsons['Dataset#5643dataset_twitter-scraper_2024-11-02_16-42-39-127'])
# Out:
# 100

# %%
jsons['Dataset#5643dataset_twitter-scraper_2024-11-02_16-42-39-127'] = dict(zip(range(len(jsons['Dataset#5643dataset_twitter-scraper_2024-11-02_16-42-39-127'])), jsons['Dataset#5643dataset_twitter-scraper_2024-11-02_16-42-39-127']))

# %%
outputs = []
for dataset_name, json in jsons.items():
    outputs.append(
        (dataset_name, extract_keys_values(json))
    )

# %%
outputs
# Out:
# [('Dataset#5643dataset_twitter-scraper_2024-11-02_16-42-39-127',
#   ['id is 0',
#    'location is ',
#    'conversation_id_str is 1424036915980943368',
#    'created_at is Sat Aug 07 15:57:12 +0000 2021',
#    'display_text_range is 0',
#    'display_text_range is 32',
#    'favorite_count is 1148',
#    'favorited is False',
#    'full_text is One must imagine Sisyphus happy.',
#    'id_str is 1424036915980943368',
#    'lang is en',
#    'permalink is /0xSisyphus/status/1424036915980943368',
#    'possibly_sensitive is False',
#    'quote_count is 25',
#    'reply_count is 218',
#    'retweet_count is 131',
#    'retweeted is False',
#    'text is One must imagine Sisyphus happy.',
#    'blocking is False',
#    'created_at is Wed Mar 03 01:58:19 +0000 2021',
#    'default_profile is True',
#    'default_profile_image is False',
#    'description is Roll boulder up hill, it rolls back down.',
#    'fast_followers_count is 0',
#    'favourites_count is 93910',
#    'follow_request_sent is False',
#    'followed_by is False',
#    'followers_count is 136966',
#    'following is False',
#    'friends_count is 400',
#    'has_custom_timelines is False',
#    'id is 0',
#    'id_str is 1366930865574584323',
#    'is_translator is False',
#    'listed_count is 3012',
#    'location is ',
#    'media_count is 1502',
#    'name is Sisyphus',
#    'normal_followers_count is 136966',
#    'notifications is False',
#    'profile_banner_url is https://pbs.twimg.com/profile_banners/1366930865574584323/1628902848',
#    'profile_image_url_https is https://pbs.twimg.com/profile_images/1749647387247693825/IGD_vcy6_normal.jpg',
#    'protected is False',
#    'screen_name is 0xSisyphus',
#    'show_all_inline_media is False',
#    'statuses_count is 34643',
#    'time_zone is ',
#    'translator_type is none',
#    'url is ',
#    'utc_offset is 0',
#    'verified is False',
#    'withheld_scope is ',
#    'is_blue_verified is True',
#    'startUrl is https://twitter.com/0xSisyphus',
#    'id is 0',
#    'location is ',
#    'conversation_id_str is 1759743974711935094',
#    'created_at is Tue Feb 20 00:57:12 +0000 2024',
#    'display_text_range is 0',
#    'display_text_range is 118',
#    'favorite_count is 72487',
#    'favorited is False',
#    'full_text is Do crackheads ever say, “I’m too broke to smoke crack tonight”?\n\nNo. They get up and make it happen.\n\nLesson in there.',
#    'id_str is 1759743974711935094',
#    'lang is en',
#    'permalink is /0xSisyphus/status/1759743974711935094',
#    'possibly_sensitive is False',
#    'quote_count is 898',
#    'reply_count is 338',
#    'retweet_count is 13693',
#    'retweeted is False',
#    'text is Do crackheads ever say, “I’m too broke to smoke crack tonight”?\n\nNo. They get up and make it happen.\n\nLesson in there.',
#    'blocking is False',
#    'created_at is Wed Mar 03 01:58:19 +0000 2021',
#    'default_profile is True',
#    'default_profile_image is False',
#    'description is Roll boulder up hill, it rolls back down.',
#    'fast_followers_count is 0',
#    'favourites_count is 93910',
#    'follow_request_sent is False',
#    'followed_by is False',
#    'followers_count is 136966',
#    'following is False',
#    'friends_count is 400',
#    'has_custom_timelines is False',
#    'id is 0',
#    'id_str is 1366930865574584323',
#    'is_translator is False',
#    'listed_count is 3012',
#    'location is ',
#    'media_count is 1502',
#    'name is Sisyphus',
#    'normal_followers_count is 136966',
#    'notifications is False',
#    'profile_banner_url is https://pbs.twimg.com/profile_banners/1366930865574584323/1628902848',
#    'profile_image_url_https is https://pbs.twimg.com/profile_images/1749647387247693825/IGD_vcy6_normal.jpg',
#    'protected is False',
#    'screen_name is 0xSisyphus',
#    'show_all_inline_media is False',
#    'statuses_count is 34643',
#    'time_zone is ',
#    'translator_type is none',
#    'url is ',
#    'utc_offset is 0',
#    'verified is False',
#    'withheld_scope is ',
#    'is_blue_verified is True',
#    'startUrl is https://twitter.com/0xSisyphus',
#    'id is 0',
#    'location is ',
#    'conversation_id_str is 1764650746119590063',
#    'created_at is Mon Mar 04 13:54:58 +0000 2024',
#    'display_text_range is 0',
#    'display_text_range is 55',
#    'favorite_count is 9570',
#    'favorited is False',
#    "full_text is I've fumbled generational wealth like 6 times this week",
#    'id_str is 1764650746119590063',
#    'lang is en',
#    'permalink is /0xSisyphus/status/1764650746119590063',
#    'possibly_sensitive is False',
#    'quote_count is 105',
#    'reply_count is 200',
#    'retweet_count is 892',
#    'retweeted is False',
#    "text is I've fumbled generational wealth like 6 times this week",
#    'blocking is False',
#    'created_at is Wed Mar 03 01:58:19 +0000 2021',
#    'default_profile is True',
#    'default_profile_image is False',
#    'description is Roll boulder up hill, it rolls back down.',
#    'fast_followers_count is 0',
#    'favourites_count is 93910',
#    'follow_request_sent is False',
#    'followed_by is False',
#    'followers_count is 136966',
#    'following is False',
#    'friends_count is 400',
#    'has_custom_timelines is False',
#    'id is 0',
#    'id_str is 1366930865574584323',
#    'is_translator is False',
#    'listed_count is 3012',
#    'location is ',
#    'media_count is 1502',
#    'name is Sisyphus',
#    'normal_followers_count is 136966',
#    'notifications is False',
#    'profile_banner_url is https://pbs.twimg.com/profile_banners/1366930865574584323/1628902848',
#    'profile_image_url_https is https://pbs.twimg.com/profile_images/1749647387247693825/IGD_vcy6_normal.jpg',
#    'protected is False',
#    'screen_name is 0xSisyphus',
#    'show_all_inline_media is False',
#    'statuses_count is 34643',
#    'time_zone is ',
#    'translator_type is none',
#    'url is ',
#    'utc_offset is 0',
#    'verified is False',
#    'withheld_scope is ',
#    'is_blue_verified is True',
#    'startUrl is https://twitter.com/0xSisyphus',
#    'id is 0',
#    'location is ',
#    'conversation_id_str is 1746637532295479496',
#    'created_at is Sun Jan 14 20:56:53 +0000 2024',
#    'display_text_range is 0',
#    'display_text_range is 180',
#    'favorite_count is 1221',
#    'favorited is False',
#    "full_text is The most evergreen meme will always be the founder's pet\n\nIf Vitalik had a pet, the resultant coin would likely be in the top 20. We will simply have to get Raj's one there instead",
#    'id_str is 1746637532295479496',
#    'lang is en',
#    'permalink is /0xSisyphus/status/1746637532295479496',
#    'possibly_sensitive is False',
#    'quote_count is 26',
#    'reply_count is 4702',
#    'retweet_count is 999',
#    'retweeted is False',
#    "text is The most evergreen meme will always be the founder's pet\n\nIf Vitalik had a pet, the resultant coin would likely be in the top 20. We will simply have to get Raj's one there instead",
#    'blocking is False',
#    'created_at is Wed Mar 03 01:58:19 +0000 2021',
#    'default_profile is True',
#    'default_profile_image is False',
#    'description is Roll boulder up hill, it rolls back down.',
#    'fast_followers_count is 0',
#    'favourites_count is 93910',
#    'follow_request_sent is False',
#    'followed_by is False',
#    'followers_count is 136966',
#    'following is False',
#    'friends_count is 400',
#    'has_custom_timelines is False',
#    'id is 0',
#    'id_str is 1366930865574584323',
#    'is_translator is False',
#    'listed_count is 3012',
#    'location is ',
#    'media_count is 1502',
#    'name is Sisyphus',
#    'normal_followers_count is 136966',
#    'notifications is False',
#    'profile_banner_url is https://pbs.twimg.com/profile_banners/1366930865574584323/1628902848',
#    'profile_image_url_https is https://pbs.twimg.com/profile_images/1749647387247693825/IGD_vcy6_normal.jpg',
#    'protected is False',
#    'screen_name is 0xSisyphus',
#    'show_all_inline_media is False',
#    'statuses_count is 34643',
#    'time_zone is ',
#    'translator_type is none',
#    'url is ',
#    'utc_offset is 0',
#    'verified is False',
#    'withheld_scope is ',
#    'is_blue_verified is True',
#    'startUrl is https://twitter.com/0xSisyphus',
#    'id is 0',
#    'location is ',
#    'conversation_id_str is 1442274497269223425',
#    'created_at is Sun Sep 26 23:46:50 +0000 2021',
#    'display_text_range is 0',
#    'display_text_range is 133',
#    'display_url is pic.x.com/xgTzfprftm',
#    'expanded_url is https://x.com/0xSisyphus/status/1442274497269223425/photo/1',
#    'id_str is 1442274378293645313',
#    'indices is 134',
#    'indices is 157',
#    'media_key is 3_1442274378293645313',
#    'media_url_https is https://pbs.twimg.com/media/FAP859LXEAEBnfv.jpg',
#    'type is photo',
#    'url is https://t.co/xgTzfprftm',
#    'status is Available',
#    'h is 878',
#    'w is 1234',
#    'resize is fit',
#    'h is 854',
#    'w is 1200',
#    'resize is fit',
#    'h is 484',
#    'w is 680',
#    'resize is fit',
#    'h is 150',
#    'w is 150',
#    'resize is crop',
#    'height is 878',
#    'width is 1234',
#    'x is 0',
#    'y is 187',
#    'w is 1234',
#    'h is 691',
#    'x is 84',
#    'y is 0',
#    'w is 878',
#    'h is 878',
#    'x is 138',
#    'y is 0',
#    'w is 770',
#    'h is 878',
#    'x is 304',
#    'y is 0',
#    'w is 439',
#    'h is 878',
#    'x is 0',
#    'y is 0',
#    'w is 1234',
#    'h is 878',
#    'display_url is pic.x.com/xgTzfprftm',
#    'expanded_url is https://x.com/0xSisyphus/status/1442274497269223425/photo/1',
#    'id_str is 1442274378293645313',
#    'indices is 134',
#    'indices is 157',
#    'media_key is 3_1442274378293645313',
#    'media_url_https is https://pbs.twimg.com/media/FAP859LXEAEBnfv.jpg',
#    'type is photo',
#    'url is https://t.co/xgTzfprftm',
#    'status is Available',
#    'h is 878',
#    'w is 1234',
#    'resize is fit',
#    'h is 854',
#    'w is 1200',
#    'resize is fit',
#    'h is 484',
#    'w is 680',
#    'resize is fit',
#    'h is 150',
#    'w is 150',
#    'resize is crop',
#    'height is 878',
#    'width is 1234',
#    'x is 0',
#    'y is 187',
#    'w is 1234',
#    'h is 691',
#    'x is 84',
#    'y is 0',
#    'w is 878',
#    'h is 878',
#    'x is 138',
#    'y is 0',
#    'w is 770',
#    'h is 878',
#    'x is 304',
#    'y is 0',
#    'w is 439',
#    'h is 878',
#    'x is 0',
#    'y is 0',
#    'w is 1234',
#    'h is 878',
#    'favorite_count is 3771',
#    'favorited is False',
#    'full_text is some levels im watching on the 450-year chart for stocks\n\nthink pretty strong support at 1930s levels, if we break there back to 1812 https://t.co/xgTzfprftm',
#    'id_str is 1442274497269223425',
#    'lang is en',
#    'permalink is /0xSisyphus/status/1442274497269223425',
#    'possibly_sensitive is False',
#    'quote_count is 121',
#    'reply_count is 140',
#    'retweet_count is 527',
#    'retweeted is False',
#    'text is some levels im watching on the 450-year chart for stocks\n\nthink pretty strong support at 1930s levels, if we break there back to 1812 https://t.co/xgTzfprftm',
#    'blocking is False',
#    'created_at is Wed Mar 03 01:58:19 +0000 2021',
#    'default_profile is True',
#    'default_profile_image is False',
#    'description is Roll boulder up hill, it rolls back down.',
#    'fast_followers_count is 0',
#    'favourites_count is 93910',
#    'follow_request_sent is False',
#    'followed_by is False',
#    'followers_count is 136966',
#    'following is False',
#    'friends_count is 400',
#    'has_custom_timelines is False',
#    'id is 0',
#    'id_str is 1366930865574584323',
#    'is_translator is False',
#    'listed_count is 3012',
#    'location is ',
#    'media_count is 1502',
#    'name is Sisyphus',
#    'normal_followers_count is 136966',
#    'notifications is False',
#    'profile_banner_url is https://pbs.twimg.com/profile_banners/1366930865574584323/1628902848',
#    'profile_image_url_https is https://pbs.twimg.com/profile_images/1749647387247693825/IGD_vcy6_normal.jpg',
#    'protected is False',
#    'screen_name is 0xSisyphus',
#    'show_all_inline_media is False',
#    'statuses_count is 34643',
#    'time_zone is ',
#    'translator_type is none',
#    'url is ',
#    'utc_offset is 0',
#    'verified is False',
#    'withheld_scope is ',
#    'is_blue_verified is True',
#    'startUrl is https://twitter.com/0xSisyphus',
#    'id is 0',
#    'location is ',
#    'conversation_id_str is 1592329743671906304',
#    'created_at is Tue Nov 15 01:32:49 +0000 2022',
#    'display_text_range is 0',
#    'display_text_range is 159',
#    'favorite_count is 3305',
#    'favorited is False',
#    'full_text is SBF mentions a video game in the NYT piece, called "Storybook Brawl" \n\nIt turns out FTX actually owns this game, he used the article as a promoted ad basically',
#    'id_str is 1592329743671906304',
#    'lang is en',
#    'permalink is /0xSisyphus/status/1592329743671906304',
#    'possibly_sensitive is False',
#    'quote_count is 100',
#    'reply_count is 170',
#    'retweet_count is 264',
#    'retweeted is False',
#    'text is SBF mentions a video game in the NYT piece, called "Storybook Brawl" \n\nIt turns out FTX actually owns this game, he used the article as a promoted ad basically',
#    'blocking is False',
#    'created_at is Wed Mar 03 01:58:19 +0000 2021',
#    'default_profile is True',
#    'default_profile_image is False',
#    'description is Roll boulder up hill, it rolls back down.',
#    'fast_followers_count is 0',
#    'favourites_count is 93910',
#    'follow_request_sent is False',
#    'followed_by is False',
#    'followers_count is 136966',
#    'following is False',
#    'friends_count is 400',
#    'has_custom_timelines is False',
#    'id is 0',
#    'id_str is 1366930865574584323',
#    'is_translator is False',
#    'listed_count is 3012',
#    'location is ',
#    'media_count is 1502',
#    'name is Sisyphus',
#    'normal_followers_count is 136966',
#    'notifications is False',
#    'profile_banner_url is https://pbs.twimg.com/profile_banners/1366930865574584323/1628902848',
#    'profile_image_url_https is https://pbs.twimg.com/profile_images/1749647387247693825/IGD_vcy6_normal.jpg',
#    'protected is False',
#    'screen_name is 0xSisyphus',
#    'show_all_inline_media is False',
#    'statuses_count is 34643',
#    'time_zone is ',
#    'translator_type is none',
#    'url is ',
#    'utc_offset is 0',
#    'verified is False',
#    'withheld_scope is ',
#    'is_blue_verified is True',
#    'startUrl is https://twitter.com/0xSisyphus',
#    'id is 0',
#    'location is ',
#    'conversation_id_str is 1593413144201904129',
#    'created_at is Fri Nov 18 01:17:52 +0000 2022',
#    'display_text_range is 0',
#    'display_text_range is 72',
#    'display_url is pic.x.com/aFhbuT2wyn',
#    'expanded_url is https://x.com/0xSisyphus/status/1593413144201904129/photo/1',
#    'id_str is 1593413140569522177',
#    'indices is 73',
#    'indices is 96',
#    'media_key is 3_1593413140569522177',
#    'media_url_https is https://pbs.twimg.com/media/FhzwzyAWAAETTz-.jpg',
#    'type is photo',
#    'url is https://t.co/aFhbuT2wyn',
#    'status is Available',
#    'x is 607',
#    'y is 188',
#    'h is 44',
#    'w is 44',
#    'x is 508',
#    'y is 192',
#    'h is 44',
#    'w is 44',
#    'x is 306',
#    'y is 145',
#    'h is 56',
#    'w is 56',
#    'x is 607',
#    'y is 188',
#    'h is 44',
#    'w is 44',
#    'x is 508',
#    'y is 192',
#    'h is 44',
#    'w is 44',
#    'x is 306',
#    'y is 145',
#    'h is 56',
#    'w is 56',
#    'x is 607',
#    'y is 188',
#    'h is 44',
#    'w is 44',
#    'x is 508',
#    'y is 192',
#    'h is 44',
#    'w is 44',
#    'x is 306',
#    'y is 145',
#    'h is 56',
#    'w is 56',
#    'x is 607',
#    'y is 188',
#    'h is 44',
#    'w is 44',
#    'x is 508',
#    'y is 192',
#    'h is 44',
#    'w is 44',
#    'x is 306',
#    'y is 145',
#    'h is 56',
#    'w is 56',
#    'h is 336',
#    'w is 670',
#    'resize is fit',
#    'h is 336',
#    'w is 670',
#    'resize is fit',
#    'h is 336',
#    'w is 670',
#    'resize is fit',
#    'h is 150',
#    'w is 150',
#    'resize is crop',
#    'height is 336',
#    'width is 670',
#    'x is 70',
#    'y is 0',
#    'w is 600',
#    'h is 336',
#    'x is 334',
#    'y is 0',
#    'w is 336',
#    'h is 336',
#    'x is 375',
#    'y is 0',
#    'w is 295',
#    'h is 336',
#    'x is 502',
#    'y is 0',
#    'w is 168',
#    'h is 336',
#    'x is 0',
#    'y is 0',
#    'w is 670',
#    'h is 336',
#    'display_url is pic.x.com/aFhbuT2wyn',
#    'expanded_url is https://x.com/0xSisyphus/status/1593413144201904129/photo/1',
#    'id_str is 1593413140569522177',
#    'indices is 73',
#    'indices is 96',
#    'media_key is 3_1593413140569522177',
#    'media_url_https is https://pbs.twimg.com/media/FhzwzyAWAAETTz-.jpg',
#    'type is photo',
#    'url is https://t.co/aFhbuT2wyn',
#    'status is Available',
#    'x is 607',
#    'y is 188',
#    'h is 44',
#    'w is 44',
#    'x is 508',
#    'y is 192',
#    'h is 44',
#    'w is 44',
#    'x is 306',
#    'y is 145',
#    'h is 56',
#    'w is 56',
#    'x is 607',
#    'y is 188',
#    'h is 44',
#    'w is 44',
#    'x is 508',
#    'y is 192',
#    'h is 44',
#    'w is 44',
#    'x is 306',
#    'y is 145',
#    'h is 56',
#    'w is 56',
#    'x is 607',
#    'y is 188',
#    'h is 44',
#    'w is 44',
#    'x is 508',
#    'y is 192',
#    'h is 44',
#    'w is 44',
#    'x is 306',
#    'y is 145',
#    'h is 56',
#    'w is 56',
#    'x is 607',
#    'y is 188',
#    'h is 44',
#    'w is 44',
#    'x is 508',
#    'y is 192',
#    'h is 44',
#    'w is 44',
#    'x is 306',
#    'y is 145',
#    'h is 56',
#    'w is 56',
#    'h is 336',
#    'w is 670',
#    'resize is fit',
#    'h is 336',
#    'w is 670',
#    'resize is fit',
#    'h is 336',
#    'w is 670',
#    'resize is fit',
#    'h is 150',
#    'w is 150',
#    'resize is crop',
#    'height is 336',
#    'width is 670',
#    'x is 70',
#    'y is 0',
#    'w is 600',
#    'h is 336',
#    'x is 334',
#    'y is 0',
#    'w is 336',
#    'h is 336',
#    'x is 375',
#    'y is 0',
#    'w is 295',
#    'h is 336',
#    'x is 502',
#    'y is 0',
#    'w is 168',
#    'h is 336',
#    'x is 0',
#    'y is 0',
#    'w is 670',
#    'h is 336',
#    'favorite_count is 3153',
#    'favorited is False',
#    'full_text is The Bahamian Supreme Court is now one of the largest holders of Ethereum https://t.co/aFhbuT2wyn',
#    'id_str is 1593413144201904129',
#    'lang is en',
#    'permalink is /0xSisyphus/status/1593413144201904129',
#    'possibly_sensitive is False',
#    'quote_count is 107',
#    'reply_count is 235',
#    'retweet_count is 270',
#    'retweeted is False',
#    'text is The Bahamian Supreme Court is now one of the largest holders of Ethereum https://t.co/aFhbuT2wyn',
#    'blocking is False',
#    'created_at is Wed Mar 03 01:58:19 +0000 2021',
#    'default_profile is True',
#    'default_profile_image is False',
#    'description is Roll boulder up hill, it rolls back down.',
#    'fast_followers_count is 0',
#    'favourites_count is 93910',
#    'follow_request_sent is False',
#    'followed_by is False',
#    'followers_count is 136966',
#    'following is False',
#    'friends_count is 400',
#    'has_custom_timelines is False',
#    'id is 0',
#    'id_str is 1366930865574584323',
#    'is_translator is False',
#    'listed_count is 3012',
#    'location is ',
#    'media_count is 1502',
#    'name is Sisyphus',
#    'normal_followers_count is 136966',
#    'notifications is False',
#    'profile_banner_url is https://pbs.twimg.com/profile_banners/1366930865574584323/1628902848',
#    'profile_image_url_https is https://pbs.twimg.com/profile_images/1749647387247693825/IGD_vcy6_normal.jpg',
#    'protected is False',
#    'screen_name is 0xSisyphus',
#    'show_all_inline_media is False',
#    'statuses_count is 34643',
#    'time_zone is ',
#    'translator_type is none',
#    'url is ',
#    'utc_offset is 0',
#    'verified is False',
#    'withheld_scope is ',
#    'is_blue_verified is True',
#    'startUrl is https://twitter.com/0xSisyphus',
#    'id is 0',
#    'location is ',
#    'conversation_id_str is 1766836817167311262',
#    'created_at is Sun Mar 10 14:41:38 +0000 2024',
#    'display_text_range is 0',
#    'display_text_range is 119',
#    'display_url is pic.x.com/dixZE9hXgR',
#    'expanded_url is https://x.com/0xSisyphus/status/1766836817167311262/photo/1',
#    'id_str is 1766836807323258880',
#    'indices is 120',
#    'indices is 143',
#    'media_key is 3_1766836807323258880',
#    'media_url_https is https://pbs.twimg.com/media/GIUQtxSWkAAsZxb.jpg',
#    'type is photo',
#    'url is https://t.co/dixZE9hXgR',
#    'status is Available',
#    'x is 218',
#    'y is 191',
#    'h is 37',
#    'w is 37',
#    'x is 218',
#    'y is 191',
#    'h is 37',
#    'w is 37',
#    'x is 218',
#    'y is 191',
#    'h is 37',
#    'w is 37',
#    'x is 218',
#    'y is 191',
#    'h is 37',
#    'w is 37',
#    'h is 500',
#    'w is 564',
#    'resize is fit',
#    'h is 500',
#    'w is 564',
#    'resize is fit',
#    'h is 500',
#    'w is 564',
#    'resize is fit',
#    'h is 150',
#    'w is 150',
#    'resize is crop',
#    'height is 500',
#    'width is 564',
#    'x is 0',
#    'y is 25',
#    'w is 564',
#    'h is 316',
#    'x is 64',
#    'y is 0',
#    'w is 500',
#    'h is 500',
#    'x is 125',
#    'y is 0',
#    'w is 439',
#    'h is 500',
#    'x is 314',
#    'y is 0',
#    'w is 250',
#    'h is 500',
#    'x is 0',
#    'y is 0',
#    'w is 564',
#    'h is 500',
#    'display_url is pic.x.com/dixZE9hXgR',
#    'expanded_url is https://x.com/0xSisyphus/status/1766836817167311262/photo/1',
#    'id_str is 1766836807323258880',
#    'indices is 120',
#    'indices is 143',
#    'media_key is 3_1766836807323258880',
#    'media_url_https is https://pbs.twimg.com/media/GIUQtxSWkAAsZxb.jpg',
#    'type is photo',
#    'url is https://t.co/dixZE9hXgR',
#    'status is Available',
#    'x is 218',
#    'y is 191',
#    'h is 37',
#    'w is 37',
#    'x is 218',
#    'y is 191',
#    'h is 37',
#    'w is 37',
#    'x is 218',
#    'y is 191',
#    'h is 37',
#    'w is 37',
#    'x is 218',
#    'y is 191',
#    'h is 37',
#    'w is 37',
#    'h is 500',
#    'w is 564',
#    'resize is fit',
#    'h is 500',
#    'w is 564',
#    'resize is fit',
#    'h is 500',
#    'w is 564',
#    'resize is fit',
#    'h is 150',
#    'w is 150',
#    'resize is crop',
#    'height is 500',
#    'width is 564',
#    'x is 0',
#    'y is 25',
#    'w is 564',
#    'h is 316',
#    'x is 64',
#    'y is 0',
#    'w is 500',
#    'h is 500',
#    'x is 125',
#    'y is 0',
#    'w is 439',
#    'h is 500',
#    'x is 314',
#    'y is 0',
#    'w is 250',
#    'h is 500',
#    'x is 0',
#    'y is 0',
#    'w is 564',
#    'h is 500',
#    'favorite_count is 2713',
#    'favorited is False',
#    'full_text is The key to cryptocurrency investing is to be the guy on the right (and sell for real world assets at appropriate times) https://t.co/dixZE9hXgR',
#    'id_str is 1766836817167311262',
#    'lang is en',
#    'permalink is /0xSisyphus/status/1766836817167311262',
#    'possibly_sensitive is False',
#    'quote_count is 22',
#    'reply_count is 48',
#    'retweet_count is 300',
#    'retweeted is False',
#    'text is The key to cryptocurrency investing is to be the guy on the right (and sell for real world assets at appropriate times) https://t.co/dixZE9hXgR',
#    'blocking is False',
#    'created_at is Wed Mar 03 01:58:19 +0000 2021',
#    'default_profile is True',
#    'default_profile_image is False',
#    'description is Roll boulder up hill, it rolls back down.',
#    'fast_followers_count is 0',
#    'favourites_count is 93910',
#    'follow_request_sent is False',
#    'followed_by is False',
#    'followers_count is 136966',
#    'following is False',
#    'friends_count is 400',
#    'has_custom_timelines is False',
#    'id is 0',
#    'id_str is 1366930865574584323',
#    'is_translator is False',
#    'listed_count is 3012',
#    'location is ',
#    'media_count is 1502',
#    'name is Sisyphus',
#    'normal_followers_count is 136966',
#    'notifications is False',
#    'profile_banner_url is https://pbs.twimg.com/profile_banners/1366930865574584323/1628902848',
#    'profile_image_url_https is https://pbs.twimg.com/profile_images/1749647387247693825/IGD_vcy6_normal.jpg',
#    'protected is False',
#    'screen_name is 0xSisyphus',
#    'show_all_inline_media is False',
#    'statuses_count is 34643',
#    'time_zone is ',
#    'translator_type is none',
#    'url is ',
#    'utc_offset is 0',
#    'verified is False',
#    'withheld_scope is ',
#    'is_blue_verified is True',
#    'startUrl is https://twitter.com/0xSisyphus',
#    'id is 0',
#    'location is ',
#    'conversation_id_str is 1590382073369747458',
#    'created_at is Wed Nov 09 16:33:28 +0000 2022',
#    'display_text_range is 0',
#    'display_text_range is 127',
#    'favorite_count is 2240',
#    'favorited is False',
#    'full_text is FTX not disabling trading; remaining users are trading wildly with monopoly money, and it affects prices on all other exchanges',
#    'id_str is 1590382073369747458',
#    'lang is en',
#    'permalink is /0xSisyphus/status/1590382073369747458',
#    'possibly_sensitive is False',
#    'quote_count is 35',
#    'reply_count is 89',
#    'retweet_count is 141',
#    'retweeted is False',
#    'text is FTX not disabling trading; remaining users are trading wildly with monopoly money, and it affects prices on all other exchanges',
#    'blocking is False',
#    'created_at is Wed Mar 03 01:58:19 +0000 2021',
#    'default_profile is True',
#    'default_profile_image is False',
#    'description is Roll boulder up hill, it rolls back down.',
#    'fast_followers_count is 0',
#    'favourites_count is 93910',
#    'follow_request_sent is False',
#    'followed_by is False',
#    'followers_count is 136966',
#    'following is False',
#    'friends_count is 400',
#    'has_custom_timelines is False',
#    'id is 0',
#    'id_str is 1366930865574584323',
#    'is_translator is False',
#    'listed_count is 3012',
#    'location is ',
#    'media_count is 1502',
#    'name is Sisyphus',
#    'normal_followers_count is 136966',
#    'notifications is False',
#    'profile_banner_url is https://pbs.twimg.com/profile_banners/1366930865574584323/1628902848',
#    'profile_image_url_https is https://pbs.twimg.com/profile_images/1749647387247693825/IGD_vcy6_normal.jpg',
#    'protected is False',
#    'screen_name is 0xSisyphus',
#    'show_all_inline_media is False',
#    'statuses_count is 34643',
#    'time_zone is ',
#    'translator_type is none',
#    'url is ',
#    'utc_offset is 0',
#    'verified is False',
#    'withheld_scope is ',
#    'is_blue_verified is True',
#    'startUrl is https://twitter.com/0xSisyphus',
#    'id is 0',
#    'location is ',
#    'conversation_id_str is 1783654986150457728',
#    'created_at is Fri Apr 26 00:31:02 +0000 2024',
#    'display_text_range is 0',
#    'display_text_range is 261',
#    'favorite_count is 2140',
#    'favorited is False',
#    'full_text is Memecoins are making people realize nearly all of the “tech” in crypto is a smokescreen designed to sell you a token that does nothing marked up 100x from the private round\n\nThis is why VC’s don’t like memecoins - it threatens their core business, selling vapor',
#    'id_str is 1783654986150457728',
#    'lang is en',
#    'permalink is /0xSisyphus/status/1783654986150457728',
#    'possibly_sensitive is False',
#    'quote_count is 67',
#    'reply_count is 119',
#    'retweet_count is 337',
#    'retweeted is False',
#    'text is Memecoins are making people realize nearly all of the “tech” in crypto is a smokescreen designed to sell you a token that does nothing marked up 100x from the private round\n\nThis is why VC’s don’t like memecoins - it threatens their core business, selling vapor',
#    'blocking is False',
#    'created_at is Wed Mar 03 01:58:19 +0000 2021',
#    'default_profile is True',
#    'default_profile_image is False',
#    'description is Roll boulder up hill, it rolls back down.',
#    'fast_followers_count is 0',
#    'favourites_count is 93910',
#    'follow_request_sent is False',
#    'followed_by is False',
#    'followers_count is 136966',
#    'following is False',
#    'friends_count is 400',
#    'has_custom_timelines is False',
#    'id is 0',
#    'id_str is 1366930865574584323',
#    'is_translator is False',
#    'listed_count is 3012',
#    'location is ',
#    'media_count is 1502',
#    'name is Sisyphus',
#    'normal_followers_count is 136966',
#    'notifications is False',
#    'profile_banner_url is https://pbs.twimg.com/profile_banners/1366930865574584323/1628902848',
#    'profile_image_url_https is https://pbs.twimg.com/profile_images/1749647387247693825/IGD_vcy6_normal.jpg',
#    'protected is False',
#    'screen_name is 0xSisyphus',
#    'show_all_inline_media is False',
#    'statuses_count is 34643',
#    'time_zone is ',
#    'translator_type is none',
#    'url is ',
#    'utc_offset is 0',
#    'verified is False',
#    'withheld_scope is ',
#    'is_blue_verified is True',
#    'startUrl is https://twitter.com/0xSisyphus',
#    'id is 0',
#    'location is ',
#    'conversation_id_str is 1787656909367148802',
#    'created_at is Tue May 07 01:33:14 +0000 2024',
#    'display_text_range is 0',
#    'display_text_range is 42',
#    'display_url is pic.x.com/553FYve9Nt',
#    'expanded_url is https://x.com/0xSisyphus/status/1787656909367148802/photo/1',
#    'id_str is 1787656885199675392',
#    'indices is 43',
#    'indices is 66',
#    'media_key is 3_1787656885199675392',
#    'media_url_https is https://pbs.twimg.com/media/GM8IdzaboAAau7S.jpg',
#    'type is photo',
#    'url is https://t.co/553FYve9Nt',
#    'status is Available',
#    'h is 1283',
#    'w is 1179',
#    'resize is fit',
#    'h is 1200',
#    'w is 1103',
#    'resize is fit',
#    'h is 680',
#    'w is 625',
#    'resize is fit',
#    'h is 150',
#    'w is 150',
#    'resize is crop',
#    'height is 1283',
#    'width is 1179',
#    'x is 0',
#    'y is 623',
#    'w is 1179',
#    'h is 660',
#    'x is 0',
#    'y is 104',
#    'w is 1179',
#    'h is 1179',
#    'x is 0',
#    'y is 0',
#    'w is 1125',
#    'h is 1283',
#    'x is 0',
#    'y is 0',
#    'w is 642',
#    'h is 1283',
#    'x is 0',
#    'y is 0',
#    'w is 1179',
#    'h is 1283',
#    'display_url is pic.x.com/553FYve9Nt',
#    'expanded_url is https://x.com/0xSisyphus/status/1787656909367148802/photo/1',
#    'id_str is 1787656885199675392',
#    'indices is 43',
#    'indices is 66',
#    'media_key is 3_1787656885199675392',
#    'media_url_https is https://pbs.twimg.com/media/GM8IdzaboAAau7S.jpg',
#    'type is photo',
#    'url is https://t.co/553FYve9Nt',
#    'status is Available',
#    'h is 1283',
#    'w is 1179',
#    'resize is fit',
#    'h is 1200',
#    'w is 1103',
#    'resize is fit',
#    'h is 680',
#    'w is 625',
#    ...])]

# %%
output_dir = './SisyphusAI output'
for name, lists in outputs:
    clean_and_split_data(name, lists, output_dir=output_dir, cleaner=normalize_and_clean)
# Out:
# id is 0
# location is
# conversation id str is
# created at is sat aug 07 15:57:12 0000 2021
# display text range is 0
# display text range is 32
# favorite count is 1148
# favorited is false
# full text is one must imagine sisyphus happy.
# id str is
# lang is en
# permalink is 0xsisyphus status
# possibly sensitive is false
# quote count is 25
# reply count is 218
# retweet count is 131
# retweeted is false
# text is one must imagine sisyphus happy.
# blocking is false
# created at is wed mar 03 01:58:19 0000 2021
# default profile is true
# default profile image is false
# description is roll boulder up hill, it rolls back down.
# fast followers count is 0
# favourites count is 93910
# follow request sent is false
# followed by is false
# followers count is 136966
# following is false
# friends count is 400
# has custom timelines is false
# id is 0
# id str is
# is translator is false
# listed count is 3012
# location is
# media count is 1502
# name is sisyphus
# normal followers count is 136966
# notifications is false
# profile banner url is profile banners
# profile image url is profile images igd vcy6 normal.jpg
# protected is false
# screen name is 0xsisyphus
# show all inline media is false
# statuses count is 34643
# time zone is
# translator type is none
# url is
# utc offset is 0
# verified is false
# withheld scope is
# is blue verified is true
# starturl is 0xsisyphus
# id is 0
# location is
# conversation id str is
# created at is tue feb 20 00:57:12 0000 2024
# display text range is 0
# display text range is 118
# favorite count is 72487
# favorited is false
# full text is do crackheads ever say, i am too broke to smoke crack tonight no. they get up and make it happen. lesson in there.
# id str is
# lang is en
# permalink is 0xsisyphus status
# possibly sensitive is false
# quote count is 898
# reply count is 338
# retweet count is 13693
# retweeted is false
# text is do crackheads ever say, i am too broke to smoke crack tonight no. they get up and make it happen. lesson in there.
# blocking is false
# created at is wed mar 03 01:58:19 0000 2021
# default profile is true
# default profile image is false
# description is roll boulder up hill, it rolls back down.
# fast followers count is 0
# favourites count is 93910
# follow request sent is false
# followed by is false
# followers count is 136966
# following is false
# friends count is 400
# has custom timelines is false
# id is 0
# id str is
# is translator is false
# listed count is 3012
# location is
# media count is 1502
# name is sisyphus
# normal followers count is 136966
# notifications is false
# profile banner url is profile banners
# profile image url is profile images igd vcy6 normal.jpg
# protected is false
# screen name is 0xsisyphus
# show all inline media is false
# statuses count is 34643
# time zone is
# translator type is none
# url is
# utc offset is 0
# verified is false
# withheld scope is
# is blue verified is true
# starturl is 0xsisyphus
# id is 0
# location is
# conversation id str is
# created at is mon mar 04 13:54:58 0000 2024
# display text range is 0
# display text range is 55
# favorite count is 9570
# favorited is false
# full text is i have fumbled generational wealth like 6 times this week
# id str is
# lang is en
# permalink is 0xsisyphus status
# possibly sensitive is false
# quote count is 105
# reply count is 200
# retweet count is 892
# retweeted is false
# text is i have fumbled generational wealth like 6 times this week
# blocking is false
# created at is wed mar 03 01:58:19 0000 2021
# default profile is true
# default profile image is false
# description is roll boulder up hill, it rolls back down.
# fast followers count is 0
# favourites count is 93910
# follow request sent is false
# followed by is false
# followers count is 136966
# following is false
# friends count is 400
# has custom timelines is false
# id is 0
# id str is
# is translator is false
# listed count is 3012
# location is
# media count is 1502
# name is sisyphus
# normal followers count is 136966
# notifications is false
# profile banner url is profile banners
# profile image url is profile images igd vcy6 normal.jpg
# protected is false
# screen name is 0xsisyphus
# show all inline media is false
# statuses count is 34643
# time zone is
# translator type is none
# url is
# utc offset is 0
# verified is false
# withheld scope is
# is blue verified is true
# starturl is 0xsisyphus
# id is 0
# location is
# conversation id str is
# created at is sun jan 14 20:56:53 0000 2024
# display text range is 0
# display text range is 180
# favorite count is 1221
# favorited is false
# full text is the most evergreen meme will always be the founder pet if vitalik had a pet, the resultant coin would likely be in the top 20. we will simply have to get raj one there instead
# id str is
# lang is en
# permalink is 0xsisyphus status
# possibly sensitive is false
# quote count is 26
# reply count is 4702
# retweet count is 999
# retweeted is false
# text is the most evergreen meme will always be the founder pet if vitalik had a pet, the resultant coin would likely be in the top 20. we will simply have to get raj one there instead
# blocking is false
# created at is wed mar 03 01:58:19 0000 2021
# default profile is true
# default profile image is false
# description is roll boulder up hill, it rolls back down.
# fast followers count is 0
# favourites count is 93910
# follow request sent is false
# followed by is false
# followers count is 136966
# following is false
# friends count is 400
# has custom timelines is false
# id is 0
# id str is
# is translator is false
# listed count is 3012
# location is
# media count is 1502
# name is sisyphus
# normal followers count is 136966
# notifications is false
# profile banner url is profile banners
# profile image url is profile images igd vcy6 normal.jpg
# protected is false
# screen name is 0xsisyphus
# show all inline media is false
# statuses count is 34643
# time zone is
# translator type is none
# url is
# utc offset is 0
# verified is false
# withheld scope is
# is blue verified is true
# starturl is 0xsisyphus
# id is 0
# location is
# conversation id str is
# created at is sun sep 26 23:46:50 0000 2021
# display text range is 0
# display text range is 133
# display url is xgtzfprftm
# expanded url is 0xsisyphus status photo 1
# id str is
# indices is 134
# indices is 157
# media key is 3
# media url is media fap859lxeaebnfv.jpg
# type is photo
# url is xgtzfprftm
# status is available
# h is 878
# w is 1234
# resize is fit
# h is 854
# w is 1200
# resize is fit
# h is 484
# w is 680
# resize is fit
# h is 150
# w is 150
# resize is crop
# height is 878
# width is 1234
# x is 0
# y is 187
# w is 1234
# h is 691
# x is 84
# y is 0
# w is 878
# h is 878
# x is 138
# y is 0
# w is 770
# h is 878
# x is 304
# y is 0
# w is 439
# h is 878
# x is 0
# y is 0
# w is 1234
# h is 878
# display url is xgtzfprftm
# expanded url is 0xsisyphus status photo 1
# id str is
# indices is 134
# indices is 157
# media key is 3
# media url is media fap859lxeaebnfv.jpg
# type is photo
# url is xgtzfprftm
# status is available
# h is 878
# w is 1234
# resize is fit
# h is 854
# w is 1200
# resize is fit
# h is 484
# w is 680
# resize is fit
# h is 150
# w is 150
# resize is crop
# height is 878
# width is 1234
# x is 0
# y is 187
# w is 1234
# h is 691
# x is 84
# y is 0
# w is 878
# h is 878
# x is 138
# y is 0
# w is 770
# h is 878
# x is 304
# y is 0
# w is 439
# h is 878
# x is 0
# y is 0
# w is 1234
# h is 878
# favorite count is 3771
# favorited is false
# full text is some levels im watching on the 450 year chart for stocks think pretty strong support at 1930s levels, if we break there back to 1812 xgtzfprftm
# id str is
# lang is en
# permalink is 0xsisyphus status
# possibly sensitive is false
# quote count is 121
# reply count is 140
# retweet count is 527
# retweeted is false
# text is some levels im watching on the 450 year chart for stocks think pretty strong support at 1930s levels, if we break there back to 1812 xgtzfprftm
# blocking is false
# created at is wed mar 03 01:58:19 0000 2021
# default profile is true
# default profile image is false
# description is roll boulder up hill, it rolls back down.
# fast followers count is 0
# favourites count is 93910
# follow request sent is false
# followed by is false
# followers count is 136966
# following is false
# friends count is 400
# has custom timelines is false
# id is 0
# id str is
# is translator is false
# listed count is 3012
# location is
# media count is 1502
# name is sisyphus
# normal followers count is 136966
# notifications is false
# profile banner url is profile banners
# profile image url is profile images igd vcy6 normal.jpg
# protected is false
# screen name is 0xsisyphus
# show all inline media is false
# statuses count is 34643
# time zone is
# translator type is none
# url is
# utc offset is 0
# verified is false
# withheld scope is
# is blue verified is true
# starturl is 0xsisyphus
# id is 0
# location is
# conversation id str is
# created at is tue nov 15 01:32:49 0000 2022
# display text range is 0
# display text range is 159
# favorite count is 3305
# favorited is false
# full text is sbf mentions a video game in the nyt piece, called storybook brawl it turns out ftx actually owns this game, he used the article as a promoted ad basically
# id str is
# lang is en
# permalink is 0xsisyphus status
# possibly sensitive is false
# quote count is 100
# reply count is 170
# retweet count is 264
# retweeted is false
# text is sbf mentions a video game in the nyt piece, called storybook brawl it turns out ftx actually owns this game, he used the article as a promoted ad basically
# blocking is false
# created at is wed mar 03 01:58:19 0000 2021
# default profile is true
# default profile image is false
# description is roll boulder up hill, it rolls back down.
# fast followers count is 0
# favourites count is 93910
# follow request sent is false
# followed by is false
# followers count is 136966
# following is false
# friends count is 400
# has custom timelines is false
# id is 0
# id str is
# is translator is false
# listed count is 3012
# location is
# media count is 1502
# name is sisyphus
# normal followers count is 136966
# notifications is false
# profile banner url is profile banners
# profile image url is profile images igd vcy6 normal.jpg
# protected is false
# screen name is 0xsisyphus
# show all inline media is false
# statuses count is 34643
# time zone is
# translator type is none
# url is
# utc offset is 0
# verified is false
# withheld scope is
# is blue verified is true
# starturl is 0xsisyphus
# id is 0
# location is
# conversation id str is
# created at is fri nov 18 01:17:52 0000 2022
# display text range is 0
# display text range is 72
# display url is afhbut2wyn
# expanded url is 0xsisyphus status photo 1
# id str is
# indices is 73
# indices is 96
# media key is 3
# media url is media fhzwzyawaaettz .jpg
# type is photo
# url is afhbut2wyn
# status is available
# x is 607
# y is 188
# h is 44
# w is 44
# x is 508
# y is 192
# h is 44
# w is 44
# x is 306
# y is 145
# h is 56
# w is 56
# x is 607
# y is 188
# h is 44
# w is 44
# x is 508
# y is 192
# h is 44
# w is 44
# x is 306
# y is 145
# h is 56
# w is 56
# x is 607
# y is 188
# h is 44
# w is 44
# x is 508
# y is 192
# h is 44
# w is 44
# x is 306
# y is 145
# h is 56
# w is 56
# x is 607
# y is 188
# h is 44
# w is 44
# x is 508
# y is 192
# h is 44
# w is 44
# x is 306
# y is 145
# h is 56
# w is 56
# h is 336
# w is 670
# resize is fit
# h is 336
# w is 670
# resize is fit
# h is 336
# w is 670
# resize is fit
# h is 150
# w is 150
# resize is crop
# height is 336
# width is 670
# x is 70
# y is 0
# w is 600
# h is 336
# x is 334
# y is 0
# w is 336
# h is 336
# x is 375
# y is 0
# w is 295
# h is 336
# x is 502
# y is 0
# w is 168
# h is 336
# x is 0
# y is 0
# w is 670
# h is 336
# display url is afhbut2wyn
# expanded url is 0xsisyphus status photo 1
# id str is
# indices is 73
# indices is 96
# media key is 3
# media url is media fhzwzyawaaettz .jpg
# type is photo
# url is afhbut2wyn
# status is available
# x is 607
# y is 188
# h is 44
# w is 44
# x is 508
# y is 192
# h is 44
# w is 44
# x is 306
# y is 145
# h is 56
# w is 56
# x is 607
# y is 188
# h is 44
# w is 44
# x is 508
# y is 192
# h is 44
# w is 44
# x is 306
# y is 145
# h is 56
# w is 56
# x is 607
# y is 188
# h is 44
# w is 44
# x is 508
# y is 192
# h is 44
# w is 44
# x is 306
# y is 145
# h is 56
# w is 56
# x is 607
# y is 188
# h is 44
# w is 44
# x is 508
# y is 192
# h is 44
# w is 44
# x is 306
# y is 145
# h is 56
# w is 56
# h is 336
# w is 670
# resize is fit
# h is 336
# w is 670
# resize is fit
# h is 336
# w is 670
# resize is fit
# h is 150
# w is 150
# resize is crop
# height is 336
# width is 670
# x is 70
# y is 0
# w is 600
# h is 336
# x is 334
# y is 0
# w is 336
# h is 336
# x is 375
# y is 0
# w is 295
# h is 336
# x is 502
# y is 0
# w is 168
# h is 336
# x is 0
# y is 0
# w is 670
# h is 336
# favorite count is 3153
# favorited is false
# full text is the bahamian supreme court is now one of the largest holders of ethereum afhbut2wyn
# id str is
# lang is en
# permalink is 0xsisyphus status
# possibly sensitive is false
# quote count is 107
# reply count is 235
# retweet count is 270
# retweeted is false
# text is the bahamian supreme court is now one of the largest holders of ethereum afhbut2wyn
# blocking is false
# created at is wed mar 03 01:58:19 0000 2021
# default profile is true
# default profile image is false
# description is roll boulder up hill, it rolls back down.
# fast followers count is 0
# favourites count is 93910
# follow request sent is false
# followed by is false
# followers count is 136966
# following is false
# friends count is 400
# has custom timelines is false
# id is 0
# id str is
# is translator is false
# listed count is 3012
# location is
# media count is 1502
# name is sisyphus
# normal followers count is 136966
# notifications is false
# profile banner url is profile banners
# profile image url is profile images igd vcy6 normal.jpg
# protected is false
# screen name is 0xsisyphus
# show all inline media is false
# statuses count is 34643
# time zone is
# translator type is none
# url is
# utc offset is 0
# verified is false
# withheld scope is
# is blue verified is true
# starturl is 0xsisyphus
# id is 0
# location is
# conversation id str is
# created at is sun mar 10 14:41:38 0000 2024
# display text range is 0
# display text range is 119
# display url is dixze9hxgr
# expanded url is 0xsisyphus status photo 1
# id str is
# indices is 120
# indices is 143
# media key is 3
# media url is media giuqtxswkaaszxb.jpg
# type is photo
# url is dixze9hxgr
# status is available
# x is 218
# y is 191
# h is 37
# w is 37
# x is 218
# y is 191
# h is 37
# w is 37
# x is 218
# y is 191
# h is 37
# w is 37
# x is 218
# y is 191
# h is 37
# w is 37
# h is 500
# w is 564
# resize is fit
# h is 500
# w is 564
# resize is fit
# h is 500
# w is 564
# resize is fit
# h is 150
# w is 150
# resize is crop
# height is 500
# width is 564
# x is 0
# y is 25
# w is 564
# h is 316
# x is 64
# y is 0
# w is 500
# h is 500
# x is 125
# y is 0
# w is 439
# h is 500
# x is 314
# y is 0
# w is 250
# h is 500
# x is 0
# y is 0
# w is 564
# h is 500
# display url is dixze9hxgr
# expanded url is 0xsisyphus status photo 1
# id str is
# indices is 120
# indices is 143
# media key is 3
# media url is media giuqtxswkaaszxb.jpg
# type is photo
# url is dixze9hxgr
# status is available
# x is 218
# y is 191
# h is 37
# w is 37
# x is 218
# y is 191
# h is 37
# w is 37
# x is 218
# y is 191
# h is 37
# w is 37
# x is 218
# y is 191
# h is 37
# w is 37
# h is 500
# w is 564
# resize is fit
# h is 500
# w is 564
# resize is fit
# h is 500
# w is 564
# resize is fit
# h is 150
# w is 150
# resize is crop
# height is 500
# width is 564
# x is 0
# y is 25
# w is 564
# h is 316
# x is 64
# y is 0
# w is 500
# h is 500
# x is 125
# y is 0
# w is 439
# h is 500
# x is 314
# y is 0
# w is 250
# h is 500
# x is 0
# y is 0
# w is 564
# h is 500
# favorite count is 2713
# favorited is false
# full text is the key to cryptocurrency investing is to be the guy on the right and sell for real world assets at appropriate times dixze9hxgr
# id str is
# lang is en
# permalink is 0xsisyphus status
# possibly sensitive is false
# quote count is 22
# reply count is 48
# retweet count is 300
# retweeted is false
# text is the key to cryptocurrency investing is to be the guy on the right and sell for real world assets at appropriate times dixze9hxgr
# blocking is false
# created at is wed mar 03 01:58:19 0000 2021
# default profile is true
# default profile image is false
# description is roll boulder up hill, it rolls back down.
# fast followers count is 0
# favourites count is 93910
# follow request sent is false
# followed by is false
# followers count is 136966
# following is false
# friends count is 400
# has custom timelines is false
# id is 0
# id str is
# is translator is false
# listed count is 3012
# location is
# media count is 1502
# name is sisyphus
# normal followers count is 136966
# notifications is false
# profile banner url is profile banners
# profile image url is profile images igd vcy6 normal.jpg
# protected is false
# screen name is 0xsisyphus
# show all inline media is false
# statuses count is 34643
# time zone is
# translator type is none
# url is
# utc offset is 0
# verified is false
# withheld scope is
# is blue verified is true
# starturl is 0xsisyphus
# id is 0
# location is
# conversation id str is
# created at is wed nov 09 16:33:28 0000 2022
# display text range is 0
# display text range is 127
# favorite count is 2240
# favorited is false
# full text is ftx not disabling trading; remaining users are trading wildly with monopoly money, and it affects prices on all other exchanges
# id str is
# lang is en
# permalink is 0xsisyphus status
# possibly sensitive is false
# quote count is 35
# reply count is 89
# retweet count is 141
# retweeted is false
# text is ftx not disabling trading; remaining users are trading wildly with monopoly money, and it affects prices on all other exchanges
# blocking is false
# created at is wed mar 03 01:58:19 0000 2021
# default profile is true
# default profile image is false
# description is roll boulder up hill, it rolls back down.
# fast followers count is 0
# favourites count is 93910
# follow request sent is false
# followed by is false
# followers count is 136966
# following is false
# friends count is 400
# has custom timelines is false
# id is 0
# id str is
# is translator is false
# listed count is 3012
# location is
# media count is 1502
# name is sisyphus
# normal followers count is 136966
# notifications is false
# profile banner url is profile banners
# profile image url is profile images igd vcy6 normal.jpg
# protected is false
# screen name is 0xsisyphus
# show all inline media is false
# statuses count is 34643
# time zone is
# translator type is none
# url is
# utc offset is 0
# verified is false
# withheld scope is
# is blue verified is true
# starturl is 0xsisyphus
# id is 0
# location is
# conversation id str is
# created at is fri apr 26 00:31:02 0000 2024
# display text range is 0
# display text range is 261
# favorite count is 2140
# favorited is false
# full text is memecoins are making people realize nearly all of the tech in crypto is a smokescreen designed to sell you a token that does nothing marked up 100x from the private round this is why vc do not like memecoins it threatens their core business, selling vapor
# id str is
# lang is en
# permalink is 0xsisyphus status
# possibly sensitive is false
# quote count is 67
# reply count is 119
# retweet count is 337
# retweeted is false
# text is memecoins are making people realize nearly all of the tech in crypto is a smokescreen designed to sell you a token that does nothing marked up 100x from the private round this is why vc do not like memecoins it threatens their core business, selling vapor
# blocking is false
# created at is wed mar 03 01:58:19 0000 2021
# default profile is true
# default profile image is false
# description is roll boulder up hill, it rolls back down.
# fast followers count is 0
# favourites count is 93910
# follow request sent is false
# followed by is false
# followers count is 136966
# following is false
# friends count is 400
# has custom timelines is false
# id is 0
# id str is
# is translator is false
# listed count is 3012
# location is
# media count is 1502
# name is sisyphus
# normal followers count is 136966
# notifications is false
# profile banner url is profile banners
# profile image url is profile images igd vcy6 normal.jpg
# protected is false
# screen name is 0xsisyphus
# show all inline media is false
# statuses count is 34643
# time zone is
# translator type is none
# url is
# utc offset is 0
# verified is false
# withheld scope is
# is blue verified is true
# starturl is 0xsisyphus
# id is 0
# location is
# conversation id str is
# created at is tue may 07 01:33:14 0000 2024
# display text range is 0
# display text range is 42
# display url is 553fyve9nt
# expanded url is 0xsisyphus status photo 1
# id str is
# indices is 43
# indices is 66
# media key is 3
# media url is media gm8idzaboaaau7s.jpg
# type is photo
# url is 553fyve9nt
# status is available
# h is 1283
# w is 1179
# resize is fit
# h is 1200
# w is 1103
# resize is fit
# h is 680
# w is 625
# resize is fit
# h is 150
# w is 150
# resize is crop
# height is 1283
# width is 1179
# x is 0
# y is 623
# w is 1179
# h is 660
# x is 0
# y is 104
# w is 1179
# h is 1179
# x is 0
# y is 0
# w is 1125
# h is 1283
# x is 0
# y is 0
# w is 642
# h is 1283
# x is 0
# y is 0
# w is 1179
# h is 1283
# display url is 553fyve9nt
# expanded url is 0xsisyphus status photo 1
# id str is
# indices is 43
# indices is 66
# media key is 3
# media url is media gm8idzaboaaau7s.jpg
# type is photo
# url is 553fyve9nt
# status is available
# h is 1283
# w is 1179
# resize is fit
# h is 1200
# w is 1103
# resize is fit
# h is 680
# w is 625
# resize is fit
# h is 150
# w is 150
# resize is crop
# height is 1283
# width is 1179
# x is 0
# y is 623
# w is 1179
# h is 660
# x is 0
# y is 104
# w is 1179
# h is 1179
# x is 0
# y is 0
# w is 1125
# h is 1283
# x is 0
# y is 0
# w is 642
# h is 1283
# x is 0
# y is 0
# w is 1179
# h is 1283
# favorite count is 1755
# favorited is false
# full text is the current state of the solana blockchain 553fyve9nt
# id str is
# lang is en
# permalink is 0xsisyphus status
# possibly sensitive is false
# quote count is 23
# reply count is 79
# retweet count is 111
# retweeted is false
# text is the current state of the solana blockchain 553fyve9nt
# blocking is false
# created at is wed mar 03 01:58:19 0000 2021
# default profile is true
# default profile image is false
# description is roll boulder up hill, it rolls back down.
# fast followers count is 0
# favourites count is 93910
# follow request sent is false
# followed by is false
# followers count is 136966
# following is false
# friends count is 400
# has custom timelines is false
# id is 0
# id str is
# is translator is false
# listed count is 3012
# location is
# media count is 1502
# name is sisyphus
# normal followers count is 136966
# notifications is false
# profile banner url is profile banners
# profile image url is profile images igd vcy6 normal.jpg
# protected is false
# screen name is 0xsisyphus
# show all inline media is false
# statuses count is 34643
# time zone is
# translator type is none
# url is
# utc offset is 0
# verified is false
# withheld scope is
# is blue verified is true
# starturl is 0xsisyphus
# id is 0
# location is
# conversation id str is
# created at is wed sep 14 15:50:35 0000 2022
# display text range is 0
# display text range is 11
# display url is 4q8ryqltej
# expanded url is 0xsisyphus status photo 1
# id str is
# indices is 12
# indices is 35
# media key is 3
# media url is media fcojjp8xeaiqhgg.png
# type is photo
# url is 4q8ryqltej
# status is available
# x is 35
# y is 17
# h is 42
# w is 42
# x is 539
# y is 156
# h is 63
# w is 63
# x is 12
# y is 183
# h is 77
# w is 77
# x is 357
# y is 96
# h is 114
# w is 114
# x is 35
# y is 17
# h is 42
# w is 42
# x is 539
# y is 156
# h is 63
# w is 63
# x is 12
# y is 183
# h is 77
# w is 77
# x is 357
# y is 96
# h is 114
# w is 114
# x is 35
# y is 17
# h is 42
# w is 42
# x is 539
# y is 156
# h is 63
# w is 63
# x is 12
# y is 183
# h is 77
# w is 77
# x is 357
# y is 96
# h is 114
# w is 114
# x is 35
# y is 17
# h is 42
# w is 42
# x is 539
# y is 156
# h is 63
# w is 63
# x is 12
# y is 183
# h is 77
# w is 77
# x is 357
# y is 96
# h is 114
# w is 114
# h is 374
# w is 680
# resize is fit
# h is 374
# w is 680
# resize is fit
# h is 374
# w is 680
# resize is fit
# h is 150
# w is 150
# resize is crop
# height is 374
# width is 680
# x is 12
# y is 0
# w is 668
# h is 374
# x is 238
# y is 0
# w is 374
# h is 374
# x is 261
# y is 0
# w is 328
# h is 374
# x is 332
# y is 0
# w is 187
# h is 374
# x is 0
# y is 0
# w is 680
# h is 374
# display url is 4q8ryqltej
# expanded url is 0xsisyphus status photo 1
# id str is
# indices is 12
# indices is 35
# media key is 3
# media url is media fcojjp8xeaiqhgg.png
# type is photo
# url is 4q8ryqltej
# status is available
# x is 35
# y is 17
# h is 42
# w is 42
# x is 539
# y is 156
# h is 63
# w is 63
# x is 12
# y is 183
# h is 77
# w is 77
# x is 357
# y is 96
# h is 114
# w is 114
# x is 35
# y is 17
# h is 42
# w is 42
# x is 539
# y is 156
# h is 63
# w is 63
# x is 12
# y is 183
# h is 77
# w is 77
# x is 357
# y is 96
# h is 114
# w is 114
# x is 35
# y is 17
# h is 42
# w is 42
# x is 539
# y is 156
# h is 63
# w is 63
# x is 12
# y is 183
# h is 77
# w is 77
# x is 357
# y is 96
# h is 114
# w is 114
# x is 35
# y is 17
# h is 42
# w is 42
# x is 539
# y is 156
# h is 63
# w is 63
# x is 12
# y is 183
# h is 77
# w is 77
# x is 357
# y is 96
# h is 114
# w is 114
# h is 374
# w is 680
# resize is fit
# h is 374
# w is 680
# resize is fit
# h is 374
# w is 680
# resize is fit
# h is 150
# w is 150
# resize is crop
# height is 374
# width is 680
# x is 12
# y is 0
# w is 668
# h is 374
# x is 238
# y is 0
# w is 374
# h is 374
# x is 261
# y is 0
# w is 328
# h is 374
# x is 332
# y is 0
# w is 187
# h is 374
# x is 0
# y is 0
# w is 680
# h is 374
# favorite count is 1616
# favorited is false
# full text is cannon time 4q8ryqltej
# id str is
# lang is en
# permalink is 0xsisyphus status
# possibly sensitive is false
# quote count is 9
# reply count is 43
# retweet count is 182
# retweeted is false
# text is cannon time 4q8ryqltej
# blocking is false
# created at is wed mar 03 01:58:19 0000 2021
# default profile is true
# default profile image is false
# description is roll boulder up hill, it rolls back down.
# fast followers count is 0
# favourites count is 93910
# follow request sent is false
# followed by is false
# followers count is 136966
# following is false
# friends count is 400
# has custom timelines is false
# id is 0
# id str is
# is translator is false
# listed count is 3012
# location is
# media count is 1502
# name is sisyphus
# normal followers count is 136966
# notifications is false
# profile banner url is profile banners
# profile image url is profile images igd vcy6 normal.jpg
# protected is false
# screen name is 0xsisyphus
# show all inline media is false
# statuses count is 34643
# time zone is
# translator type is none
# url is
# utc offset is 0
# verified is false
# withheld scope is
# is blue verified is true
# starturl is 0xsisyphus
# id is 0
# location is
# conversation id str is
# created at is mon nov 14 22:39:12 0000 2022
# display text range is 0
# display text range is 229
# favorite count is 1463
# favorited is false
# full text is the nyt article reads as narrative and information control it would be very bad for the industry, but good for sbf, if american based non crypto natives believed binance was responsible for ftx alameda losing billions in user deposits
# id str is
# lang is en
# permalink is 0xsisyphus status
# possibly sensitive is false
# quote count is 19
# reply count is 133
# retweet count is 111
# retweeted is false
# text is the nyt article reads as narrative and information control it would be very bad for the industry, but good for sbf, if american based non crypto natives believed binance was responsible for ftx alameda losing billions in user deposits
# blocking is false
# created at is wed mar 03 01:58:19 0000 2021
# default profile is true
# default profile image is false
# description is roll boulder up hill, it rolls back down.
# fast followers count is 0
# favourites count is 93910
# follow request sent is false
# followed by is false
# followers count is 136966
# following is false
# friends count is 400
# has custom timelines is false
# id is 0
# id str is
# is translator is false
# listed count is 3012
# location is
# media count is 1502
# name is sisyphus
# normal followers count is 136966
# notifications is false
# profile banner url is profile banners
# profile image url is profile images igd vcy6 normal.jpg
# protected is false
# screen name is 0xsisyphus
# show all inline media is false
# statuses count is 34643
# time zone is
# translator type is none
# url is
# utc offset is 0
# verified is false
# withheld scope is
# is blue verified is true
# starturl is 0xsisyphus
# id is 0
# location is
# conversation id str is
# created at is wed jun 15 14:25:45 0000 2022
# display text range is 0
# display text range is 0
# display url is urdgpgda2d
# expanded url is 0xsisyphus status photo 1
# id str is
# indices is 0
# indices is 23
# media key is 3
# media url is media fvtnh38wyaa2uj1.png
# type is photo
# url is urdgpgda2d
# status is available
# h is 1223
# w is 1280
# resize is fit
# h is 1147
# w is 1200
# resize is fit
# h is 650
# w is 680
# resize is fit
# h is 150
# w is 150
# resize is crop
# height is 1223
# width is 1280
# x is 0
# y is 121
# w is 1280
# h is 717
# x is 57
# y is 0
# w is 1223
# h is 1223
# x is 207
# y is 0
# w is 1073
# h is 1223
# x is 557
# y is 0
# w is 612
# h is 1223
# x is 0
# y is 0
# w is 1280
# h is 1223
# display url is urdgpgda2d
# expanded url is 0xsisyphus status photo 1
# id str is
# indices is 0
# indices is 23
# media key is 3
# media url is media fvtnh38wyaa2uj1.png
# type is photo
# url is urdgpgda2d
# status is available
# h is 1223
# w is 1280
# resize is fit
# h is 1147
# w is 1200
# resize is fit
# h is 650
# w is 680
# resize is fit
# h is 150
# w is 150
# resize is crop
# height is 1223
# width is 1280
# x is 0
# y is 121
# w is 1280
# h is 717
# x is 57
# y is 0
# w is 1223
# h is 1223
# x is 207
# y is 0
# w is 1073
# h is 1223
# x is 557
# y is 0
# w is 612
# h is 1223
# x is 0
# y is 0
# w is 1280
# h is 1223
# favorite count is 1470
# favorited is false
# full text is urdgpgda2d
# id str is
# lang is zxx
# permalink is 0xsisyphus status
# possibly sensitive is false
# quote count is 23
# reply count is 19
# retweet count is 225
# retweeted is false
# text is urdgpgda2d
# blocking is false
# created at is wed mar 03 01:58:19 0000 2021
# default profile is true
# default profile image is false
# description is roll boulder up hill, it rolls back down.
# fast followers count is 0
# favourites count is 93910
# follow request sent is false
# followed by is false
# followers count is 136966
# following is false
# friends count is 400
# has custom timelines is false
# id is 0
# id str is
# is translator is false
# listed count is 3012
# location is
# media count is 1502
# name is sisyphus
# normal followers count is 136966
# notifications is false
# profile banner url is profile banners
# profile image url is profile images igd vcy6 normal.jpg
# protected is false
# screen name is 0xsisyphus
# show all inline media is false
# statuses count is 34643
# time zone is
# translator type is none
# url is
# utc offset is 0
# verified is false
# withheld scope is
# is blue verified is true
# starturl is 0xsisyphus
# id is 0
# location is
# conversation id str is
# created at is thu aug 05 17:23:18 0000 2021
# display text range is 0
# display text range is 43
# display url is vgi0dbtsmo
# expanded url is 0xsisyphus status photo 1
# id str is
# indices is 44
# indices is 67
# media key is 3
# media url is media e8cyjbkxiagb0uk.png
# type is photo
# url is vgi0dbtsmo
# status is available
# h is 486
# w is 512
# resize is fit
# h is 486
# w is 512
# resize is fit
# h is 486
# w is 512
# resize is fit
# h is 150
# w is 150
# resize is crop
# height is 486
# width is 512
# x is 0
# y is 0
# w is 512
# h is 287
# x is 0
# y is 0
# w is 486
# h is 486
# x is 30
# y is 0
# w is 426
# h is 486
# x is 122
# y is 0
# w is 243
# h is 486
# x is 0
# y is 0
# w is 512
# h is 486
# display url is vgi0dbtsmo
# expanded url is 0xsisyphus status photo 1
# id str is
# indices is 44
# indices is 67
# media key is 3
# media url is media e8cyjbkxiagb0uk.png
# type is photo
# url is vgi0dbtsmo
# status is available
# h is 486
# w is 512
# resize is fit
# h is 486
# w is 512
# resize is fit
# h is 486
# w is 512
# resize is fit
# h is 150
# w is 150
# resize is crop
# height is 486
# width is 512
# x is 0
# y is 0
# w is 512
# h is 287
# x is 0
# y is 0
# w is 486
# h is 486
# x is 30
# y is 0
# w is 426
# h is 486
# x is 122
# y is 0
# w is 243
# h is 486
# x is 0
# y is 0
# w is 512
# h is 486
# favorite count is 1415
# favorited is false
# full text is eth is actually deflationary right now. wow vgi0dbtsmo
# id str is
# lang is en
# permalink is 0xsisyphus status
# possibly sensitive is false
# quote count is 15
# reply count is 43
# retweet count is 145
# retweeted is false
# text is eth is actually deflationary right now. wow vgi0dbtsmo
# blocking is false
# created at is wed mar 03 01:58:19 0000 2021
# default profile is true
# default profile image is false
# description is roll boulder up hill, it rolls back down.
# fast followers count is 0
# favourites count is 93910
# follow request sent is false
# followed by is false
# followers count is 136966
# following is false
# friends count is 400
# has custom timelines is false
# id is 0
# id str is
# is translator is false
# listed count is 3012
# location is
# media count is 1502
# name is sisyphus
# normal followers count is 136966
# notifications is false
# profile banner url is profile banners
# profile image url is profile images igd vcy6 normal.jpg
# protected is false
# screen name is 0xsisyphus
# show all inline media is false
# statuses count is 34643
# time zone is
# translator type is none
# url is
# utc offset is 0
# verified is false
# withheld scope is
# is blue verified is true
# starturl is 0xsisyphus
# id is 0
# location is
# conversation id str is
# created at is wed may 08 01:13:40 0000 2024
# display text range is 0
# display text range is 279
# display url is pump.fun
# expanded url is http: pump.fun
# url is ba4nrl0lil
# indices is 17
# indices is 40
# display url is ojq2cqoxrg
# expanded url is 0xsisyphus status photo 1
# id str is
# indices is 280
# indices is 303
# media key is 3
# media url is media gnbmmchbwaaqzt5.png
# type is photo
# url is ojq2cqoxrg
# status is available
# h is 338
# w is 398
# resize is fit
# h is 338
# w is 398
# resize is fit
# h is 338
# w is 398
# resize is fit
# h is 150
# w is 150
# resize is crop
# height is 338
# width is 398
# x is 0
# y is 115
# w is 398
# h is 223
# x is 0
# y is 0
# w is 338
# h is 338
# x is 0
# y is 0
# w is 296
# h is 338
# x is 0
# y is 0
# w is 169
# h is 338
# x is 0
# y is 0
# w is 398
# h is 338
# display url is ojq2cqoxrg
# expanded url is 0xsisyphus status photo 1
# id str is
# indices is 280
# indices is 303
# media key is 3
# media url is media gnbmmchbwaaqzt5.png
# type is photo
# url is ojq2cqoxrg
# status is available
# h is 338
# w is 398
# resize is fit
# h is 338
# w is 398
# resize is fit
# h is 338
# w is 398
# resize is fit
# h is 150
# w is 150
# resize is crop
# height is 338
# width is 398
# x is 0
# y is 115
# w is 398
# h is 223
# x is 0
# y is 0
# w is 338
# h is 338
# x is 0
# y is 0
# w is 296
# h is 338
# x is 0
# y is 0
# w is 169
# h is 338
# x is 0
# y is 0
# w is 398
# h is 338
# favorite count is 893
# favorited is false
# full text is yesterday i used ba4nrl0lil to launch a funny meme yes, really . of the 48 percent from the dev wallet: 28 percent is burned, 10 percent is locked for a year and 10 percent is locked for ten years. i do not have any other supply some interesting learnings about the memecoin factory from this: ojq2cqoxrg
# id str is
# lang is en
# permalink is 0xsisyphus status
# possibly sensitive is false
# quote count is 48
# reply count is 110
# retweet count is 109
# retweeted is false
# text is yesterday i used ba4nrl0lil to launch a funny meme yes, really . of the 48 percent from the dev wallet: 28 percent is burned, 10 percent is locked for a year and 10 percent is locked for ten years. i do not have any other supply some interesting learnings about the memecoin factory from this: ojq2cqoxrg
# blocking is false
# created at is wed mar 03 01:58:19 0000 2021
# default profile is true
# default profile image is false
# description is roll boulder up hill, it rolls back down.
# fast followers count is 0
# favourites count is 93910
# follow request sent is false
# followed by is false
# followers count is 136966
# following is false
# friends count is 400
# has custom timelines is false
# id is 0
# id str is
# is translator is false
# listed count is 3012
# location is
# media count is 1502
# name is sisyphus
# normal followers count is 136966
# notifications is false
# profile banner url is profile banners
# profile image url is profile images igd vcy6 normal.jpg
# protected is false
# screen name is 0xsisyphus
# show all inline media is false
# statuses count is 34643
# time zone is
# translator type is none
# url is
# utc offset is 0
# verified is false
# withheld scope is
# is blue verified is true
# starturl is 0xsisyphus
# id is 0
# location is
# conversation id str is
# created at is fri aug 19 16:25:24 0000 2022
# display text range is 0
# display text range is 0
# display url is lvrzwhm75v
# expanded url is 0xsisyphus status photo 1
# id str is
# indices is 0
# indices is 23
# media key is 3
# media url is media faix2dcwiae2cqf.jpg
# type is photo
# url is lvrzwhm75v
# status is available
# x is 803
# y is 672
# h is 45
# w is 45
# x is 752
# y is 630
# h is 42
# w is 42
# x is 426
# y is 357
# h is 23
# w is 23
# x is 803
# y is 672
# h is 45
# w is 45
# h is 748
# w is 1280
# resize is fit
# h is 701
# w is 1200
# resize is fit
# h is 397
# w is 680
# resize is fit
# h is 150
# w is 150
# resize is crop
# height is 748
# width is 1280
# x is 0
# y is 31
# w is 1280
# h is 717
# x is 490
# y is 0
# w is 748
# h is 748
# x is 536
# y is 0
# w is 656
# h is 748
# x is 677
# y is 0
# w is 374
# h is 748
# x is 0
# y is 0
# w is 1280
# h is 748
# display url is lvrzwhm75v
# expanded url is 0xsisyphus status photo 1
# id str is
# indices is 0
# indices is 23
# media key is 3
# media url is media faix2dcwiae2cqf.jpg
# type is photo
# url is lvrzwhm75v
# status is available
# x is 803
# y is 672
# h is 45
# w is 45
# x is 752
# y is 630
# h is 42
# w is 42
# x is 426
# y is 357
# h is 23
# w is 23
# x is 803
# y is 672
# h is 45
# w is 45
# h is 748
# w is 1280
# resize is fit
# h is 701
# w is 1200
# resize is fit
# h is 397
# w is 680
# resize is fit
# h is 150
# w is 150
# resize is crop
# height is 748
# width is 1280
# x is 0
# y is 31
# w is 1280
# h is 717
# x is 490
# y is 0
# w is 748
# h is 748
# x is 536
# y is 0
# w is 656
# h is 748
# x is 677
# y is 0
# w is 374
# h is 748
# x is 0
# y is 0
# w is 1280
# h is 748
# favorite count is 1205
# favorited is false
# full text is lvrzwhm75v
# id str is
# lang is zxx
# permalink is 0xsisyphus status
# possibly sensitive is false
# quote count is 32
# reply count is 64
# retweet count is 180
# retweeted is false
# text is lvrzwhm75v
# blocking is false
# created at is wed mar 03 01:58:19 0000 2021
# default profile is true
# default profile image is false
# description is roll boulder up hill, it rolls back down.
# fast followers count is 0
# favourites count is 93910
# follow request sent is false
# followed by is false
# followers count is 136966
# following is false
# friends count is 400
# has custom timelines is false
# id is 0
# id str is
# is translator is false
# listed count is 3012
# location is
# media count is 1502
# name is sisyphus
# normal followers count is 136966
# notifications is false
# profile banner url is profile banners
# profile image url is profile images igd vcy6 normal.jpg
# protected is false
# screen name is 0xsisyphus
# show all inline media is false
# statuses count is 34643
# time zone is
# translator type is none
# url is
# utc offset is 0
# verified is false
# withheld scope is
# is blue verified is true
# starturl is 0xsisyphus
# id is 0
# location is
# conversation id str is
# created at is tue aug 20 18:25:28 0000 2024
# display text range is 0
# display text range is 42
# display url is dbunsqf8ic
# expanded url is 0xsisyphus status photo 1
# id str is
# indices is 43
# indices is 66
# media key is 3
# media url is media gvcfgxiwwaepvfo.jpg
# type is photo
# url is dbunsqf8ic
# status is available
# h is 838
# w is 1182
# resize is fit
# h is 838
# w is 1182
# resize is fit
# h is 482
# w is 680
# resize is fit
# h is 150
# w is 150
# resize is crop
# height is 838
# width is 1182
# x is 0
# y is 176
# w is 1182
# h is 662
# x is 0
# y is 0
# w is 838
# h is 838
# x is 0
# y is 0
# w is 735
# h is 838
# x is 0
# y is 0
# w is 419
# h is 838
# x is 0
# y is 0
# w is 1182
# h is 838
# display url is dbunsqf8ic
# expanded url is 0xsisyphus status photo 1
# id str is
# indices is 43
# indices is 66
# media key is 3
# media url is media gvcfgxiwwaepvfo.jpg
# type is photo
# url is dbunsqf8ic
# status is available
# h is 838
# w is 1182
# resize is fit
# h is 838
# w is 1182
# resize is fit
# h is 482
# w is 680
# resize is fit
# h is 150
# w is 150
# resize is crop
# height is 838
# width is 1182
# x is 0
# y is 176
# w is 1182
# h is 662
# x is 0
# y is 0
# w is 838
# h is 838
# x is 0
# y is 0
# w is 735
# h is 838
# x is 0
# y is 0
# w is 419
# h is 838
# x is 0
# y is 0
# w is 1182
# h is 838
# favorite count is 1310
# favorited is false
# full text is two chains that do not exist august 2024 dbunsqf8ic
# id str is
# lang is en
# permalink is 0xsisyphus status
# possibly sensitive is false
# quote count is 11
# reply count is 50
# retweet count is 66
# retweeted is false
# text is two chains that do not exist august 2024 dbunsqf8ic
# blocking is false
# created at is wed mar 03 01:58:19 0000 2021
# default profile is true
# default profile image is false
# description is roll boulder up hill, it rolls back down.
# fast followers count is 0
# favourites count is 93910
# follow request sent is false
# followed by is false
# followers count is 136966
# following is false
# friends count is 400
# has custom timelines is false
# id is 0
# id str is
# is translator is false
# listed count is 3012
# location is
# media count is 1502
# name is sisyphus
# normal followers count is 136966
# notifications is false
# profile banner url is profile banners
# profile image url is profile images igd vcy6 normal.jpg
# protected is false
# screen name is 0xsisyphus
# show all inline media is false
# statuses count is 34643
# time zone is
# translator type is none
# url is
# utc offset is 0
# verified is false
# withheld scope is
# is blue verified is true
# starturl is 0xsisyphus
# id is 0
# location is
# conversation id str is
# created at is wed nov 09 15:46:09 0000 2022
# display text range is 0
# display text range is 164
# favorite count is 1243
# favorited is false
# full text is the scary part to me isnt near term bank runs or price going down, its that the long term legitimacy of crypto as an industry is in real danger for the first time
# id str is
# lang is en
# permalink is 0xsisyphus status
# possibly sensitive is false
# quote count is 23
# reply count is 117
# retweet count is 74
# retweeted is false
# text is the scary part to me isnt near term bank runs or price going down, its that the long term legitimacy of crypto as an industry is in real danger for the first time
# blocking is false
# created at is wed mar 03 01:58:19 0000 2021
# default profile is true
# default profile image is false
# description is roll boulder up hill, it rolls back down.
# fast followers count is 0
# favourites count is 93910
# follow request sent is false
# followed by is false
# followers count is 136966
# following is false
# friends count is 400
# has custom timelines is false
# id is 0
# id str is
# is translator is false
# listed count is 3012
# location is
# media count is 1502
# name is sisyphus
# normal followers count is 136966
# notifications is false
# profile banner url is profile banners
# profile image url is profile images igd vcy6 normal.jpg
# protected is false
# screen name is 0xsisyphus
# show all inline media is false
# statuses count is 34643
# time zone is
# translator type is none
# url is
# utc offset is 0
# verified is false
# withheld scope is
# is blue verified is true
# starturl is 0xsisyphus
# id is 0
# location is
# conversation id str is
# created at is wed mar 27 01:06:33 0000 2024
# display text range is 0
# display text range is 199
# favorite count is 1073
# favorited is false
# full text is do not worry, your funds are safe on blast because the chain can be rolled back by a multisig which is unilaterally controlled by a guy who slept with peter thiel when he was 20 for seed round funding
# id str is
# lang is en
# permalink is 0xsisyphus status
# possibly sensitive is false
# quote count is 15
# reply count is 83
# retweet count is 69
# retweeted is false
# text is do not worry, your funds are safe on blast because the chain can be rolled back by a multisig which is unilaterally controlled by a guy who slept with peter thiel when he was 20 for seed round funding
# blocking is false
# created at is wed mar 03 01:58:19 0000 2021
# default profile is true
# default profile image is false
# description is roll boulder up hill, it rolls back down.
# fast followers count is 0
# favourites count is 93910
# follow request sent is false
# followed by is false
# followers count is 136966
# following is false
# friends count is 400
# has custom timelines is false
# id is 0
# id str is
# is translator is false
# listed count is 3012
# location is
# media count is 1502
# name is sisyphus
# normal followers count is 136966
# notifications is false
# profile banner url is profile banners
# profile image url is profile images igd vcy6 normal.jpg
# protected is false
# screen name is 0xsisyphus
# show all inline media is false
# statuses count is 34643
# time zone is
# translator type is none
# url is
# utc offset is 0
# verified is false
# withheld scope is
# is blue verified is true
# starturl is 0xsisyphus
# id is 0
# location is
# conversation id str is
# created at is fri mar 08 18:56:30 0000 2024
# display text range is 0
# display text range is 188
# favorite count is 1129
# favorited is false
# full text is people work 18 hours a day in crypto trying to grind out wins only to get outperformed by people who bought a coin with a hat and go around the world partying there is a lesson in there
# id str is
# lang is en
# permalink is 0xsisyphus status
# possibly sensitive is false
# quote count is 12
# reply count is 79
# retweet count is 95
# retweeted is false
# text is people work 18 hours a day in crypto trying to grind out wins only to get outperformed by people who bought a coin with a hat and go around the world partying there is a lesson in there
# blocking is false
# created at is wed mar 03 01:58:19 0000 2021
# default profile is true
# default profile image is false
# description is roll boulder up hill, it rolls back down.
# fast followers count is 0
# favourites count is 93910
# follow request sent is false
# followed by is false
# followers count is 136966
# following is false
# friends count is 400
# has custom timelines is false
# id is 0
# id str is
# is translator is false
# listed count is 3012
# location is
# media count is 1502
# name is sisyphus
# normal followers count is 136966
# notifications is false
# profile banner url is profile banners
# profile image url is profile images igd vcy6 normal.jpg
# protected is false
# screen name is 0xsisyphus
# show all inline media is false
# statuses count is 34643
# time zone is
# translator type is none
# url is
# utc offset is 0
# verified is false
# withheld scope is
# is blue verified is true
# starturl is 0xsisyphus
# id is 0
# location is
# conversation id str is
# created at is tue aug 22 14:44:26 0000 2023
# display text range is 0
# display text range is 153
# favorite count is 1100
# favorited is false
# full text is a lot of people think they are in crypto for the tech, but really from what i can tell crypto is more like a religion for the lonely and terminally online
# id str is
# lang is en
# permalink is 0xsisyphus status
# possibly sensitive is false
# quote count is 17
# reply count is 111
# retweet count is 80
# retweeted is false
# text is a lot of people think they are in crypto for the tech, but really from what i can tell crypto is more like a religion for the lonely and terminally online
# blocking is false
# created at is wed mar 03 01:58:19 0000 2021
# default profile is true
# default profile image is false
# description is roll boulder up hill, it rolls back down.
# fast followers count is 0
# favourites count is 93910
# follow request sent is false
# followed by is false
# followers count is 136966
# following is false
# friends count is 400
# has custom timelines is false
# id is 0
# id str is
# is translator is false
# listed count is 3012
# location is
# media count is 1502
# name is sisyphus
# normal followers count is 136966
# notifications is false
# profile banner url is profile banners
# profile image url is profile images igd vcy6 normal.jpg
# protected is false
# screen name is 0xsisyphus
# show all inline media is false
# statuses count is 34643
# time zone is
# translator type is none
# url is
# utc offset is 0
# verified is false
# withheld scope is
# is blue verified is true
# starturl is 0xsisyphus
# id is 0
# location is
# conversation id str is
# created at is sun jan 21 17:04:06 0000 2024
# display text range is 0
# display text range is 160
# favorite count is 1102
# favorited is false
# full text is celestia does 75 dollars of revenue a day. nobody knows what dymension or altlayer does. your project does not need adoption or users , just launch the token
# id str is
# lang is en
# permalink is 0xsisyphus status
# possibly sensitive is false
# quote count is 30
# reply count is 63
# retweet count is 78
# retweeted is false
# text is celestia does 75 dollars of revenue a day. nobody knows what dymension or altlayer does. your project does not need adoption or users , just launch the token
# blocking is false
# created at is wed mar 03 01:58:19 0000 2021
# default profile is true
# default profile image is false
# description is roll boulder up hill, it rolls back down.
# fast followers count is 0
# favourites count is 93910
# follow request sent is false
# followed by is false
# followers count is 136966
# following is false
# friends count is 400
# has custom timelines is false
# id is 0
# id str is
# is translator is false
# listed count is 3012
# location is
# media count is 1502
# name is sisyphus
# normal followers count is 136966
# notifications is false
# profile banner url is profile banners
# profile image url is profile images igd vcy6 normal.jpg
# protected is false
# screen name is 0xsisyphus
# show all inline media is false
# statuses count is 34643
# time zone is
# translator type is none
# url is
# utc offset is 0
# verified is false
# withheld scope is
# is blue verified is true
# starturl is 0xsisyphus
# id is 0
# location is
# conversation id str is
# created at is wed aug 30 12:52:34 0000 2023
# display text range is 0
# display text range is 249
# display url is qmzbeeya7q
# expanded url is 0xsisyphus status photo 1
# id str is
# indices is 250
# indices is 273
# media key is 3
# media url is media f4x8qjqxaaafajq.png
# type is photo
# url is qmzbeeya7q
# status is available
# h is 385
# w is 644
# resize is fit
# h is 385
# w is 644
# resize is fit
# h is 385
# w is 644
# resize is fit
# h is 150
# w is 150
# resize is crop
# height is 385
# width is 644
# x is 0
# y is 24
# w is 644
# h is 361
# x is 0
# y is 0
# w is 385
# ...
# output file: ./SisyphusAI output\Dataset#5643dataset_twitter-scraper_2024-11-02_16-42-39-127_processed_part101.txt
# output file: ./SisyphusAI output\Dataset#5643dataset_twitter-scraper_2024-11-02_16-42-39-127_processed_part102.txt
# output file: ./SisyphusAI output\Dataset#5643dataset_twitter-scraper_2024-11-02_16-42-39-127_processed_part103.txt
# output file: ./SisyphusAI output\Dataset#5643dataset_twitter-scraper_2024-11-02_16-42-39-127_processed_part104.txt
# output file: ./SisyphusAI output\Dataset#5643dataset_twitter-scraper_2024-11-02_16-42-39-127_processed_part105.txt
# output file: ./SisyphusAI output\Dataset#5643dataset_twitter-scraper_2024-11-02_16-42-39-127_processed_part106.txt
# output file: ./SisyphusAI output\Dataset#5643dataset_twitter-scraper_2024-11-02_16-42-39-127_processed_part107.txt
# output file: ./SisyphusAI output\Dataset#5643dataset_twitter-scraper_2024-11-02_16-42-39-127_processed_part108.txt
# output file: ./SisyphusAI output\Dataset#5643dataset_twitter-scraper_2024-11-02_16-42-39-127_processed_part109.txt
# output file: ./SisyphusAI output\Dataset#5643dataset_twitter-scraper_2024-11-02_16-42-39-127_processed_part110.txt
# output file: ./SisyphusAI output\Dataset#5643dataset_twitter-scraper_2024-11-02_16-42-39-127_processed_part111.txt
# output file: ./SisyphusAI output\Dataset#5643dataset_twitter-scraper_2024-11-02_16-42-39-127_processed_part112.txt
# output file: ./SisyphusAI output\Dataset#5643dataset_twitter-scraper_2024-11-02_16-42-39-127_processed_part113.txt
# output file: ./SisyphusAI output\Dataset#5643dataset_twitter-scraper_2024-11-02_16-42-39-127_processed_part114.txt
# output file: ./SisyphusAI output\Dataset#5643dataset_twitter-scraper_2024-11-02_16-42-39-127_processed_part115.txt
# output file: ./SisyphusAI output\Dataset#5643dataset_twitter-scraper_2024-11-02_16-42-39-127_processed_part116.txt
# output file: ./SisyphusAI output\Dataset#5643dataset_twitter-scraper_2024-11-02_16-42-39-127_processed_part117.txt
# output file: ./SisyphusAI output\Dataset#5643dataset_twitter-scraper_2024-11-02_16-42-39-127_processed_part118.txt
# output file: ./SisyphusAI output\Dataset#5643dataset_twitter-scraper_2024-11-02_16-42-39-127_processed_part119.txt
# output file: ./SisyphusAI output\Dataset#5643dataset_twitter-scraper_2024-11-02_16-42-39-127_processed_part120.txt
# output file: ./SisyphusAI output\Dataset#5643dataset_twitter-scraper_2024-11-02_16-42-39-127_processed_part121.txt
# output file: ./SisyphusAI output\Dataset#5643dataset_twitter-scraper_2024-11-02_16-42-39-127_processed_part122.txt
# output file: ./SisyphusAI output\Dataset#5643dataset_twitter-scraper_2024-11-02_16-42-39-127_processed_part123.txt
# output file: ./SisyphusAI output\Dataset#5643dataset_twitter-scraper_2024-11-02_16-42-39-127_processed_part124.txt
# output file: ./SisyphusAI output\Dataset#5643dataset_twitter-scraper_2024-11-02_16-42-39-127_processed_part125.txt
# output file: ./SisyphusAI output\Dataset#5643dataset_twitter-scraper_2024-11-02_16-42-39-127_processed_part126.txt
# output file: ./SisyphusAI output\Dataset#5643dataset_twitter-scraper_2024-11-02_16-42-39-127_processed_part127.txt
# output file: ./SisyphusAI output\Dataset#5643dataset_twitter-scraper_2024-11-02_16-42-39-127_processed_part128.txt
# output file: ./SisyphusAI output\Dataset#5643dataset_twitter-scraper_2024-11-02_16-42-39-127_processed_part129.txt
# output file: ./SisyphusAI output\Dataset#5643dataset_twitter-scraper_2024-11-02_16-42-39-127_processed_part130.txt
# output file: ./SisyphusAI output\Dataset#5643dataset_twitter-scraper_2024-11-02_16-42-39-127_processed_part131.txt
# output file: ./SisyphusAI output\Dataset#5643dataset_twitter-scraper_2024-11-02_16-42-39-127_processed_part132.txt
# output file: ./SisyphusAI output\Dataset#5643dataset_twitter-scraper_2024-11-02_16-42-39-127_processed_part133.txt
# output file: ./SisyphusAI output\Dataset#5643dataset_twitter-scraper_2024-11-02_16-42-39-127_processed_part134.txt
# output file: ./SisyphusAI output\Dataset#5643dataset_twitter-scraper_2024-11-02_16-42-39-127_processed_part135.txt
# output file: ./SisyphusAI output\Dataset#5643dataset_twitter-scraper_2024-11-02_16-42-39-127_processed_part136.txt
# output file: ./SisyphusAI output\Dataset#5643dataset_twitter-scraper_2024-11-02_16-42-39-127_processed_part137.txt
# output file: ./SisyphusAI output\Dataset#5643dataset_twitter-scraper_2024-11-02_16-42-39-127_processed_part138.txt
# output file: ./SisyphusAI output\Dataset#5643dataset_twitter-scraper_2024-11-02_16-42-39-127_processed_part139.txt
# output file: ./SisyphusAI output\Dataset#5643dataset_twitter-scraper_2024-11-02_16-42-39-127_processed_part140.txt
# output file: ./SisyphusAI output\Dataset#5643dataset_twitter-scraper_2024-11-02_16-42-39-127_processed_part141.txt
# output file: ./SisyphusAI output\Dataset#5643dataset_twitter-scraper_2024-11-02_16-42-39-127_processed_part142.txt
# output file: ./SisyphusAI output\Dataset#5643dataset_twitter-scraper_2024-11-02_16-42-39-127_processed_part143.txt
# output file: ./SisyphusAI output\Dataset#5643dataset_twitter-scraper_2024-11-02_16-42-39-127_processed_part144.txt
# output file: ./SisyphusAI output\Dataset#5643dataset_twitter-scraper_2024-11-02_16-42-39-127_processed_part145.txt
# output file: ./SisyphusAI output\Dataset#5643dataset_twitter-scraper_2024-11-02_16-42-39-127_processed_part146.txt
# output file: ./SisyphusAI output\Dataset#5643dataset_twitter-scraper_2024-11-02_16-42-39-127_processed_part147.txt
# output file: ./SisyphusAI output\Dataset#5643dataset_twitter-scraper_2024-11-02_16-42-39-127_processed_part148.txt
# output file: ./SisyphusAI output\Dataset#5643dataset_twitter-scraper_2024-11-02_16-42-39-127_processed_part149.txt
# output file: ./SisyphusAI output\Dataset#5643dataset_twitter-scraper_2024-11-02_16-42-39-127_processed_part150.txt
# output file: ./SisyphusAI output\Dataset#5643dataset_twitter-scraper_2024-11-02_16-42-39-127_processed_part151.txt
# output file: ./SisyphusAI output\Dataset#5643dataset_twitter-scraper_2024-11-02_16-42-39-127_processed_part152.txt
# output file: ./SisyphusAI output\Dataset#5643dataset_twitter-scraper_2024-11-02_16-42-39-127_processed_part153.txt
# output file: ./SisyphusAI output\Dataset#5643dataset_twitter-scraper_2024-11-02_16-42-39-127_processed_part154.txt
# output file: ./SisyphusAI output\Dataset#5643dataset_twitter-scraper_2024-11-02_16-42-39-127_processed_part155.txt
# output file: ./SisyphusAI output\Dataset#5643dataset_twitter-scraper_2024-11-02_16-42-39-127_processed_part156.txt
# output file: ./SisyphusAI output\Dataset#5643dataset_twitter-scraper_2024-11-02_16-42-39-127_processed_part157.txt
# output file: ./SisyphusAI output\Dataset#5643dataset_twitter-scraper_2024-11-02_16-42-39-127_processed_part158.txt
# output file: ./SisyphusAI output\Dataset#5643dataset_twitter-scraper_2024-11-02_16-42-39-127_processed_part159.txt
# output file: ./SisyphusAI output\Dataset#5643dataset_twitter-scraper_2024-11-02_16-42-39-127_processed_part160.txt
# output file: ./SisyphusAI output\Dataset#5643dataset_twitter-scraper_2024-11-02_16-42-39-127_processed_part161.txt
# output file: ./SisyphusAI output\Dataset#5643dataset_twitter-scraper_2024-11-02_16-42-39-127_processed_part162.txt
# output file: ./SisyphusAI output\Dataset#5643dataset_twitter-scraper_2024-11-02_16-42-39-127_processed_part163.txt
# output file: ./SisyphusAI output\Dataset#5643dataset_twitter-scraper_2024-11-02_16-42-39-127_processed_part164.txt
# output file: ./SisyphusAI output\Dataset#5643dataset_twitter-scraper_2024-11-02_16-42-39-127_processed_part165.txt
# output file: ./SisyphusAI output\Dataset#5643dataset_twitter-scraper_2024-11-02_16-42-39-127_processed_part166.txt
# output file: ./SisyphusAI output\Dataset#5643dataset_twitter-scraper_2024-11-02_16-42-39-127_processed_part167.txt
# output file: ./SisyphusAI output\Dataset#5643dataset_twitter-scraper_2024-11-02_16-42-39-127_processed_part168.txt
# output file: ./SisyphusAI output\Dataset#5643dataset_twitter-scraper_2024-11-02_16-42-39-127_processed_part169.txt
# output file: ./SisyphusAI output\Dataset#5643dataset_twitter-scraper_2024-11-02_16-42-39-127_processed_part170.txt
# output file: ./SisyphusAI output\Dataset#5643dataset_twitter-scraper_2024-11-02_16-42-39-127_processed_part171.txt
# output file: ./SisyphusAI output\Dataset#5643dataset_twitter-scraper_2024-11-02_16-42-39-127_processed_part172.txt
# output file: ./SisyphusAI output\Dataset#5643dataset_twitter-scraper_2024-11-02_16-42-39-127_processed_part173.txt
# output file: ./SisyphusAI output\Dataset#5643dataset_twitter-scraper_2024-11-02_16-42-39-127_processed_part174.txt
# output file: ./SisyphusAI output\Dataset#5643dataset_twitter-scraper_2024-11-02_16-42-39-127_processed_part175.txt
# output file: ./SisyphusAI output\Dataset#5643dataset_twitter-scraper_2024-11-02_16-42-39-127_processed_part176.txt
# output file: ./SisyphusAI output\Dataset#5643dataset_twitter-scraper_2024-11-02_16-42-39-127_processed_part177.txt
# output file: ./SisyphusAI output\Dataset#5643dataset_twitter-scraper_2024-11-02_16-42-39-127_processed_part178.txt
# output file: ./SisyphusAI output\Dataset#5643dataset_twitter-scraper_2024-11-02_16-42-39-127_processed_part179.txt
# output file: ./SisyphusAI output\Dataset#5643dataset_twitter-scraper_2024-11-02_16-42-39-127_processed_part180.txt
# output file: ./SisyphusAI output\Dataset#5643dataset_twitter-scraper_2024-11-02_16-42-39-127_processed_part181.txt
# output file: ./SisyphusAI output\Dataset#5643dataset_twitter-scraper_2024-11-02_16-42-39-127_processed_part182.txt
# output file: ./SisyphusAI output\Dataset#5643dataset_twitter-scraper_2024-11-02_16-42-39-127_processed_part183.txt
# output file: ./SisyphusAI output\Dataset#5643dataset_twitter-scraper_2024-11-02_16-42-39-127_processed_part184.txt
# output file: ./SisyphusAI output\Dataset#5643dataset_twitter-scraper_2024-11-02_16-42-39-127_processed_part185.txt
# output file: ./SisyphusAI output\Dataset#5643dataset_twitter-scraper_2024-11-02_16-42-39-127_processed_part186.txt
# output file: ./SisyphusAI output\Dataset#5643dataset_twitter-scraper_2024-11-02_16-42-39-127_processed_part187.txt
# output file: ./SisyphusAI output\Dataset#5643dataset_twitter-scraper_2024-11-02_16-42-39-127_processed_part188.txt
# output file: ./SisyphusAI output\Dataset#5643dataset_twitter-scraper_2024-11-02_16-42-39-127_processed_part189.txt
# output file: ./SisyphusAI output\Dataset#5643dataset_twitter-scraper_2024-11-02_16-42-39-127_processed_part190.txt
# output file: ./SisyphusAI output\Dataset#5643dataset_twitter-scraper_2024-11-02_16-42-39-127_processed_part191.txt
# output file: ./SisyphusAI output\Dataset#5643dataset_twitter-scraper_2024-11-02_16-42-39-127_processed_part192.txt
# output file: ./SisyphusAI output\Dataset#5643dataset_twitter-scraper_2024-11-02_16-42-39-127_processed_part193.txt
# output file: ./SisyphusAI output\Dataset#5643dataset_twitter-scraper_2024-11-02_16-42-39-127_processed_part194.txt
# output file: ./SisyphusAI output\Dataset#5643dataset_twitter-scraper_2024-11-02_16-42-39-127_processed_part195.txt
# output file: ./SisyphusAI output\Dataset#5643dataset_twitter-scraper_2024-11-02_16-42-39-127_processed_part196.txt
# output file: ./SisyphusAI output\Dataset#5643dataset_twitter-scraper_2024-11-02_16-42-39-127_processed_part197.txt
# output file: ./SisyphusAI output\Dataset#5643dataset_twitter-scraper_2024-11-02_16-42-39-127_processed_part198.txt
# output file: ./SisyphusAI output\Dataset#5643dataset_twitter-scraper_2024-11-02_16-42-39-127_processed_part199.txt
# output file: ./SisyphusAI output\Dataset#5643dataset_twitter-scraper_2024-11-02_16-42-39-127_processed_part200.txt
# output file: ./SisyphusAI output\Dataset#5643dataset_twitter-scraper_2024-11-02_16-42-39-127_processed_part201.txt
# output file: ./SisyphusAI output\Dataset#5643dataset_twitter-scraper_2024-11-02_16-42-39-127_processed_part202.txt
# output file: ./SisyphusAI output\Dataset#5643dataset_twitter-scraper_2024-11-02_16-42-39-127_processed_part203.txt
# output file: ./SisyphusAI output\Dataset#5643dataset_twitter-scraper_2024-11-02_16-42-39-127_processed_part204.txt
# output file: ./SisyphusAI output\Dataset#5643dataset_twitter-scraper_2024-11-02_16-42-39-127_processed_part205.txt
# output file: ./SisyphusAI output\Dataset#5643dataset_twitter-scraper_2024-11-02_16-42-39-127_processed_part206.txt
# output file: ./SisyphusAI output\Dataset#5643dataset_twitter-scraper_2024-11-02_16-42-39-127_processed_part207.txt
# output file: ./SisyphusAI output\Dataset#5643dataset_twitter-scraper_2024-11-02_16-42-39-127_processed_part208.txt
# output file: ./SisyphusAI output\Dataset#5643dataset_twitter-scraper_2024-11-02_16-42-39-127_processed_part209.txt
# output file: ./SisyphusAI output\Dataset#5643dataset_twitter-scraper_2024-11-02_16-42-39-127_processed_part210.txt
# output file: ./SisyphusAI output\Dataset#5643dataset_twitter-scraper_2024-11-02_16-42-39-127_processed_part211.txt
# output file: ./SisyphusAI output\Dataset#5643dataset_twitter-scraper_2024-11-02_16-42-39-127_processed_part212.txt
# output file: ./SisyphusAI output\Dataset#5643dataset_twitter-scraper_2024-11-02_16-42-39-127_processed_part213.txt
# output file: ./SisyphusAI output\Dataset#5643dataset_twitter-scraper_2024-11-02_16-42-39-127_processed_part214.txt
# output file: ./SisyphusAI output\Dataset#5643dataset_twitter-scraper_2024-11-02_16-42-39-127_processed_part215.txt
# output file: ./SisyphusAI output\Dataset#5643dataset_twitter-scraper_2024-11-02_16-42-39-127_processed_part216.txt
# output file: ./SisyphusAI output\Dataset#5643dataset_twitter-scraper_2024-11-02_16-42-39-127_processed_part217.txt
# output file: ./SisyphusAI output\Dataset#5643dataset_twitter-scraper_2024-11-02_16-42-39-127_processed_part218.txt
# output file: ./SisyphusAI output\Dataset#5643dataset_twitter-scraper_2024-11-02_16-42-39-127_processed_part219.txt
# output file: ./SisyphusAI output\Dataset#5643dataset_twitter-scraper_2024-11-02_16-42-39-127_processed_part220.txt
# output file: ./SisyphusAI output\Dataset#5643dataset_twitter-scraper_2024-11-02_16-42-39-127_processed_part221.txt
# output file: ./SisyphusAI output\Dataset#5643dataset_twitter-scraper_2024-11-02_16-42-39-127_processed_part222.txt
# output file: ./SisyphusAI output\Dataset#5643dataset_twitter-scraper_2024-11-02_16-42-39-127_processed_part223.txt
# output file: ./SisyphusAI output\Dataset#5643dataset_twitter-scraper_2024-11-02_16-42-39-127_processed_part224.txt
# output file: ./SisyphusAI output\Dataset#5643dataset_twitter-scraper_2024-11-02_16-42-39-127_processed_part225.txt
# output file: ./SisyphusAI output\Dataset#5643dataset_twitter-scraper_2024-11-02_16-42-39-127_processed_part226.txt
# output file: ./SisyphusAI output\Dataset#5643dataset_twitter-scraper_2024-11-02_16-42-39-127_processed_part227.txt
# output file: ./SisyphusAI output\Dataset#5643dataset_twitter-scraper_2024-11-02_16-42-39-127_processed_part228.txt
# output file: ./SisyphusAI output\Dataset#5643dataset_twitter-scraper_2024-11-02_16-42-39-127_processed_part229.txt
# output file: ./SisyphusAI output\Dataset#5643dataset_twitter-scraper_2024-11-02_16-42-39-127_processed_part230.txt
# output file: ./SisyphusAI output\Dataset#5643dataset_twitter-scraper_2024-11-02_16-42-39-127_processed_part231.txt
# output file: ./SisyphusAI output\Dataset#5643dataset_twitter-scraper_2024-11-02_16-42-39-127_processed_part232.txt
# output file: ./SisyphusAI output\Dataset#5643dataset_twitter-scraper_2024-11-02_16-42-39-127_processed_part233.txt
# output file: ./SisyphusAI output\Dataset#5643dataset_twitter-scraper_2024-11-02_16-42-39-127_processed_part234.txt
# output file: ./SisyphusAI output\Dataset#5643dataset_twitter-scraper_2024-11-02_16-42-39-127_processed_part235.txt
# output file: ./SisyphusAI output\Dataset#5643dataset_twitter-scraper_2024-11-02_16-42-39-127_processed_part236.txt
# output file: ./SisyphusAI output\Dataset#5643dataset_twitter-scraper_2024-11-02_16-42-39-127_processed_part237.txt
# File ./SisyphusAI output\Dataset#5643dataset_twitter-scraper_2024-11-02_16-42-39-127_processed_part237.txt has been created with 22 lines.

# %%
def read_txt_files(input_dir: str, files: list[str]):
    def helper(file_name):
        with open(f'{input_dir}/{file_name}', 'r') as file:
            data = file.readlines()
            file.close()

        new_name = file_name.replace('.txt', '')
        return new_name, data

    # concurrently read and load all .json files
    with ThreadPoolExecutor() as exe:
        txts = dict(list(exe.map(helper, files)))
    return txts

# %%
txt_files = [file for file in files if file.endswith('.txt')]
txts = read_txt_files(input_dir=input_dir, files=txt_files)
txts
# Out:
# {'Dataset#5642tweets-sample': ['One must imagine Sisyphus happy\n',
#   'Do crackheads ever say Im too broke to smoke crack tonight  No They get up and make it happen  Lesson in there\n',
#   'Ive fumbled generational wealth like 6 times this week\n',
#   'The most evergreen meme will always be the founders pet  If Vitalik had a pet the resultant coin would likely be in the top 20 We will simply have to get Rajs one there instead\n',
#   'some levels im watching on the 450year chart for stocks  think pretty strong support at 1930s levels if we break there back to 1812\n',
#   'SBF mentions a video game in the NYT piece called Storybook Brawl   It turns out FTX actually owns this game he used the article as a promoted ad basically\n',
#   'The Bahamian Supreme Court is now one of the largest holders of Ethereum\n',
#   'The key to cryptocurrency investing is to be the guy on the right and sell for real world assets at appropriate times\n',
#   'FTX not disabling trading remaining users are trading wildly with monopoly money and it affects prices on all other exchanges\n',
#   'Memecoins are making people realize nearly all of the tech in crypto is a smokescreen designed to sell you a token that does nothing marked up 100x from the private round  This is why VCs dont like memecoins  it threatens their core business selling vapor\n',
#   'The current state of the Solana blockchain\n',
#   'The NYT article reads as narrative and information control  It would be very bad for the industry but good for SBF if US based non crypto natives believed Binance was responsible for FTXAlameda losing billions in user deposits\n',
#   'ETH is actually deflationary right now Wow\n',
#   'Yesterday I used  to launch a funny meme yes really Of the 48 from the dev wallet 28 is burned 10 is locked for a year and 10 is locked for ten years I dont have any other supply  Some interesting learnings about the memecoin factory from this\n',
#   'Two chains that do not exist   August 2024\n',
#   'The scary part to me isnt near term bank runs or price going down its that the long term legitimacy of crypto as an industry is in real danger for the first time\n',
#   'Dont worry your funds are safe on Blast because the chain can be rolled back by a multisig which is unilaterally controlled by a guy who slept with Peter thiel when he was 20 for seed round funding\n',
#   'People work 18 hours a day in crypto trying to grind out wins only to get outperformed by people who bought a coin with a hat and go around the world partying   There is a lesson in there\n',
#   'A lot of people think theyre in crypto for the tech but really from what I can tell crypto is more like a religion for the lonely and terminally online\n',
#   'Celestia does 75 dollars of revenue a day Nobody knows what dymension or altlayer does Your project doesnt need adoption or users just launch the token\n',
#   'StarkWare just zerod all user balances on old wallets that didnt upgrade to latest contracts  equivalent of having the money in your bank account disappear if you dont get the latest software package  Thank You For Flying With StarkWare Airlines\n',
#   'Matic raised 450 million in cash just about one year ago so they were burning 200m a year prior to layoffs   They just publicly said they have 250m left maybe 18 months of runway if they sell no tokens\n',
#   'Be patient with the people who have been in crypto for 5 years who dont know what etherscan transaction spoofing is This may be their first time ever looking at blockchain data\n',
#   'BREAKING US to face extremely rare cicadageddon as two generations of over 100 trillion cicadas will emerge together for the first time since 1803 shortly after the April 8th solar eclipse\n',
#   'klima whitelist for 1000 accessed by being early in Discord got you 100 tokens 130 tokens after crucible vesting Worth 325k at market   All you had to do was show up early and pay the 1k presale cost\n',
#   'june 2020 halving dump june 2021 fallout from may end of cycle bottom in july with alameda bid june 2022 3ac  leverage blowup actually exactly 2 years ago 61822 was market bottom june 2023 robinhood delisting securities FUD june 2024 alt meltdown  usually up by august\n',
#   'in crypto where there are no fundamentals most people only have conviction until 40 down or so   this means theyll happily hold thru a 15 drawdown but if the market really breaks theyll panic  its better to panic first or not at all\n',
#   'Much higher levels of dispersion than prior cycles in crypto where everything went up and to the right  People betting on the wrong chains wrong tokens and wrong narratives making next to no money Handful of participants in the right coins making big money\n',
#   'Pretty obviously somewhere midcycle IMO We are clearly not truly early anymore but try to avoid saying this out loud too much\n',
#   'Im in a group chat where two people are making a 2 million dollar bet about whether Irene zhao is a tranny  Its a bull market\n',
#   'yesterday was the first day in a while where it felt like crypto again and not web3\n',
#   'This was an OTC deal done at a 35 billion valuation directly with the foundation a few months ago and I think it also unlocks in October\n',
#   'Saylor has spent 366bn on BTC he bought 113bn in 2020 at 159k cost basis 253bn in 2021 at 487k cost basis  Somehow his DCA for 2021 is essentially breakeven at current market prices With 253bn of initial capital deployed theres abt 30mm of returns 1\n',
#   'the more people i meet in the crypto space the more astonished i am at how many people  1 know almost nothing about the space dont do any work 2 have an expectation of massive relative returns ie 1000x 3 dont allin  Get in the trenches and grind\n',
#   'Anyone notice that this time it wasnt different\n',
#   'Crypto networking Wow I can tell youre not a retard who worked at a gas station before winning 4 coin flips in a row Lets chat more\n',
#   'web3 instead of crypto is such a great vehicle for reframing amp legitimizing the space in the eyes of people who already wrote off bitcoinethereumwhatever   very next gen\n',
#   'coinbase really hired 400 thousand people and still cant combine the USD and USDC market liquidity into one book\n',
#   'Thought crypto long term screwed at first but the hardcore will stick around   People will build some new game and get rich again by being early The cycle will begin anew\n',
#   'This is on Ethereum and not somewhere else because security and neutrality are far more important than cheap transaction costs btw\n',
#   'why has the BALD dev interacted with alameda so much two years ago and was one of the first votes on every sushi proposal\n',
#   'Wonder if Jump Trading ever looks at Jump Crypto and says OK thats enough in realized losses\n',
#   'People often forget the number 1 job of CT is to gaslight 99 of market participants to hold their bags to 0\n',
#   'You have to be actively giving yourself brain damage to keep up with crypto at this point\n',
#   'Brian Armstrong is probably checking the Base chains block explorer in his 133 million dollar mansion smiling right now  The retards are gambling god bless them\n',
#   'You ever think about how the ETH Foundation always sells the top without fail\n',
#   'This is what the market rebounds feel like now that someone more sophisticated than alameda is managing liquidations   moon dat\n',
#   'someone bought an etherrock for 120 ETH 160k while gas was gt500 gwei Why\n',
#   'the second plane just hit the curve pools\n',
#   'Base will have memecoins that go to billions probably  Betting on the biggest one is the simplest bet you can make That coin is brett\n',
#   'Eth foundation sold 30m of the second largest and most liquid asset in crypto and price moved down 7 in a day which I think is a large move  What happens when the l1s and l2s trading at 10bn with 10 of float circulating have 100m unlocks\n',
#   'The bull case for crypto can be summarized in this single chart\n',
#   'Invest in the absurd   People dont want to buy productive assets they want to buy black squares with white text on them rocks Cardano Hex jpegs   Scoreboard proves this out\n',
#   'Probably time to run back much of the gambling we just did on Solana but on Base this time\n',
#   'Lol remember yield farming   That was awesome\n',
#   'Celestia nearing the price they did a 100 million OTC deal at 350 which people thought was free money  It turns out buying something that can generate a maximum of about 5 million dollars in revenue for a valuation of 35 billion dollars may not be financially responsible\n',
#   'Last cycles shitcoins were usually simple cute mascots with catchy names and a low unit bias   Lately shitcoins lean into manic shilling shock value and deep internet memes Its a very different vibe\n',
#   'Im not familiar with this type of hedging\n',
#   'Study Paraswap\n',
#   'People who do not use crypto but who are in the crypto industry discuss many different things DePin AI gaming and others  People who use crypto only discuss memecoins\n',
#   'If you can 1 avoid blowing up and 2 mentally capitulating I believe time is on your side for owning cryptocurrencies now specifically Ethereum  positive structural supply imbalance inflation data rolled  rates stepdown  Revisit in a year Hopefully doesnt take two years\n',
#   'Even if the cycle top is not in judging by how most people are reacting to this correction it is 100 certain that the majority of CT will roundtrip everything\n',
#   'ETH supply has been deflating for 9 days now with minimal retail participation onchain or in crypto at all  an extremely low level of network activity is required for scarcity to rise\n',
#   'if you lost money you can always make it back  dont lose the will to keep gambling\n',
#   'why are people upset about michael from curve selling his fake tokens to buy real property  you know thats kind of the point of this right\n',
#   'I wonder why trabucco left\n',
#   'the alpha of 2020 and early 2021 was basically info asymmetry knowing about a project first following the right wallets  information is way more even across participants now alpha in 2022 and beyond is probably how you interpret given info and data\n',
#   'Not sure if Ive ever seen a wellfunded crypto company selfimmolate faster than OpenSea did over the last 18 months   From a valuation in excess of 10 billion to likely being worth nothing and evidently with no plans for a token\n',
#   'who had megacap stocks trading like uniswap shitcoins on their 2022 bingo card\n',
#   'Wanted to to publicly disclose i have been in contact with USHK authorities on the Anubis situation  Working on a full detailed timeline of events transpiring over the last 48 hours soon to come from this account\n',
#   'I think we are in and have been in a golden age for crypto    enough built so we arent just trading the 5m candles in Mex troll box and theres real stuff to evaluate critically   not enough built where the average peopleallocators have totally compressed our returns\n',
#   'They ran out of gas on the exchange hot wallet\n',
#   'Solana is doing whatever BSC did last cycle  Almost every new meme catchphrase or whatever deploys there Someone forked the Pepe images turned it into a penguin and the token hit 40 mil Every single new meme on CT gets put on that chain first Theres a lesson in here\n',
#   'I just spent the last of my eth on this kaws statue\n',
#   'Martin shkreli dumping his own token from a few different wallets\n',
#   'Officially a Rollbit partner Have been very impressed with the continued product work across both casino and crypto trading the first class UIUX and the ambition of the team   Fly with us today if you are not geoblocked or restricted\n',
#   'series A investors in this vaporware are down approximately 50 while locked for 3 years  market healing\n',
#   'putin really sat down and got crypto traders worldwide to listen to russian psyops for 30 minutes\n',
#   'permabulls either liquidated or forcibly delevered people calling for multiyear bear markets panic in every corner and circle  not high conviction enough to lever but im long\n',
#   'Cardano has a 17 billion dollar market cap and the chain cannot process transactions after 8 years Adjust Your Targets Higher\n',
#   'It Would Benefit Most People To Drop Everything And Play Runescape For The Next 912 Months\n',
#   'Normies showing up isnt a top signal  When they start quitting their IRL jobs for crypto or starting funds thats when we need to worry\n',
#   'with a high degree of certainty i can say the anubis rug probably was not a phishing attack and was instead a rogue team member  i am open to him returning only a portion of funds and backstopping the remainder with my personal money\n',
#   'Matic bridges have not been functional for about 3 days\n',
#   'Ethereum price performance has been so bad the dev is posting roadmaps\n',
#   'What did tulip traders end up doing for a living a decade after once things had ended\n',
#   'Its about to get really silly I think\n',
#   'This is the most seriously the US government has ever taken crypto  it is worth thinking about how much normie legitimacy of our industry comes from interactions like this\n',
#   'Over the weekend someone turned 002 ETH into 63 ETH on a coin called pepe\n',
#   'Base chain today in summary   everyone bridged to chase a coin made by either SBF or a close associate which then rugged   shortly thereafter the primary DEX on the chain had an exploit where all LP positions could be drained and halted trading  you still cant bridge back\n',
#   'what if there was a way to race crypto currencies  like you make money if the price of the token goes up\n',
#   'the whole world will soon rely on gambling to make ends meet  retardio\n',
#   'Crypto Youtube is an underrated pathway for finding coins  Most of the video content doesnt make its way back to CT and targets a diff userbase with a position size that is perfect for Solana  The guy who told the world to buy 1 of BTC at 010c is now buying ponke']}

# %%
output_dir = './SisyphusAI output'
for name, lists in txts.items():
    clean_and_split_data(name, lists, output_dir=output_dir, cleaner=normalize_and_clean)
# Out:
# one must imagine sisyphus happy
# do crackheads ever say im too broke to smoke crack tonight no they get up and make it happen lesson in there
# ive fumbled generational wealth like 6 times this week
# the most evergreen meme will always be the founders pet if vitalik had a pet the resultant coin would likely be in the top 20 we will simply have to get rajs one there instead
# some levels im watching on the 450year chart for stocks think pretty strong support at 1930s levels if we break there back to 1812
# sbf mentions a video game in the nyt piece called storybook brawl it turns out ftx actually owns this game he used the article as a promoted ad basically
# the bahamian supreme court is now one of the largest holders of ethereum
# the key to cryptocurrency investing is to be the guy on the right and sell for real world assets at appropriate times
# ftx not disabling trading remaining users are trading wildly with monopoly money and it affects prices on all other exchanges
# memecoins are making people realize nearly all of the tech in crypto is a smokescreen designed to sell you a token that does nothing marked up 100x from the private round this is why vcs dont like memecoins it threatens their core business selling vapor
# the current state of the solana blockchain
# the nyt article reads as narrative and information control it would be very bad for the industry but good for sbf if american based non crypto natives believed binance was responsible for ftxalameda losing billions in user deposits
# eth is actually deflationary right now wow
# yesterday i used to launch a funny meme yes really of the 48 from the dev wallet 28 is burned 10 is locked for a year and 10 is locked for ten years i dont have any other supply some interesting learnings about the memecoin factory from this
# two chains that do not exist august 2024
# the scary part to me isnt near term bank runs or price going down its that the long term legitimacy of crypto as an industry is in real danger for the first time
# dont worry your funds are safe on blast because the chain can be rolled back by a multisig which is unilaterally controlled by a guy who slept with peter thiel when he was 20 for seed round funding
# people work 18 hours a day in crypto trying to grind out wins only to get outperformed by people who bought a coin with a hat and go around the world partying there is a lesson in there
# a lot of people think theyre in crypto for the tech but really from what i can tell crypto is more like a religion for the lonely and terminally online
# celestia does 75 dollars of revenue a day nobody knows what dymension or altlayer does your project doesnt need adoption or users just launch the token
# starkware just zerod all user balances on old wallets that didnt upgrade to latest contracts equivalent of having the money in your bank account disappear if you dont get the latest software package thank you for flying with starkware airlines
# matic raised 450 million in cash just about one year ago so they were burning 200m a year prior to layoffs they just publicly said they have 250m left maybe 18 months of runway if they sell no tokens
# be patient with the people who have been in crypto for 5 years who dont know what etherscan transaction spoofing is this may be their first time ever looking at blockchain data
# breaking american to face extremely rare cicadageddon as two generations of over 100 trillion cicadas will emerge together for the first time since 1803 shortly after the april 8th solar eclipse
# klima whitelist for 1000 accessed by being early in discord got you 100 tokens 130 tokens after crucible vesting worth 325000 at market all you had to do was show up early and pay the 1000 presale cost
# june 2020 halving dump june 2021 fallout from may end of cycle bottom in july with alameda bid june 2022 3ac leverage blowup actually exactly 2 years ago 61822 was market bottom june 2023 robinhood delisting securities fud june 2024 alt meltdown usually up by august
# in crypto where there are no fundamentals most people only have conviction until 40 down or so this means theyll happily hold thru a 15 drawdown but if the market really breaks theyll panic its better to panic first or not at all
# much higher levels of dispersion than prior cycles in crypto where everything went up and to the right people betting on the wrong chains wrong tokens and wrong narratives making next to no money handful of participants in the right coins making big money
# pretty obviously somewhere midcycle imo we are clearly not truly early anymore but try to avoid saying this out loud too much
# im in a group chat where two people are making a 2 million dollar bet about whether irene zhao is a tranny its a bull market
# yesterday was the first day in a while where it felt like crypto again and not web3
# this was an otc deal done at a 35 billion valuation directly with the foundation a few months ago and i think it also unlocks in october
# saylor has spent 366bn on btc he bought 113bn in 2020 at 159000 cost basis 253bn in 2021 at 487000 cost basis somehow his dca for 2021 is essentially breakeven at current market prices with 253bn of initial capital deployed theres abt 30mm of returns 1
# the more people i meet in the crypto space the more astonished i am at how many people 1 know almost nothing about the space dont do any work 2 have an expectation of massive relative returns ie 1000x 3 dont allin get in the trenches and grind
# anyone notice that this time it wasnt different
# crypto networking wow i can tell youre not a retard who worked at a gas station before winning 4 coin flips in a row lets chat more
# web3 instead of crypto is such a great vehicle for reframing amp legitimizing the space in the eyes of people who already wrote off bitcoinethereumwhatever very next gen
# coinbase really hired 400 thousand people and still cant combine the usd and usdc market liquidity into one book
# thought crypto long term screwed at first but the hardcore will stick around people will build some new game and get rich again by being early the cycle will begin anew
# this is on ethereum and not somewhere else because security and neutrality are far more important than cheap transaction costs btw
# why has the bald dev interacted with alameda so much two years ago and was one of the first votes on every sushi proposal
# wonder if jump trading ever looks at jump crypto and says ok thats enough in realized losses
# people often forget the number 1 job of ct is to gaslight 99 of market participants to hold their bags to 0
# you have to be actively giving yourself brain damage to keep up with crypto at this point
# brian armstrong is probably checking the base chains block explorer in his 133 million dollar mansion smiling right now the retards are gambling god bless them
# you ever think about how the eth foundation always sells the top without fail
# this is what the market rebounds feel like now that someone more sophisticated than alameda is managing liquidations moon dat
# someone bought an etherrock for 120 eth 160000 while gas was gt500 gwei why
# the second plane just hit the curve pools
# base will have memecoins that go to billions probably betting on the biggest one is the simplest bet you can make that coin is brett
# eth foundation sold 30m of the second largest and most liquid asset in crypto and price moved down 7 in a day which i think is a large move what happens when the l1s and l2s trading at 10bn with 10 of float circulating have 100m unlocks
# the bull case for crypto can be summarized in this single chart
# invest in the absurd people dont want to buy productive assets they want to buy black squares with white text on them rocks cardano hex jpegs scoreboard proves this out
# probably time to run back much of the gambling we just did on solana but on base this time
# lol remember yield farming that was awesome
# celestia nearing the price they did a 100 million otc deal at 350 which people thought was free money it turns out buying something that can generate a maximum of about 5 million dollars in revenue for a valuation of 35 billion dollars may not be financially responsible
# last cycles shitcoins were usually simple cute mascots with catchy names and a low unit bias lately shitcoins lean into manic shilling shock value and deep internet memes its a very different vibe
# im not familiar with this type of hedging
# study paraswap
# people who do not use crypto but who are in the crypto industry discuss many different things depin ai gaming and others people who use crypto only discuss memecoins
# if you can 1 avoid blowing up and 2 mentally capitulating i believe time is on your side for owning cryptocurrencies now specifically ethereum positive structural supply imbalance inflation data rolled rates stepdown revisit in a year hopefully doesnt take two years
# even if the cycle top is not in judging by how most people are reacting to this correction it is 100 certain that the majority of ct will roundtrip everything
# eth supply has been deflating for 9 days now with minimal retail participation onchain or in crypto at all an extremely low level of network activity is required for scarcity to rise
# if you lost money you can always make it back dont lose the will to keep gambling
# why are people upset about michael from curve selling his fake tokens to buy real property you know thats kind of the point of this right
# i wonder why trabucco left
# the alpha of 2020 and early 2021 was basically info asymmetry knowing about a project first following the right wallets information is way more even across participants now alpha in 2022 and beyond is probably how you interpret given info and data
# not sure if ive ever seen a wellfunded crypto company selfimmolate faster than opensea did over the last 18 months from a valuation in excess of 10 billion to likely being worth nothing and evidently with no plans for a token
# who had megacap stocks trading like uniswap shitcoins on their 2022 bingo card
# wanted to to publicly disclose i have been in contact with ushk authorities on the anubis situation working on a full detailed timeline of events transpiring over the last 48 hours soon to come from this account
# i think we are in and have been in a golden age for crypto enough built so we arent just trading the 5m candles in mex troll box and theres real stuff to evaluate critically not enough built where the average peopleallocators have totally compressed our returns
# they ran out of gas on the exchange hot wallet
# solana is doing whatever bsc did last cycle almost every new meme catchphrase or whatever deploys there someone forked the pepe images turned it into a penguin and the token hit 40 mil every single new meme on ct gets put on that chain first theres a lesson in here
# i just spent the last of my eth on this kaws statue
# martin shkreli dumping his own token from a few different wallets
# officially a rollbit partner have been very impressed with the continued product work across both casino and crypto trading the first class uiux and the ambition of the team fly with us today if you are not geoblocked or restricted
# series a investors in this vaporware are down approximately 50 while locked for 3 years market healing
# putin really sat down and got crypto traders worldwide to listen to russian psyops for 30 minutes
# permabulls either liquidated or forcibly delevered people calling for multiyear bear markets panic in every corner and circle not high conviction enough to lever but im long
# cardano has a 17 billion dollar market cap and the chain cannot process transactions after 8 years adjust your targets higher
# it would benefit most people to drop everything and play runescape for the next 912 months
# normies showing up isnt a top signal when they start quitting their irl jobs for crypto or starting funds thats when we need to worry
# with a high degree of certainty i can say the anubis rug probably was not a phishing attack and was instead a rogue team member i am open to him returning only a portion of funds and backstopping the remainder with my personal money
# matic bridges have not been functional for about 3 days
# ethereum price performance has been so bad the dev is posting roadmaps
# what did tulip traders end up doing for a living a decade after once things had ended
# its about to get really silly i think
# this is the most seriously the american government has ever taken crypto it is worth thinking about how much normie legitimacy of our industry comes from interactions like this
# over the weekend someone turned 002 eth into 63 eth on a coin called pepe
# base chain today in summary everyone bridged to chase a coin made by either sbf or a close associate which then rugged shortly thereafter the primary dex on the chain had an exploit where all lp positions could be drained and halted trading you still cant bridge back
# what if there was a way to race crypto currencies like you make money if the price of the token goes up
# the whole world will soon rely on gambling to make ends meet retardio
# crypto youtube is an underrated pathway for finding coins most of the video content doesnt make its way back to ct and targets a diff userbase with a position size that is perfect for solana the guy who told the world to buy 1 of btc at 010c is now buying ponke
# output file: ./SisyphusAI output\Dataset#5642tweets-sample_processed_part1.txt
# output file: ./SisyphusAI output\Dataset#5642tweets-sample_processed_part2.txt
# output file: ./SisyphusAI output\Dataset#5642tweets-sample_processed_part3.txt
# File ./SisyphusAI output\Dataset#5642tweets-sample_processed_part3.txt has been created with 13 lines.

# %%
from utilities.utilities import rename_all

# %%
rename_all('C:/Users/LARRY/Documents/Scripts/virtuals-internship/SisyphusAI output')
